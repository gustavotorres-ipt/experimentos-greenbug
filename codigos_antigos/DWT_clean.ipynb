# %%
# POde pular essa etapa se os pacotes já estão instalados
# !pip install numpy
# !pip install scikit-learn
# !pip install scikit-image
# !pip install librosa
# !pip install tqdm
# !pip install matplotlib
# !pip install tensorflow
# Out:
# Collecting numpy
#   Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 803.9 kB/s eta 0:00:00 0:00:01
# Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 17.4 MB/s eta 0:00:0000:0100:01
# Installing collected packages: numpy
# Successfully installed numpy-1.26.4
# Collecting scikit-learn
#   Downloading scikit_learn-1.4.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.19.5 in /home/gustavo/.venv/green_bug/lib/python3.12/site-packages (from scikit-learn) (1.26.4)
# Collecting scipy>=1.6.0 (from scikit-learn)
#   Downloading scipy-1.13.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 886.1 kB/s eta 0:00:00 0:00:01
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Downloading joblib-1.4.0-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=2.0.0 (from scikit-learn)
#   Downloading threadpoolctl-3.4.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.4.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 25.4 MB/s eta 0:00:0000:0100:01
# Downloading joblib-1.4.0-py3-none-any.whl (301 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.2/301.2 kB 22.8 MB/s eta 0:00:00
# Downloading scipy-1.13.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (38.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.2/38.2 MB 12.5 MB/s eta 0:00:0000:0100:01
# Downloading threadpoolctl-3.4.0-py3-none-any.whl (17 kB)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
# Successfully installed joblib-1.4.0 scikit-learn-1.4.2 scipy-1.13.0 threadpoolctl-3.4.0
# Collecting scikit-image
#   Downloading scikit_image-0.23.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (14 kB)
# Requirement already satisfied: numpy>=1.23 in /home/gustavo/.venv/green_bug/lib/python3.12/site-packages (from scikit-image) (1.26.4)
# Requirement already satisfied: scipy>=1.9 in /home/gustavo/.venv/green_bug/lib/python3.12/site-packages (from scikit-image) (1.13.0)
# Collecting networkx>=2.8 (from scikit-image)
#   Downloading networkx-3.3-py3-none-any.whl.metadata (5.1 kB)
# Collecting pillow>=9.1 (from scikit-image)
#   Downloading pillow-10.3.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (9.2 kB)
# Collecting imageio>=2.33 (from scikit-image)
#   Downloading imageio-2.34.1-py3-none-any.whl.metadata (4.9 kB)
# Collecting tifffile>=2022.8.12 (from scikit-image)
#   Downloading tifffile-2024.4.24-py3-none-any.whl.metadata (31 kB)
# Requirement already satisfied: packaging>=21 in /home/gustavo/.venv/green_bug/lib/python3.12/site-packages (from scikit-image) (24.0)
# Collecting lazy-loader>=0.4 (from scikit-image)
#   Downloading lazy_loader-0.4-py3-none-any.whl.metadata (7.6 kB)
# Downloading scikit_image-0.23.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.9/14.9 MB 12.4 MB/s eta 0:00:0000:0100:01
# Downloading imageio-2.34.1-py3-none-any.whl (313 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.5/313.5 kB 4.7 MB/s eta 0:00:00:00:01
# Downloading lazy_loader-0.4-py3-none-any.whl (12 kB)
# Downloading networkx-3.3-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 13.4 MB/s eta 0:00:0000:0100:01
# Downloading pillow-10.3.0-cp312-cp312-manylinux_2_28_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 16.4 MB/s eta 0:00:0000:0100:01
# Downloading tifffile-2024.4.24-py3-none-any.whl (225 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 225.0/225.0 kB 7.2 MB/s eta 0:00:00
# Installing collected packages: tifffile, pillow, networkx, lazy-loader, imageio, scikit-image
# Successfully installed imageio-2.34.1 lazy-loader-0.4 networkx-3.3 pillow-10.3.0 scikit-image-0.23.2 tifffile-2024.4.24
# Collecting librosa
#   Downloading librosa-0.10.1-py3-none-any.whl.metadata (8.3 kB)
# Collecting audioread>=2.1.9 (from librosa)
#   Downloading audioread-3.0.1-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3 in /home/gustavo/.venv/green_bug/lib/python3.12/site-packages (from librosa) (1.26.4)
# Requirement already satisfied: scipy>=1.2.0 in /home/gustavo/.venv/green_bug/lib/python3.12/site-packages (from librosa) (1.13.0)
# Requirement already satisfied: scikit-learn>=0.20.0 in /home/gustavo/.venv/green_bug/lib/python3.12/site-packages (from librosa) (1.4.2)
# Requirement already satisfied: joblib>=0.14 in /home/gustavo/.venv/green_bug/lib/python3.12/site-packages (from librosa) (1.4.0)
# Requirement already satisfied: decorator>=4.3.0 in /home/gustavo/.venv/green_bug/lib/python3.12/site-packages (from librosa) (5.1.1)
# Collecting numba>=0.51.0 (from librosa)
#   Downloading numba-0.59.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.7 kB)
# Collecting soundfile>=0.12.1 (from librosa)
#   Downloading soundfile-0.12.1-py2.py3-none-manylinux_2_31_x86_64.whl.metadata (14 kB)
# Collecting pooch>=1.0 (from librosa)
#   Downloading pooch-1.8.1-py3-none-any.whl.metadata (9.5 kB)
# Collecting soxr>=0.3.2 (from librosa)
#   Downloading soxr-0.3.7-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.5 kB)
# Collecting typing-extensions>=4.1.1 (from librosa)
#   Downloading typing_extensions-4.11.0-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: lazy-loader>=0.1 in /home/gustavo/.venv/green_bug/lib/python3.12/site-packages (from librosa) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /home/gustavo/.venv/green_bug/lib/python3.12/site-packages (from librosa) (1.0.8)
# Requirement already satisfied: packaging in /home/gustavo/.venv/green_bug/lib/python3.12/site-packages (from lazy-loader>=0.1->librosa) (24.0)
# Collecting llvmlite<0.43,>=0.42.0dev0 (from numba>=0.51.0->librosa)
#   Downloading llvmlite-0.42.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.8 kB)
# Requirement already satisfied: platformdirs>=2.5.0 in /home/gustavo/.venv/green_bug/lib/python3.12/site-packages (from pooch>=1.0->librosa) (4.2.1)
# Collecting requests>=2.19.0 (from pooch>=1.0->librosa)
#   Downloading requests-2.31.0-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/gustavo/.venv/green_bug/lib/python3.12/site-packages (from scikit-learn>=0.20.0->librosa) (3.4.0)
# Collecting cffi>=1.0 (from soundfile>=0.12.1->librosa)
#   Downloading cffi-1.16.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting pycparser (from cffi>=1.0->soundfile>=0.12.1->librosa)
#   Using cached pycparser-2.22-py3-none-any.whl.metadata (943 bytes)
# Collecting charset-normalizer<4,>=2 (from requests>=2.19.0->pooch>=1.0->librosa)
#   Downloading charset_normalizer-3.3.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (33 kB)
# Collecting idna<4,>=2.5 (from requests>=2.19.0->pooch>=1.0->librosa)
#   Downloading idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Collecting urllib3<3,>=1.21.1 (from requests>=2.19.0->pooch>=1.0->librosa)
#   Downloading urllib3-2.2.1-py3-none-any.whl.metadata (6.4 kB)
# Collecting certifi>=2017.4.17 (from requests>=2.19.0->pooch>=1.0->librosa)
#   Downloading certifi-2024.2.2-py3-none-any.whl.metadata (2.2 kB)
# Downloading librosa-0.10.1-py3-none-any.whl (253 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.7/253.7 kB 3.2 MB/s eta 0:00:00a 0:00:01
# Downloading audioread-3.0.1-py3-none-any.whl (23 kB)
# Downloading numba-0.59.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 18.9 MB/s eta 0:00:0000:0100:01
# Downloading pooch-1.8.1-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.0/63.0 kB 4.2 MB/s eta 0:00:00
# Downloading soundfile-0.12.1-py2.py3-none-manylinux_2_31_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 22.3 MB/s eta 0:00:00a 0:00:01
# Downloading soxr-0.3.7-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 21.9 MB/s eta 0:00:00a 0:00:01
# Downloading typing_extensions-4.11.0-py3-none-any.whl (34 kB)
# Downloading cffi-1.16.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (477 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 477.6/477.6 kB 16.0 MB/s eta 0:00:00
# Downloading llvmlite-0.42.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (43.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.8/43.8 MB 7.6 MB/s eta 0:00:00:00:0100:01
# Downloading requests-2.31.0-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.6/62.6 kB 396.0 kB/s eta 0:00:000:01
# Downloading certifi-2024.2.2-py3-none-any.whl (163 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.8/163.8 kB 14.6 MB/s eta 0:00:00
# Downloading charset_normalizer-3.3.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (141 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.9/141.9 kB 9.7 MB/s eta 0:00:00
# Downloading idna-3.7-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 4.7 MB/s eta 0:00:00
# Downloading urllib3-2.2.1-py3-none-any.whl (121 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.1/121.1 kB 12.9 MB/s eta 0:00:00
# Using cached pycparser-2.22-py3-none-any.whl (117 kB)
# Installing collected packages: urllib3, typing-extensions, soxr, pycparser, llvmlite, idna, charset-normalizer, certifi, audioread, requests, numba, cffi, soundfile, pooch, librosa
# Successfully installed audioread-3.0.1 certifi-2024.2.2 cffi-1.16.0 charset-normalizer-3.3.2 idna-3.7 librosa-0.10.1 llvmlite-0.42.0 numba-0.59.1 pooch-1.8.1 pycparser-2.22 requests-2.31.0 soundfile-0.12.1 soxr-0.3.7 typing-extensions-4.11.0 urllib3-2.2.1
# Collecting tqdm
#   Downloading tqdm-4.66.2-py3-none-any.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 890.1 kB/s eta 0:00:00a 0:00:01
# Downloading tqdm-4.66.2-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.3/78.3 kB 1.2 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: tqdm
# Successfully installed tqdm-4.66.2
# Collecting matplotlib
#   Downloading matplotlib-3.8.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.8 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.2.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.8 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.51.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (159 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 159.5/159.5 kB 2.6 MB/s eta 0:00:00a 0:00:01
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.5-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.4 kB)
# Requirement already satisfied: numpy>=1.21 in /home/gustavo/.venv/green_bug/lib/python3.12/site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /home/gustavo/.venv/green_bug/lib/python3.12/site-packages (from matplotlib) (24.0)
# Requirement already satisfied: pillow>=8 in /home/gustavo/.venv/green_bug/lib/python3.12/site-packages (from matplotlib) (10.3.0)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Downloading pyparsing-3.1.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /home/gustavo/.venv/green_bug/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/gustavo/.venv/green_bug/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Downloading matplotlib-3.8.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 26.2 MB/s eta 0:00:0000:0100:01
# Downloading contourpy-1.2.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (309 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.2/309.2 kB 20.1 MB/s eta 0:00:00
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.51.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 22.7 MB/s eta 0:00:0000:0100:01
# Downloading kiwisolver-1.4.5-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 19.6 MB/s eta 0:00:0000:01
# Downloading pyparsing-3.1.2-py3-none-any.whl (103 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.2/103.2 kB 11.5 MB/s eta 0:00:00
# Installing collected packages: pyparsing, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.2.1 cycler-0.12.1 fonttools-4.51.0 kiwisolver-1.4.5 matplotlib-3.8.4 pyparsing-3.1.2
# Collecting tensorflow
#   Downloading tensorflow-2.16.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.3 kB)
# Collecting absl-py>=1.0.0 (from tensorflow)
#   Downloading absl_py-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting astunparse>=1.6.0 (from tensorflow)
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting flatbuffers>=23.5.26 (from tensorflow)
#   Downloading flatbuffers-24.3.25-py2.py3-none-any.whl.metadata (850 bytes)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 (from tensorflow)
#   Downloading gast-0.5.4-py3-none-any.whl.metadata (1.3 kB)
# Collecting google-pasta>=0.1.1 (from tensorflow)
#   Downloading google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting h5py>=3.10.0 (from tensorflow)
#   Downloading h5py-3.11.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.5 kB)
# Collecting libclang>=13.0.0 (from tensorflow)
#   Downloading libclang-18.1.1-py2.py3-none-manylinux2010_x86_64.whl.metadata (5.2 kB)
# Collecting ml-dtypes~=0.3.1 (from tensorflow)
#   Downloading ml_dtypes-0.3.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Collecting opt-einsum>=2.3.2 (from tensorflow)
#   Downloading opt_einsum-3.3.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: packaging in /home/gustavo/.venv/green_bug/lib/python3.12/site-packages (from tensorflow) (24.0)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 (from tensorflow)
#   Downloading protobuf-4.25.3-cp37-abi3-manylinux2014_x86_64.whl.metadata (541 bytes)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/gustavo/.venv/green_bug/lib/python3.12/site-packages (from tensorflow) (2.31.0)
# Collecting setuptools (from tensorflow)
#   Using cached setuptools-69.5.1-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: six>=1.12.0 in /home/gustavo/.venv/green_bug/lib/python3.12/site-packages (from tensorflow) (1.16.0)
# Collecting termcolor>=1.1.0 (from tensorflow)
#   Downloading termcolor-2.4.0-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/gustavo/.venv/green_bug/lib/python3.12/site-packages (from tensorflow) (4.11.0)
# Collecting wrapt>=1.11.0 (from tensorflow)
#   Downloading wrapt-1.16.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow)
#   Downloading grpcio-1.62.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# Collecting tensorboard<2.17,>=2.16 (from tensorflow)
#   Downloading tensorboard-2.16.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting keras>=3.0.0 (from tensorflow)
#   Downloading keras-3.3.3-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: numpy<2.0.0,>=1.26.0 in /home/gustavo/.venv/green_bug/lib/python3.12/site-packages (from tensorflow) (1.26.4)
# Collecting wheel<1.0,>=0.23.0 (from astunparse>=1.6.0->tensorflow)
#   Using cached wheel-0.43.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting rich (from keras>=3.0.0->tensorflow)
#   Downloading rich-13.7.1-py3-none-any.whl.metadata (18 kB)
# Collecting namex (from keras>=3.0.0->tensorflow)
#   Downloading namex-0.0.8-py3-none-any.whl.metadata (246 bytes)
# Collecting optree (from keras>=3.0.0->tensorflow)
#   Downloading optree-0.11.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.4/45.4 kB 2.7 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/gustavo/.venv/green_bug/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/gustavo/.venv/green_bug/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/gustavo/.venv/green_bug/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/gustavo/.venv/green_bug/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (2024.2.2)
# Collecting markdown>=2.6.8 (from tensorboard<2.17,>=2.16->tensorflow)
#   Downloading Markdown-3.6-py3-none-any.whl.metadata (7.0 kB)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard<2.17,>=2.16->tensorflow)
#   Downloading tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard<2.17,>=2.16->tensorflow)
#   Downloading werkzeug-3.0.2-py3-none-any.whl.metadata (4.1 kB)
# Collecting MarkupSafe>=2.1.1 (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow)
#   Downloading MarkupSafe-2.1.5-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.0 kB)
# Collecting markdown-it-py>=2.2.0 (from rich->keras>=3.0.0->tensorflow)
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/gustavo/.venv/green_bug/lib/python3.12/site-packages (from rich->keras>=3.0.0->tensorflow) (2.17.2)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich->keras>=3.0.0->tensorflow)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Downloading tensorflow-2.16.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (589.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 589.9/589.9 MB 1.4 MB/s eta 0:00:00:00:0100:01
# Downloading absl_py-2.1.0-py3-none-any.whl (133 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.7/133.7 kB 9.1 MB/s eta 0:00:00
# Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Downloading flatbuffers-24.3.25-py2.py3-none-any.whl (26 kB)
# Downloading gast-0.5.4-py3-none-any.whl (19 kB)
# Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 1.1 MB/s eta 0:00:00ta 0:00:01
# Downloading grpcio-1.62.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 9.2 MB/s eta 0:00:00:00:0100:01
# Downloading h5py-3.11.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 12.4 MB/s eta 0:00:0000:0100:01
# Downloading keras-3.3.3-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 5.8 MB/s eta 0:00:00:00:0100:01
# Downloading libclang-18.1.1-py2.py3-none-manylinux2010_x86_64.whl (24.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.5/24.5 MB 10.1 MB/s eta 0:00:0000:0100:01
# Downloading ml_dtypes-0.3.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 9.2 MB/s eta 0:00:00:00:0100:01
# Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 4.4 MB/s eta 0:00:00
# Downloading protobuf-4.25.3-cp37-abi3-manylinux2014_x86_64.whl (294 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.6/294.6 kB 14.0 MB/s eta 0:00:00
# Downloading tensorboard-2.16.2-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 10.1 MB/s eta 0:00:0000:0100:01
# Using cached setuptools-69.5.1-py3-none-any.whl (894 kB)
# Downloading termcolor-2.4.0-py3-none-any.whl (7.7 kB)
# Downloading wrapt-1.16.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (87 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.3/87.3 kB 8.5 MB/s eta 0:00:00
# Downloading Markdown-3.6-py3-none-any.whl (105 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 kB 9.6 MB/s eta 0:00:00
# Downloading tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 17.5 MB/s eta 0:00:0000:0100:01
# Downloading werkzeug-3.0.2-py3-none-any.whl (226 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.8/226.8 kB 1.6 MB/s eta 0:00:00:00:01
# Using cached wheel-0.43.0-py3-none-any.whl (65 kB)
# Downloading namex-0.0.8-py3-none-any.whl (5.8 kB)
# Downloading optree-0.11.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (308 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 308.3/308.3 kB 1.2 MB/s eta 0:00:00:00:01
# Downloading rich-13.7.1-py3-none-any.whl (240 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.7/240.7 kB 4.6 MB/s eta 0:00:00:00:01
# Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.5/87.5 kB 5.9 MB/s eta 0:00:00
# Downloading MarkupSafe-2.1.5-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (28 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: namex, libclang, flatbuffers, wrapt, wheel, termcolor, tensorboard-data-server, setuptools, protobuf, optree, opt-einsum, ml-dtypes, mdurl, MarkupSafe, markdown, h5py, grpcio, google-pasta, gast, absl-py, werkzeug, markdown-it-py, astunparse, tensorboard, rich, keras, tensorflow
# Successfully installed MarkupSafe-2.1.5 absl-py-2.1.0 astunparse-1.6.3 flatbuffers-24.3.25 gast-0.5.4 google-pasta-0.2.0 grpcio-1.62.2 h5py-3.11.0 keras-3.3.3 libclang-18.1.1 markdown-3.6 markdown-it-py-3.0.0 mdurl-0.1.2 ml-dtypes-0.3.2 namex-0.0.8 opt-einsum-3.3.0 optree-0.11.0 protobuf-4.25.3 rich-13.7.1 setuptools-69.5.1 tensorboard-2.16.2 tensorboard-data-server-0.7.2 tensorflow-2.16.1 termcolor-2.4.0 werkzeug-3.0.2 wheel-0.43.0 wrapt-1.16.0

# %%
#ref: https://www.kaggle.com/code/msripooja/steps-to-convert-audio-clip-to-spectrogram
import os
import matplotlib.pyplot as plt
import numpy as np
import skimage.io as io
import librosa
import librosa.display
import pywt
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
from tqdm import tqdm
from keras.losses import CategoricalCrossentropy
from keras.optimizers import Adam
from keras.models import Sequential, load_model
from keras.layers import GRU, LSTM, Conv2D, MaxPooling2D, Dense, Conv1D, MaxPooling1D, Flatten, Dropout, Activation, TimeDistributed
from PIL import Image
#to play audio
import IPython.display as ipd

# %%
# Nesse caso você precisa ter no seu diretório uma pasta com o mesmo nome da variável base_dir
base_dir = "clean_audioset"
tipo_espectrograma = "dwt"
# E dentro da pasta audioset, você precisa de 3 pastas: carros, motocicletas e motosserras contendo os áudios
audio_carro_path = base_dir + "/carros/"
audio_moto_path = base_dir + "/motocicletas/"  # caminho onde estão os arquivos de audio
audio_serra_path = base_dir + "/motosserras/"

spec_base_path = base_dir + f"/{tipo_espectrograma}"
spec_carro_path = os.path.join(spec_base_path, "carros")
spec_moto_path = os.path.join(spec_base_path, "motocicletas")
spec_serra_path = os.path.join(spec_base_path, "motosserras")
 
os.makedirs(spec_base_path, exist_ok=True)
os.makedirs(spec_carro_path, exist_ok=True)
os.makedirs(spec_moto_path, exist_ok=True)
os.makedirs(spec_serra_path, exist_ok=True)

FILE_FORMAT = "png"
TAM_IMAGEM = 128

# %%
audio_carro_clips = sorted(os.listdir(audio_carro_path))[:50]
print(f"Número de arquivos .wav na pasta {audio_carro_path}= ",len(audio_carro_clips))

audio_moto_clips = sorted(os.listdir(audio_moto_path))[:50]
print(f"Número de arquivos .wav na pasta {audio_moto_path}= ",len(audio_moto_clips))

audio_serra_clips = sorted(os.listdir(audio_serra_path))[:50]
print(f"Número de arquivos .wav na pasta {audio_serra_path}= ",len(audio_serra_clips))
# Out:
# Número de arquivos .wav na pasta clean_audioset/carros/=  50
# Número de arquivos .wav na pasta clean_audioset/motocicletas/=  50
# Número de arquivos .wav na pasta clean_audioset/motosserras/=  50

# %%
#aqui está selecionando o primeiro arquivo da lista, pode ser feito um for para pegar todos de uma vez
#verificar esse sample rate
x_carro, sr_carro = librosa.load(audio_carro_path+audio_carro_clips[0]) 
x_moto, sr_moto = librosa.load(audio_moto_path+audio_moto_clips[4]) 
x_serra, sr_serra = librosa.load(audio_serra_path+audio_serra_clips[6]) 

print(type(x_carro), type(sr_carro))
print(x_carro.shape, sr_carro)

print(type(x_moto), type(sr_moto))
print(x_moto.shape, sr_moto)

print(type(x_serra), type(sr_serra))
print(x_serra.shape, sr_serra)
# Out:
# <class 'numpy.ndarray'> <class 'int'>
# (220676,) 22050
# <class 'numpy.ndarray'> <class 'int'>
# (114308,) 22050
# <class 'numpy.ndarray'> <class 'int'>
# (1323000,) 22050

# %% [markdown]
# # Salvar valores de espectrograma
#  - Pule esse passo se os arquivos já estiverem na pasta

# %%
##converter o audio para espectrograma:255
## é nesse amplitude_to_dB que ele está convertendo para pressão sonora. Podemos explorar outras ponderações aqui. Se não tiver implementado, podemos implementar.
def gerar_espectrograma(y, sr):

    # Tamanho do segmento (512 pontos)
    segment_length = 512
    num_segments = len(y) // segment_length  # Calcular o número de segmentos

    # Definir parâmetros para a Wavelet Packet Transform usando "haar"
    wavelet_level = 7  # Nível desejado de decomposição
    n_packets = 2 ** wavelet_level  # Número de pacotes para o nível 3

    # Criar um array para armazenar características para cada segmento
    # Dimensão desejada é 128 x 128
    features_wl = np.zeros((num_segments, n_packets))

    # Processar cada segmento do áudio
    for i in range(num_segments):
        # Extrair o segmento de áudio
        start_idx = i * segment_length  # Início do segmento
        end_idx = start_idx + segment_length  # Fim do segmento
        segment = y[start_idx:end_idx]  # Extrair o segmento do áudio

        # Aplicar a Wavelet Packet Transform
        wp = pywt.WaveletPacket(data=segment, wavelet="haar", maxlevel=wavelet_level)

        # Obter os nomes dos pacotes no nível desejado
        packet_names = [node.path for node in wp.get_level(wavelet_level, "natural")]

        # Calcular a energia para cada pacote
        for j in range(n_packets):
            packet = wp[packet_names[j]].data
            features_wl[i, j] = np.linalg.norm(packet) ** 2

        # Normalizar a energia total do segmento
        total_energy = np.sum(features_wl[i, :])
        features_wl[i, :] = features_wl[i, :] / (total_energy + 0.0000000001)

    # A saída é um array de dimensões 128 x 128
    #print("Array final com características normalizadas:")
    #print(features_wl)

    # Gerar uma imagem a partir da matriz 128 x 128
    features_wl = np.log(features_wl.T + 0.0000000001)
    return features_wl
    # features_wl_novo = (features_wl-features_wl.min()) / (features_wl.max()-features_wl.min())*255
    # plt.imshow(features_wl_novo, aspect='auto', cmap='viridis')  # Usar um mapa de cores
    # plt.colorbar()  # Adicionar uma barra de cores para escala
    # plt.title("Imagem da matriz 128 x 128")
    # plt.xlabel("Pacotes")
    # plt.ylabel("Segmentos")
    # return(plt.show())  # Mostrar a imagem


def cortar_espectrograma(spectrogram, largura_janela=TAM_IMAGEM, altura_janela=TAM_IMAGEM):
    altura_spec = spectrogram.shape[0]+1
    largura_spec = spectrogram.shape[1]
    spectrogram_slices = []

    print("Tamanho espectrograma:",spectrogram.shape )

    for h in range(altura_janela, altura_spec, altura_janela):
        for w in range(largura_janela, largura_spec, largura_janela):
            slice = spectrogram[h-altura_janela : h,   # largura
                                w-largura_janela : w,  # altura
                                np.newaxis]
            spectrogram_slices.append(slice)
            
    return spectrogram_slices

# %%
# Salvar espectrogramas na pasta específica (carros, serras etc)
def salvar_espectrogtramas (audio_clips, audio_path, spectrogram_path, audios_por_arquivo=50):
    numero_audios = len(audio_clips)
    num_arquivo = 1

    spectrogram_values = []
    
    for i, audio_name in enumerate(audio_clips):
        y, sr = librosa.load( os.path.join(audio_path, audio_name) )
        audio_name = audio_name.replace(".mp3", "")

        fullpath = os.path.join(spectrogram_path, audio_name)
        try:
            dwt_spec = gerar_espectrograma(y, sr)
            dwt_spec = 255 * (dwt_spec - dwt_spec.min()) / (dwt_spec.max() - dwt_spec.min())
            dwt_spec = np.flip(dwt_spec, axis=0) # put low frequencies at the bottom in image
            #fft_spec = 255 - fft_spec
            dwt_spec_slices = cortar_espectrograma(dwt_spec)
            
            # Salva o arquivo e começa o próximo
            for j in range(len(dwt_spec_slices)):
                full_filename = fullpath + f"_{j+1}.{FILE_FORMAT}"
                spec_save = dwt_spec_slices[j][:, :, 0]

                if FILE_FORMAT == "csv":
                    np.savetxt(full_filename, spec_save, delimiter=",")
                else:
                    im = Image.fromarray(spec_save).convert("L")
                    im.save(full_filename)

            print("Arquivo %s salvo com sucesso." % full_filename)
                
        except Exception as e:
            print( "Erro ao salvar %s: %s." % (fullpath, e) )


salvar_espectrogtramas(audio_carro_clips, audio_carro_path, spec_carro_path)

salvar_espectrogtramas(audio_moto_clips, audio_moto_path, spec_moto_path)

salvar_espectrogtramas(audio_serra_clips, audio_serra_path, spec_serra_path)
# Out:
# Tamanho espectrograma: (128, 431)
# Arquivo clean_audioset/dwt/carros/(HD) - Forza 4 - Top Gear - Car Test - 1990 Lotus Carlton-0GZbu00-aMY_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 430)
# Arquivo clean_audioset/dwt/carros/1968 Chevy Camaro - V8 327 - MUSCLECAR SOUND - restauriert-1ddvRm8MURI_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 430)
# Arquivo clean_audioset/dwt/carros/1995 Toyota Supra FOR SALE-2-1wY_Ndtgw_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 430)
# Arquivo clean_audioset/dwt/carros/2013 Porsche 911 Carrera Start Up and Review 3.4 L Horizontally Opposed⧸6 Cylinder-9BzZvj5W09s_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 387)
# Arquivo clean_audioset/dwt/carros/95 Mustang drag car start up-1sjKon7lrLY_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 430)
# Arquivo clean_audioset/dwt/carros/99 Trans Am WS6 - Donuts, Take-Offs, 110MPH!-G4Rp68qV_aw_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 387)
# Arquivo clean_audioset/dwt/carros/A guy trying to start car after flood-0TGPaUN2V5Q_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 431)
# Arquivo clean_audioset/dwt/carros/AX kit car-1-Vhr9Ut4Tg_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 399)
# Arquivo clean_audioset/dwt/carros/Atlanta GA： 1999 Jeep Grand Cherokee - Ignition Lock  Problem!-vsGv0Xf_hMI_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 430)
# Arquivo clean_audioset/dwt/carros/Audely End House and Gardens Stately House. Essex. England. English Heritage-1pKxZkeXe9w_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 430)
# Arquivo clean_audioset/dwt/carros/Audi 90 ISMA GTO und Audi 200 TransAm-B4l-0zH00nI_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 387)
# Arquivo clean_audioset/dwt/carros/BMW E46 M3 Drift Day in car-2ujlG9xd9NA_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 398)
# Arquivo clean_audioset/dwt/carros/Best car sounds in the world Part 14.--nlq9Dz4NIk_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 430)
# Arquivo clean_audioset/dwt/carros/Bold and Beautiful 1969 Camaro Muscle Car For Sale!-0hefQELmzq8_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 430)
# Arquivo clean_audioset/dwt/carros/Brisca F1 Stock Car Racing Swaffham 13⧸8⧸2000 Semi FWJ Wainman Speak Lund Harrison Pearce Willis--V2t-Yt1_-0_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 431)
# Arquivo clean_audioset/dwt/carros/CAMERA CAR FABIO CON PIT BIKE 125 cc CROSS 002.AVI-5MVE73rP6R8_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 430)
# Arquivo clean_audioset/dwt/carros/CAR ACCIDENT ON JERICHO TURNPIKE-2WoOCPOfgAo_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 430)
# Arquivo clean_audioset/dwt/carros/CWC Car Winter Cup - Záskalí 2006-0Ree10eqPN4_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 430)
# Arquivo clean_audioset/dwt/carros/Car 66 Adrian Barker Stages - Warts and All!--t3ETssuUYQ_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 225)
# Arquivo clean_audioset/dwt/carros/Car Crash Sound Effects-22QDZUi_oS0_1.png salvo com sucesso.
# Tamanho espectrograma: (128, 430)
# Arquivo clean_audioset/dwt/carros/Car Recycling in Russia 15.9.2012 ｜FMV｜-2sF7d4EYxsI_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 398)
# Arquivo clean_audioset/dwt/carros/Car sound imitations 3--vBVkcJCZ7M_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 207)
# Arquivo clean_audioset/dwt/carros/Circuit Of Ireland 2014 - Car 18--nyKu0ezRN8_1.png salvo com sucesso.
# Tamanho espectrograma: (128, 430)
# Arquivo clean_audioset/dwt/carros/City Car Driving 1.2.2 BMW M3 E36-6HMi-OYf0rI_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 431)
# Arquivo clean_audioset/dwt/carros/Conduite de prototype⧸Drive a race car--XH1WiOPLRs_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 430)
# Arquivo clean_audioset/dwt/carros/Custom 3 Car racing trailer (Toy Hauler) with tractor with sleeping Quarters for sale-3Mif39PORh8_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 431)
# Arquivo clean_audioset/dwt/carros/Dead Rising： white car in the maitinence tunnel-2IDAWvi5alA_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 430)
# Arquivo clean_audioset/dwt/carros/Dodge Cummins Rollin Coal!!-AiQoXi32QIA_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 425)
# Arquivo clean_audioset/dwt/carros/Elnef Racing in new car from US 2010-3NBAnKg3YKU_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 431)
# Arquivo clean_audioset/dwt/carros/Exhaust System Noise, Sounds like a Jet, bad catalytic converter？--K4R9SXZZsk_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 430)
# Arquivo clean_audioset/dwt/carros/Fast Motorsports Catback '09 WRX sound clip in car-6QLZfL4SnR8_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 431)
# Arquivo clean_audioset/dwt/carros/First ever Uber  car in Paris!---zLzL0sq3M_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 430)
# Arquivo clean_audioset/dwt/carros/Fun car 7 Août 2011 St Christophe sur Guiers part.2-1N6OZ71Lvs0_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 430)
# Arquivo clean_audioset/dwt/carros/GT4- Spoon Race car @ Citta Di Aria 1'25.568--whHfyc3-ds_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 387)
# Arquivo clean_audioset/dwt/carros/GT40 Kit Car Test Drive-13_qekhjE4U_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 430)
# Arquivo clean_audioset/dwt/carros/GTA 5 CAR MEETUP MP#3-1pAuLvy2K7o_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 430)
# Arquivo clean_audioset/dwt/carros/GTA Car Repo Gone Wrong-1wU63KRlATQ_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 423)
# Arquivo clean_audioset/dwt/carros/GTA IV Hit by my own car-0zwkWRoTW7k_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 430)
# Arquivo clean_audioset/dwt/carros/GTR2： Spa 2008 Track in BMW Sauber F1 Car-1M_NPbRFjq8_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 430)
# Arquivo clean_audioset/dwt/carros/Galatea Automobiles LLC Hyundai Tiburon Kit Car Body-3K-5ZZXUOO4_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 418)
# Arquivo clean_audioset/dwt/carros/HONDA EK9 CIVIC VS DC5 INTEGRA ROLLING .RACE ⧸ CAMERA CAR EP3 CIVIC ⧸ NORTH CYPRUS MPG-2fVi79vgrUo_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 350)
# Arquivo clean_audioset/dwt/carros/Hitchcock 39 Steps Car scene-3HiB7lqcJro_2.png salvo com sucesso.
# Tamanho espectrograma: (128, 430)
# Arquivo clean_audioset/dwt/carros/How NOT to drive a race car - Masterly demonstrated by Mr. Tommy Jagerwall-2weLpzs8h1o_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 431)
# Arquivo clean_audioset/dwt/carros/How to sell your car gangstar vegas-2GOGdPSUAzg_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 430)
# Arquivo clean_audioset/dwt/carros/IMCA Stock Car feature Boone Speedway 4⧸25⧸15-1Xt-GC4q1XI_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 430)
# Arquivo clean_audioset/dwt/carros/In Car Footage of My Ride Along with Rob Primo-0t99Q6XnOPg_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 430)
# Arquivo clean_audioset/dwt/carros/Insane golf car stunt-338ZA2jtFC4_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 302)
# Arquivo clean_audioset/dwt/carros/Japanese girl cranking Renault 5 in black mary janes flats-c31HkFqWLAk_2.png salvo com sucesso.
# Tamanho espectrograma: (128, 430)
# Arquivo clean_audioset/dwt/carros/Kabul - Islamic Republic of Afghanistan - October 2011-5P3aq2BJYa0_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 345)
# Arquivo clean_audioset/dwt/carros/LCPDFR 0.95  IN POLICE CAR RADIO SOUNDS IN GTA IV--8ZU97ub6l8_2.png salvo com sucesso.
# Tamanho espectrograma: (128, 430)
# Arquivo clean_audioset/dwt/motocicletas/100% attention, 100% of the time - Danger around the bends-49H9cty2Nfk_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 430)
# Arquivo clean_audioset/dwt/motocicletas/1978 Suzuki DS 185 Demo, 7 May 15-5BgJKx7Kkwc_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 430)
# Arquivo clean_audioset/dwt/motocicletas/2001 Kawasaki Ninja ZX6R - For Sale - Newton Motorcars-2QqLKkqEg44_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 430)
# Arquivo clean_audioset/dwt/motocicletas/2003 Yamaha R6 Special Edition (ON SALE!!!) $4,999-7BUhuRCSRgc_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 223)
# Arquivo clean_audioset/dwt/motocicletas/2007 Yamaha V-Star 1100 Silverado Classic-8b0tC2eLNOk_1.png salvo com sucesso.
# Tamanho espectrograma: (128, 430)
# Arquivo clean_audioset/dwt/motocicletas/2008 Yamaha V-star 1100 Custom Hard-Krome Big Straights-7-bG394pYps_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 430)
# Arquivo clean_audioset/dwt/motocicletas/2008 zx10r dyno run--7gC66Xp1iY_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 430)
# Arquivo clean_audioset/dwt/motocicletas/2010 Ducati Streetfighter s-1PV6TCRQTok_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 431)
# Arquivo clean_audioset/dwt/motocicletas/2011⧸2012 QIRRCH Round 7 Highlights 26-5wpmjCOnunA_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 430)
# Arquivo clean_audioset/dwt/motocicletas/2014 Arctic Cat ZR7000 LXR - Yamaha engine sound-7qZqAraRFco_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 430)
# Arquivo clean_audioset/dwt/motocicletas/2014 Beta 450 RR Motorcycle Walk Around, 3 Seas Recreation, American Beta Motorcycle-8At-88WYYe8_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 430)
# Arquivo clean_audioset/dwt/motocicletas/2014 Kawasaki Z1000 dyno run-05Z4emmS7IE_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 430)
# Arquivo clean_audioset/dwt/motocicletas/400ex 460 stroker.-4V8UeW_t_U8_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 430)
# Arquivo clean_audioset/dwt/motocicletas/ARDIE RBU 350 erster Probelauf ⧸ vintage motorcycle first run-6kofP5LGVoU_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 431)
# Arquivo clean_audioset/dwt/motocicletas/Alpha Sport Cobra 180RS Quad-7Ybm8eUMEww_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 430)
# Arquivo clean_audioset/dwt/motocicletas/Around the block on Mike's `49 HRD Vincent, Black Shadow-3edhLN5jwvU_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 430)
# Arquivo clean_audioset/dwt/motocicletas/Backyard Pitbike Session Part 1-43FtdwYnMjA_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 431)
# Arquivo clean_audioset/dwt/motocicletas/Bean're interviewing spectators when a fire broke out on the Cannonball Motorcycle Rally-2p9WJ6wdHR8_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 430)
# Arquivo clean_audioset/dwt/motocicletas/Big pit pro 125cc RR-3vPuVLFnSX4_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 339)
# Arquivo clean_audioset/dwt/motocicletas/Booster 70 Dr On Board  Test Drive  Sound Arrow extreme HD-0p68pGdkUnE_2.png salvo com sucesso.
# Tamanho espectrograma: (128, 430)
# Arquivo clean_audioset/dwt/motocicletas/CBR 125 Bike RIde-0BGmq-cu28w_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 430)
# Arquivo clean_audioset/dwt/motocicletas/CRF 450X Flaming Two Brothers Exhaust-22SLpBN31R0_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 399)
# Arquivo clean_audioset/dwt/motocicletas/Can Am MX500 -1985--3-t7Sm6un0_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 430)
# Arquivo clean_audioset/dwt/motocicletas/Classic motorcycle and car meeting in Nessebar, Bulgaria--pdljKJHPgg_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 430)
# Arquivo clean_audioset/dwt/motocicletas/Cleveland Cyclewerks tha Heist Updated Widow Kick started to life-8W2jnBkwMF0_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 430)
# Arquivo clean_audioset/dwt/motocicletas/Comine 19⧸03⧸16 KTM électrique-5gDn97zTkKs_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 430)
# Arquivo clean_audioset/dwt/motocicletas/Como tirar o filtro de ar da pop-9h1qTbIOiDs_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 387)
# Arquivo clean_audioset/dwt/motocicletas/Crazy Dog on Motorcycle-6RZA3VBca6Q_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 431)
# Arquivo clean_audioset/dwt/motocicletas/Crazy Mad Man Cycling Too Fast - Rides it like he stole it!---p-rk_HBuU_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 430)
# Arquivo clean_audioset/dwt/motocicletas/Credit loans insured motorcycle traffic car part 3.1-2FjwjCaIvo4_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 430)
# Arquivo clean_audioset/dwt/motocicletas/Crocodile tries to eat lawnmower-5CQU7-RISwA_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 383)
# Arquivo clean_audioset/dwt/motocicletas/DRZ Wheelie Practice and Wheelie Vlog-66j22lKCjQc_2.png salvo com sucesso.
# Tamanho espectrograma: (128, 430)
# Arquivo clean_audioset/dwt/motocicletas/Daves MTX 125 - Fix and Test.-25Q3ZhL4me8_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 430)
# Arquivo clean_audioset/dwt/motocicletas/Derbi Antorcha funcionando.-6-mlwMzZ2Ow_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 430)
# Arquivo clean_audioset/dwt/motocicletas/Ducati 848 akrapovic cold start-1ZzPc9NkJsg_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 430)
# Arquivo clean_audioset/dwt/motocicletas/ENA DUGMA APO THN BOLTA TON STREET THUGS..!!-1e2uAdWaMBk_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 430)
# Arquivo clean_audioset/dwt/motocicletas/Flash Flood High Desert California 7⧸19⧸2015 - Shadrach Max-2cx1ZH-uolA_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 430)
# Arquivo clean_audioset/dwt/motocicletas/GPZ turbo rattle-2eG8jc_R46E_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 430)
# Arquivo clean_audioset/dwt/motocicletas/Ghostrider vs baddog and walt and hitman vs jb--QDkHHg5U2s_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 430)
# Arquivo clean_audioset/dwt/motocicletas/Group Ride： 4 Ducati, 2 Yamaha. 1 Kawasaki, 1 Suzuki, 1 Cagiva, 1 Bmw-4tRlgk--1ro_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 431)
# Arquivo clean_audioset/dwt/motocicletas/Großer Preis von Deutschland für Motorräder 1966 - Hockenheim-3UPGjswFukU_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 430)
# Arquivo clean_audioset/dwt/motocicletas/Guy Martin Big brew @ J&S Leicester 2014 - FZ8 Dyno run-9kSBEpCCnZQ_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 431)
# Arquivo clean_audioset/dwt/motocicletas/Gymineer - Dirtbiking-5Kx-mPqbvMU_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 430)
# Arquivo clean_audioset/dwt/motocicletas/HONDA CBF 600S Dominator exhaust-4gmq40xxXYA_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 430)
# Arquivo clean_audioset/dwt/motocicletas/HONDA CBF500 & SUZUKI GS500 & KAWASAKI ZX6R-6iOyPTnANbw_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 430)
# Arquivo clean_audioset/dwt/motocicletas/Hayling Island Scooter Rally Rideout 2014-8IBW3vNa0Ao_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 430)
# Arquivo clean_audioset/dwt/motocicletas/Honda ATC 70 r55 Suspension Kit-7OrTMrrIO9s_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 430)
# Arquivo clean_audioset/dwt/motocicletas/Honda TRX400ex HMF exhaust sound test-0axKgORkskQ_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 430)
# Arquivo clean_audioset/dwt/motocicletas/Honda VT1300CS Sabre 2010   COBRA Speedster Swept exhaust 2)--wfzJ1-A5Lc_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 430)
# Arquivo clean_audioset/dwt/motocicletas/Honda Valkyrie first engine start for season 2016 - pure sound-6N2spJt3rJA_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 430)
# Arquivo clean_audioset/dwt/motosserras/1996 mcculloch mac 3200 chainsaw-ir3ipI5k1kI_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 2583)
# Arquivo clean_audioset/dwt/motosserras/2024-04-13-greenbug-15_05_ (1).wav_20.png salvo com sucesso.
# Tamanho espectrograma: (128, 2583)
# Arquivo clean_audioset/dwt/motosserras/2024-04-13-greenbug-15_05_ (10).wav_20.png salvo com sucesso.
# Tamanho espectrograma: (128, 1582)
# Arquivo clean_audioset/dwt/motosserras/2024-04-13-greenbug-15_05_ (2).wav_12.png salvo com sucesso.
# Tamanho espectrograma: (128, 2583)
# Arquivo clean_audioset/dwt/motosserras/2024-04-13-greenbug-15_05_ (3).wav_20.png salvo com sucesso.
# Tamanho espectrograma: (128, 2583)
# Arquivo clean_audioset/dwt/motosserras/2024-04-13-greenbug-15_05_ (4).wav_20.png salvo com sucesso.
# Tamanho espectrograma: (128, 2583)
# Arquivo clean_audioset/dwt/motosserras/2024-04-13-greenbug-15_05_ (6).wav_20.png salvo com sucesso.
# Tamanho espectrograma: (128, 2583)
# Arquivo clean_audioset/dwt/motosserras/2024-04-13-greenbug-15_05_ (7).wav_20.png salvo com sucesso.
# Tamanho espectrograma: (128, 2583)
# Arquivo clean_audioset/dwt/motosserras/2024-04-13-greenbug-15_05_ (8).wav_20.png salvo com sucesso.
# Tamanho espectrograma: (128, 430)
# Arquivo clean_audioset/dwt/motosserras/Abattage chandelle liquidambart vs ms 660 guide de 55-Nszf2gBWruU_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 430)
# Arquivo clean_audioset/dwt/motosserras/Alaskan saw mill-Jci_knX9g1I_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 430)
# Arquivo clean_audioset/dwt/motosserras/Beezone бензопила М.mpg-Y4JfR36zPi4_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 431)
# Arquivo clean_audioset/dwt/motosserras/Brian cutting down our mostly dead birch tree.m4v-mnfToxaQAgc_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 430)
# Arquivo clean_audioset/dwt/motosserras/Bucherons2015-aqhELp8-o_c_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 430)
# Arquivo clean_audioset/dwt/motosserras/Burnett Model B6 Chainsaw 125cc Villiers engine-Apudgyyvhvs_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 430)
# Arquivo clean_audioset/dwt/motosserras/Caribou Creek Handcrafted Log Home -- 1775 LH -- Anaya -- YD -- 072909 -- 5 Arch part 3-Qb0LUJzJf64_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 430)
# Arquivo clean_audioset/dwt/motosserras/Chainsaw Husqvarna 560 XP-WHzUPzWkST0_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 430)
# Arquivo clean_audioset/dwt/motosserras/Chainsaw faceting with Aaron Hammer： Making circles with a chainsaw-pWRMgo0BGhU_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 430)
# Arquivo clean_audioset/dwt/motosserras/Cuesta la pared Coamo 2-nkOXb95N0LU_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 431)
# Arquivo clean_audioset/dwt/motosserras/DSCN2587.MOV Jonsered 370 chainsaw-4j2KuWhT_Ss_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 286)
# Arquivo clean_audioset/dwt/motosserras/Dolmar 7900 + ＂Wojo＂-muffler--XVu2GZypIY_2.png salvo com sucesso.
# Tamanho espectrograma: (128, 430)
# Arquivo clean_audioset/dwt/motosserras/Dolpima BK3A Polnische Oldtimer Motorsäge-Hj5EYl2b91Q_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 430)
# Arquivo clean_audioset/dwt/motosserras/Echo Timberwolf CS590 review-HNhLJa-cU-Y_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 431)
# Arquivo clean_audioset/dwt/motosserras/FSI Baumstumpffräse Avant 528+-MfiszhvwDzI_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 430)
# Arquivo clean_audioset/dwt/motosserras/Felling a Tree Bigger than Your Chainsaw-axr1fuHMcmA_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 430)
# Arquivo clean_audioset/dwt/motosserras/Ford F150 Ecoboost Torture Test： HaulingTimber shot on the 5D MK II with Zeiss CP.2 compact primes-xQh4jY4n5_g_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 430)
# Arquivo clean_audioset/dwt/motosserras/Handmade Chainsaw Base-5a_LPLNtBQs_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 430)
# Arquivo clean_audioset/dwt/motosserras/Hepsiparis.Com - Oleo-Mac 952 Motorlu Testere-6-DAiSEzRA4_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 431)
# Arquivo clean_audioset/dwt/motosserras/Hoss's 990g-rhGSqHtz_C4_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 430)
# Arquivo clean_audioset/dwt/motosserras/Husqvarna 346xpg - Gopro HD-FGJQ3KC-Geo_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 430)
# Arquivo clean_audioset/dwt/motosserras/Husqvarna 536 li XP-LXkUfPG3jKo_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 431)
# Arquivo clean_audioset/dwt/motosserras/Husqvarna Longest Bar-zhFcXNK076k_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 387)
# Arquivo clean_audioset/dwt/motosserras/Husqvarna NE346XP-BpBBVyd28e8_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 430)
# Arquivo clean_audioset/dwt/motosserras/I need a new chainsaw-DZeyWdZ7yxw_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 430)
# Arquivo clean_audioset/dwt/motosserras/Jonsered 2153 Vs Tölgy-_if557QC-zE_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 430)
# Arquivo clean_audioset/dwt/motosserras/Jonsered Cs 2153 chainsaw-2XVl8t1-XOM_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 430)
# Arquivo clean_audioset/dwt/motosserras/Linnunpönttö kelopuusta-TeDqdC16Wn0_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 430)
# Arquivo clean_audioset/dwt/motosserras/Little Hot Saw-24ywlO1l1mE_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 430)
# Arquivo clean_audioset/dwt/motosserras/MALL 2 man comes to life-t2pD_W3k-Ak_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 430)
# Arquivo clean_audioset/dwt/motosserras/MS150TC After Ignition Timing Advance-jSCzPxHOfRI_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 357)
# Arquivo clean_audioset/dwt/motosserras/Mann fährt mit Motorsäge auf Eis-pFo39HyyuYQ_2.png salvo com sucesso.
# Tamanho espectrograma: (128, 430)
# Arquivo clean_audioset/dwt/motosserras/McCULLOCH RACING ENGINE CONVERTED FROM CHAINSAW MOTOR-SGdSYIOgeSg_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 329)
# Arquivo clean_audioset/dwt/motosserras/McCulloch 35cc chain saw-1B6kKOARYBo_2.png salvo com sucesso.
# Tamanho espectrograma: (128, 431)
# Arquivo clean_audioset/dwt/motosserras/McCulloch Pro Mac 610 60cc (3.7CI)-ez3rWlm8AcM_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 419)
# Arquivo clean_audioset/dwt/motosserras/McCulloch saw motor conversion for go kart-nhtNK6LhBkg_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 430)
# Arquivo clean_audioset/dwt/motosserras/Modified Mini ATV 110cc SEMI Selfmade ATV Quad Custom-9D32xsXlQeQ_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 430)
# Arquivo clean_audioset/dwt/motosserras/Motorka MKS 35⧸35 Royal--eEZX4WFrcI_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 430)
# Arquivo clean_audioset/dwt/motosserras/My first attempt at chainsaw carving.-aJb09Ttp69Q_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 430)
# Arquivo clean_audioset/dwt/motosserras/New Toys - Lawn Mower, Leaf Blower, Chainsaw #3-zICNzWYJQ2o_3.png salvo com sucesso.
# Tamanho espectrograma: (128, 430)
# Arquivo clean_audioset/dwt/motosserras/Open face cut-XJSRthb6Fsw_3.png salvo com sucesso.

# %% [markdown]
# # Treinamento e teste de rede neural

# %%
# Carregar espectrogramas com uma CNN e classificar entre "motosserras e não motosserras"

espectrogramas_carro = sorted(os.listdir(spec_carro_path))
espectrogramas_moto = sorted(os.listdir(spec_moto_path))
espectrogramas_serra = sorted(os.listdir(spec_serra_path))

spectrogram_list = []
labels = []

def carregar_espectrograma(full_filename):
    if FILE_FORMAT == "png":
        return np.asarray(Image.open(full_filename))
    else:
        return np.loadtxt(full_filename, delimiter=",")


def adicionar_rotulos_spec(espectrogramas, spec_path, label):
    for filename in espectrogramas:
        full_filename = os.path.join(spec_path, filename)  

        spectrogram = carregar_espectrograma(full_filename)
        spectrogram_list.append(spectrogram)
        # 0 corresponde aos carros e motos
        labels.append(label)


adicionar_rotulos_spec(espectrogramas_carro, spec_carro_path, 0)
adicionar_rotulos_spec(espectrogramas_moto, spec_moto_path, 0)
adicionar_rotulos_spec(espectrogramas_serra, spec_serra_path, 1)


print("Número de espectrogramas carros: ", len(espectrogramas_carro))
print("Número de espectrogramas motos: ", len(espectrogramas_moto))
print("Número de espectrogramas motosserras: ", len(espectrogramas_serra))


spectrogram_np = np.array(spectrogram_list) / 255

spectrogram_np = spectrogram_np.reshape(
    (spectrogram_np.shape[0], spectrogram_np.shape[1], spectrogram_np.shape[2], 1)
)

labels_np = np.array(labels)

X_train, X_test, y_train, y_test = train_test_split(
    spectrogram_np, labels_np, test_size=0.05  # , random_state=42
)

print("Amostras treinamento:", len(X_train))
print("Amostras teste:", len(X_test))
# Out:
# Número de espectrogramas carros:  143
# Número de espectrogramas motos:  146
# Número de espectrogramas motosserras:  275
# Amostras treinamento: 535
# Amostras teste: 29

# %%
## Initialize the model
#model = Sequential()
#
## Add convolutional layers
#model.add(Conv2D(32, (3, 3), input_shape=X_train[0].shape))
#model.add(Activation('relu'))
#model.add(MaxPooling2D(pool_size=(2, 2)))
#
#model.add(Conv2D(64, (3, 3)))
#model.add(Activation('relu'))
#model.add(MaxPooling2D(pool_size=(2, 2)))
#
#model.add(Conv2D(128, (3, 3)))
#model.add(Activation('relu'))
#model.add(MaxPooling2D(pool_size=(2, 2)))
#
## Flatten the output before fully connected layers
#model.add(Flatten())
#
## Fully connected layer with dropout
#model.add(Dense(256))
#model.add(Activation('relu'))
#model.add(Dropout(0.5))
#
## Output layer with softmax activation
#model.add(Dense(1, activation='sigmoid')) # Binary classification
#
## Compile the model
#model.compile(loss='binary_crossentropy',
#              optimizer='adam',
#              metrics=['accuracy'])
## Print model summaryImage.open
#model.summary()
#model.fit(X_train, y_train, epochs=100, validation_split=0.2, batch_size=32)
#
#model.save(f"checkpoints/{tipo_espectrograma}.keras")


model = Sequential()

model.add(Conv2D(16, 3, activation='relu', use_bias=True, bias_initializer='zeros', input_shape=X_train[0].shape))
model.add(MaxPooling2D())
model.add(Conv2D(32, 3, activation='relu', use_bias=True, bias_initializer='zeros'))
model.add(MaxPooling2D())
model.add(Conv2D(64, 3, activation='relu', use_bias=True, bias_initializer='zeros'))
model.add(MaxPooling2D())
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.25))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.25))
model.add(Dense(1, activation='sigmoid')) # Binary classification
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
# Print model summaryImage.open
model.summary()
model.fit(X_train, y_train, epochs=100, validation_split=0.2, batch_size=16)

model.save(f"checkpoints/{tipo_espectrograma}.keras")
# Out:
# /home/gustavo/.venv/green_bug/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_9"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_25 (Conv2D)              │ (None, 126, 126, 16)   │           160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_24 (MaxPooling2D) │ (None, 63, 63, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_26 (Conv2D)              │ (None, 61, 61, 32)     │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_25 (MaxPooling2D) │ (None, 30, 30, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_27 (Conv2D)              │ (None, 28, 28, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_26 (MaxPooling2D) │ (None, 14, 14, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_8 (Flatten)             │ (None, 12544)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_23 (Dense)                │ (None, 128)            │     1,605,760 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_15 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_24 (Dense)                │ (None, 256)            │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_16 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_25 (Dense)                │ (None, 1)              │           257 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,662,337 (6.34 MB)
#  Trainable params: 1,662,337 (6.34 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 13s 325ms/step - accuracy: 0.4522 - loss: 0.7254 - val_accuracy: 0.4673 - val_loss: 0.6932
# Epoch 2/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 12s 383ms/step - accuracy: 0.5127 - loss: 0.6953 - val_accuracy: 0.4673 - val_loss: 0.6949
# Epoch 3/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 16s 212ms/step - accuracy: 0.4838 - loss: 0.6939 - val_accuracy: 0.5327 - val_loss: 0.6925
# Epoch 4/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 188ms/step - accuracy: 0.5088 - loss: 0.6935 - val_accuracy: 0.4673 - val_loss: 0.6929
# Epoch 5/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 6s 218ms/step - accuracy: 0.5142 - loss: 0.6925 - val_accuracy: 0.5794 - val_loss: 0.6920
# Epoch 6/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 215ms/step - accuracy: 0.5258 - loss: 0.6926 - val_accuracy: 0.5327 - val_loss: 0.6909
# Epoch 7/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 200ms/step - accuracy: 0.4867 - loss: 0.6938 - val_accuracy: 0.5327 - val_loss: 0.6915
# Epoch 8/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 193ms/step - accuracy: 0.4899 - loss: 0.6942 - val_accuracy: 0.5514 - val_loss: 0.6927
# Epoch 9/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 201ms/step - accuracy: 0.4971 - loss: 0.6928 - val_accuracy: 0.5140 - val_loss: 0.6919
# Epoch 10/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 9s 163ms/step - accuracy: 0.4996 - loss: 0.6925 - val_accuracy: 0.4673 - val_loss: 0.7089
# Epoch 11/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 202ms/step - accuracy: 0.4718 - loss: 0.7004 - val_accuracy: 0.4766 - val_loss: 0.6928
# Epoch 12/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 6s 208ms/step - accuracy: 0.5730 - loss: 0.6893 - val_accuracy: 0.5327 - val_loss: 0.6978
# Epoch 13/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 185ms/step - accuracy: 0.4785 - loss: 0.6992 - val_accuracy: 0.5327 - val_loss: 0.6922
# Epoch 14/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 196ms/step - accuracy: 0.5475 - loss: 0.6891 - val_accuracy: 0.4860 - val_loss: 0.6914
# Epoch 15/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 162ms/step - accuracy: 0.5538 - loss: 0.6910 - val_accuracy: 0.7009 - val_loss: 0.6814
# Epoch 16/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 196ms/step - accuracy: 0.5936 - loss: 0.6867 - val_accuracy: 0.4673 - val_loss: 0.7045
# Epoch 17/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 6s 205ms/step - accuracy: 0.5206 - loss: 0.6909 - val_accuracy: 0.5981 - val_loss: 0.6750
# Epoch 18/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 191ms/step - accuracy: 0.5654 - loss: 0.6766 - val_accuracy: 0.6636 - val_loss: 0.6627
# Epoch 19/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 169ms/step - accuracy: 0.5703 - loss: 0.6828 - val_accuracy: 0.6262 - val_loss: 0.6279
# Epoch 20/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 189ms/step - accuracy: 0.6480 - loss: 0.6376 - val_accuracy: 0.6542 - val_loss: 0.6031
# Epoch 21/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 6s 204ms/step - accuracy: 0.6759 - loss: 0.6098 - val_accuracy: 0.6636 - val_loss: 0.5970
# Epoch 22/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 198ms/step - accuracy: 0.7773 - loss: 0.5110 - val_accuracy: 0.4860 - val_loss: 0.6869
# Epoch 23/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 9s 164ms/step - accuracy: 0.5439 - loss: 0.6768 - val_accuracy: 0.5047 - val_loss: 0.6792
# Epoch 24/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 195ms/step - accuracy: 0.5712 - loss: 0.6817 - val_accuracy: 0.6262 - val_loss: 0.6605
# Epoch 25/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 179ms/step - accuracy: 0.6045 - loss: 0.6490 - val_accuracy: 0.5794 - val_loss: 0.6784
# Epoch 26/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 197ms/step - accuracy: 0.6526 - loss: 0.6413 - val_accuracy: 0.6636 - val_loss: 0.6241
# Epoch 27/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 202ms/step - accuracy: 0.5489 - loss: 0.6860 - val_accuracy: 0.5607 - val_loss: 0.6726
# Epoch 28/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 6s 229ms/step - accuracy: 0.5911 - loss: 0.6587 - val_accuracy: 0.6449 - val_loss: 0.6623
# Epoch 29/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 9s 177ms/step - accuracy: 0.6393 - loss: 0.6240 - val_accuracy: 0.6449 - val_loss: 0.6182
# Epoch 30/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 188ms/step - accuracy: 0.7168 - loss: 0.5630 - val_accuracy: 0.7009 - val_loss: 0.5621
# Epoch 31/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 198ms/step - accuracy: 0.7137 - loss: 0.5409 - val_accuracy: 0.7196 - val_loss: 0.5778
# Epoch 32/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 193ms/step - accuracy: 0.7624 - loss: 0.4670 - val_accuracy: 0.6542 - val_loss: 0.6432
# Epoch 33/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 174ms/step - accuracy: 0.7223 - loss: 0.5815 - val_accuracy: 0.7196 - val_loss: 0.5657
# Epoch 34/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 195ms/step - accuracy: 0.7829 - loss: 0.4740 - val_accuracy: 0.7009 - val_loss: 0.6186
# Epoch 35/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 185ms/step - accuracy: 0.7890 - loss: 0.4254 - val_accuracy: 0.6729 - val_loss: 0.7109
# Epoch 36/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 196ms/step - accuracy: 0.7904 - loss: 0.4429 - val_accuracy: 0.7009 - val_loss: 0.7128
# Epoch 37/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 195ms/step - accuracy: 0.8203 - loss: 0.3727 - val_accuracy: 0.7196 - val_loss: 0.7694
# Epoch 38/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 201ms/step - accuracy: 0.7763 - loss: 0.4259 - val_accuracy: 0.6916 - val_loss: 0.6363
# Epoch 39/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 196ms/step - accuracy: 0.8265 - loss: 0.3846 - val_accuracy: 0.6822 - val_loss: 0.7500
# Epoch 40/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 194ms/step - accuracy: 0.8132 - loss: 0.3742 - val_accuracy: 0.6729 - val_loss: 0.7518
# Epoch 41/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 200ms/step - accuracy: 0.8592 - loss: 0.3170 - val_accuracy: 0.6729 - val_loss: 0.7882
# Epoch 42/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 189ms/step - accuracy: 0.8598 - loss: 0.2966 - val_accuracy: 0.6822 - val_loss: 0.8622
# Epoch 43/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 188ms/step - accuracy: 0.8614 - loss: 0.3128 - val_accuracy: 0.7009 - val_loss: 0.7431
# Epoch 44/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 6s 200ms/step - accuracy: 0.8501 - loss: 0.2927 - val_accuracy: 0.7103 - val_loss: 1.2567
# Epoch 45/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 6s 208ms/step - accuracy: 0.8391 - loss: 0.3329 - val_accuracy: 0.6729 - val_loss: 1.0094
# Epoch 46/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 198ms/step - accuracy: 0.8783 - loss: 0.2712 - val_accuracy: 0.6916 - val_loss: 1.0820
# Epoch 47/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 192ms/step - accuracy: 0.8509 - loss: 0.2533 - val_accuracy: 0.6729 - val_loss: 1.1032
# Epoch 48/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 204ms/step - accuracy: 0.8993 - loss: 0.2258 - val_accuracy: 0.6636 - val_loss: 1.1811
# Epoch 49/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 203ms/step - accuracy: 0.8782 - loss: 0.2331 - val_accuracy: 0.6729 - val_loss: 1.0529
# Epoch 50/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 187ms/step - accuracy: 0.8828 - loss: 0.2537 - val_accuracy: 0.6822 - val_loss: 1.0787
# Epoch 51/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 190ms/step - accuracy: 0.8849 - loss: 0.2348 - val_accuracy: 0.6729 - val_loss: 1.0601
# Epoch 52/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 164ms/step - accuracy: 0.8951 - loss: 0.2277 - val_accuracy: 0.6916 - val_loss: 1.3968
# Epoch 53/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 193ms/step - accuracy: 0.9168 - loss: 0.1972 - val_accuracy: 0.7103 - val_loss: 1.1400
# Epoch 54/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 6s 207ms/step - accuracy: 0.9025 - loss: 0.2107 - val_accuracy: 0.7196 - val_loss: 1.2343
# Epoch 55/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 196ms/step - accuracy: 0.8912 - loss: 0.2551 - val_accuracy: 0.6822 - val_loss: 1.3920
# Epoch 56/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 199ms/step - accuracy: 0.9085 - loss: 0.2324 - val_accuracy: 0.7009 - val_loss: 1.2289
# Epoch 57/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 197ms/step - accuracy: 0.9200 - loss: 0.1963 - val_accuracy: 0.7009 - val_loss: 1.3763
# Epoch 58/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 176ms/step - accuracy: 0.9070 - loss: 0.2007 - val_accuracy: 0.6822 - val_loss: 1.6464
# Epoch 59/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 195ms/step - accuracy: 0.9136 - loss: 0.1850 - val_accuracy: 0.7009 - val_loss: 1.4154
# Epoch 60/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 6s 203ms/step - accuracy: 0.8948 - loss: 0.2088 - val_accuracy: 0.7009 - val_loss: 1.2872
# Epoch 61/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 186ms/step - accuracy: 0.9267 - loss: 0.1565 - val_accuracy: 0.6822 - val_loss: 1.5903
# Epoch 62/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 196ms/step - accuracy: 0.9101 - loss: 0.2052 - val_accuracy: 0.6916 - val_loss: 1.4971
# Epoch 63/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 184ms/step - accuracy: 0.9458 - loss: 0.1338 - val_accuracy: 0.6449 - val_loss: 1.9561
# Epoch 64/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 195ms/step - accuracy: 0.9357 - loss: 0.1483 - val_accuracy: 0.6916 - val_loss: 1.9462
# Epoch 65/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 6s 207ms/step - accuracy: 0.9234 - loss: 0.1405 - val_accuracy: 0.7103 - val_loss: 1.6874
# Epoch 66/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 6s 209ms/step - accuracy: 0.9212 - loss: 0.1366 - val_accuracy: 0.6822 - val_loss: 2.0321
# Epoch 67/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 6s 232ms/step - accuracy: 0.9480 - loss: 0.1057 - val_accuracy: 0.6916 - val_loss: 2.0666
# Epoch 68/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 197ms/step - accuracy: 0.9367 - loss: 0.1474 - val_accuracy: 0.6355 - val_loss: 2.4840
# Epoch 69/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 240ms/step - accuracy: 0.9630 - loss: 0.0973 - val_accuracy: 0.6542 - val_loss: 2.0030
# Epoch 70/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 216ms/step - accuracy: 0.9307 - loss: 0.1189 - val_accuracy: 0.6822 - val_loss: 1.9271
# Epoch 71/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 6s 231ms/step - accuracy: 0.9584 - loss: 0.1012 - val_accuracy: 0.6449 - val_loss: 2.6075
# Epoch 72/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 6s 231ms/step - accuracy: 0.9685 - loss: 0.0902 - val_accuracy: 0.6822 - val_loss: 2.6658
# Epoch 73/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 7s 248ms/step - accuracy: 0.9669 - loss: 0.0702 - val_accuracy: 0.6916 - val_loss: 2.9318
# Epoch 74/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 7s 272ms/step - accuracy: 0.9733 - loss: 0.0787 - val_accuracy: 0.7009 - val_loss: 2.1515
# Epoch 75/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 7s 248ms/step - accuracy: 0.9705 - loss: 0.0870 - val_accuracy: 0.7103 - val_loss: 2.9361
# Epoch 76/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 248ms/step - accuracy: 0.9841 - loss: 0.1066 - val_accuracy: 0.6449 - val_loss: 1.5949
# Epoch 77/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 6s 220ms/step - accuracy: 0.9388 - loss: 0.1866 - val_accuracy: 0.6916 - val_loss: 1.6036
# Epoch 78/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 6s 213ms/step - accuracy: 0.9698 - loss: 0.0801 - val_accuracy: 0.6729 - val_loss: 2.1236
# Epoch 79/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 9s 175ms/step - accuracy: 0.9732 - loss: 0.0610 - val_accuracy: 0.6916 - val_loss: 2.3543
# Epoch 80/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 170ms/step - accuracy: 0.9930 - loss: 0.0377 - val_accuracy: 0.6916 - val_loss: 2.5167
# Epoch 81/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 176ms/step - accuracy: 0.9941 - loss: 0.0414 - val_accuracy: 0.6729 - val_loss: 2.9565
# Epoch 82/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 192ms/step - accuracy: 0.9931 - loss: 0.0314 - val_accuracy: 0.6916 - val_loss: 3.0069
# Epoch 83/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 165ms/step - accuracy: 0.9734 - loss: 0.0713 - val_accuracy: 0.7290 - val_loss: 2.4941
# Epoch 84/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 162ms/step - accuracy: 0.9765 - loss: 0.0700 - val_accuracy: 0.6542 - val_loss: 3.3536
# Epoch 85/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 163ms/step - accuracy: 0.9877 - loss: 0.0443 - val_accuracy: 0.7009 - val_loss: 3.6835
# Epoch 86/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 164ms/step - accuracy: 0.9949 - loss: 0.0296 - val_accuracy: 0.7103 - val_loss: 2.9410
# Epoch 87/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 186ms/step - accuracy: 0.9949 - loss: 0.0138 - val_accuracy: 0.7103 - val_loss: 3.1288
# Epoch 88/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 170ms/step - accuracy: 0.9913 - loss: 0.0325 - val_accuracy: 0.7383 - val_loss: 2.9102
# Epoch 89/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 171ms/step - accuracy: 0.9956 - loss: 0.0200 - val_accuracy: 0.7103 - val_loss: 3.4544
# Epoch 90/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 167ms/step - accuracy: 0.9924 - loss: 0.0195 - val_accuracy: 0.7290 - val_loss: 3.3129
# Epoch 91/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 174ms/step - accuracy: 0.9866 - loss: 0.0215 - val_accuracy: 0.7009 - val_loss: 3.3229
# Epoch 92/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 170ms/step - accuracy: 0.9895 - loss: 0.0330 - val_accuracy: 0.6636 - val_loss: 3.6463
# Epoch 93/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 174ms/step - accuracy: 0.9749 - loss: 0.0688 - val_accuracy: 0.7103 - val_loss: 3.3484
# Epoch 94/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 189ms/step - accuracy: 0.9899 - loss: 0.0280 - val_accuracy: 0.7009 - val_loss: 3.0401
# Epoch 95/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 171ms/step - accuracy: 1.0000 - loss: 0.0081 - val_accuracy: 0.6916 - val_loss: 3.4875
# Epoch 96/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 6s 206ms/step - accuracy: 0.9887 - loss: 0.0268 - val_accuracy: 0.7103 - val_loss: 3.3872
# Epoch 97/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 9s 173ms/step - accuracy: 0.9517 - loss: 0.1460 - val_accuracy: 0.6542 - val_loss: 2.9390
# Epoch 98/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 175ms/step - accuracy: 0.9628 - loss: 0.1248 - val_accuracy: 0.7103 - val_loss: 2.4136
# Epoch 99/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 167ms/step - accuracy: 0.9722 - loss: 0.0931 - val_accuracy: 0.7009 - val_loss: 2.4107
# Epoch 100/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 170ms/step - accuracy: 0.9617 - loss: 0.0629 - val_accuracy: 0.6822 - val_loss: 2.5865

# %%
model = load_model(f"checkpoints/{tipo_espectrograma}.keras")
y_pred = model.predict(X_test)[:, 0]
y_pred = np.round(y_pred)
acc = len(np.where(y_pred == y_test)[0]) / len(y_test)
print("Acurácia:", acc)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 263ms/step
# Acurácia: 0.5862068965517241

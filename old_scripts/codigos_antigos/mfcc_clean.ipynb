# %%
# POde pular essa etapa se os pacotes já estão instalados
# !pip install numpy
# !pip install scikit-learn
# !pip install scikit-image
# !pip install librosa
# !pip install tqdm
# !pip install matplotlib
# !pip install tensorflow
# Out:
# Requirement already satisfied: numpy in /home/gustavo/.venv/green_bug/lib/python3.11/site-packages (1.26.3)
# Requirement already satisfied: scikit-learn in /home/gustavo/.venv/green_bug/lib/python3.11/site-packages (1.4.0)
# Requirement already satisfied: numpy<2.0,>=1.19.5 in /home/gustavo/.venv/green_bug/lib/python3.11/site-packages (from scikit-learn) (1.26.3)
# Requirement already satisfied: scipy>=1.6.0 in /home/gustavo/.venv/green_bug/lib/python3.11/site-packages (from scikit-learn) (1.12.0)
# Requirement already satisfied: joblib>=1.2.0 in /home/gustavo/.venv/green_bug/lib/python3.11/site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/gustavo/.venv/green_bug/lib/python3.11/site-packages (from scikit-learn) (3.2.0)
# Requirement already satisfied: scikit-image in /home/gustavo/.venv/green_bug/lib/python3.11/site-packages (0.22.0)
# Requirement already satisfied: numpy>=1.22 in /home/gustavo/.venv/green_bug/lib/python3.11/site-packages (from scikit-image) (1.26.3)
# Requirement already satisfied: scipy>=1.8 in /home/gustavo/.venv/green_bug/lib/python3.11/site-packages (from scikit-image) (1.12.0)
# Requirement already satisfied: networkx>=2.8 in /home/gustavo/.venv/green_bug/lib/python3.11/site-packages (from scikit-image) (3.2.1)
# Requirement already satisfied: pillow>=9.0.1 in /home/gustavo/.venv/green_bug/lib/python3.11/site-packages (from scikit-image) (10.2.0)
# Requirement already satisfied: imageio>=2.27 in /home/gustavo/.venv/green_bug/lib/python3.11/site-packages (from scikit-image) (2.33.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /home/gustavo/.venv/green_bug/lib/python3.11/site-packages (from scikit-image) (2024.1.30)
# Requirement already satisfied: packaging>=21 in /home/gustavo/.venv/green_bug/lib/python3.11/site-packages (from scikit-image) (23.2)
# Requirement already satisfied: lazy_loader>=0.3 in /home/gustavo/.venv/green_bug/lib/python3.11/site-packages (from scikit-image) (0.3)
# Requirement already satisfied: librosa in /home/gustavo/.venv/green_bug/lib/python3.11/site-packages (0.10.1)
# Requirement already satisfied: audioread>=2.1.9 in /home/gustavo/.venv/green_bug/lib/python3.11/site-packages (from librosa) (3.0.1)
# Requirement already satisfied: numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3 in /home/gustavo/.venv/green_bug/lib/python3.11/site-packages (from librosa) (1.26.3)
# Requirement already satisfied: scipy>=1.2.0 in /home/gustavo/.venv/green_bug/lib/python3.11/site-packages (from librosa) (1.12.0)
# Requirement already satisfied: scikit-learn>=0.20.0 in /home/gustavo/.venv/green_bug/lib/python3.11/site-packages (from librosa) (1.4.0)
# Requirement already satisfied: joblib>=0.14 in /home/gustavo/.venv/green_bug/lib/python3.11/site-packages (from librosa) (1.3.2)
# Requirement already satisfied: decorator>=4.3.0 in /home/gustavo/.venv/green_bug/lib/python3.11/site-packages (from librosa) (5.1.1)
# Requirement already satisfied: numba>=0.51.0 in /home/gustavo/.venv/green_bug/lib/python3.11/site-packages (from librosa) (0.59.0)
# Requirement already satisfied: soundfile>=0.12.1 in /home/gustavo/.venv/green_bug/lib/python3.11/site-packages (from librosa) (0.12.1)
# Requirement already satisfied: pooch>=1.0 in /home/gustavo/.venv/green_bug/lib/python3.11/site-packages (from librosa) (1.8.0)
# Requirement already satisfied: soxr>=0.3.2 in /home/gustavo/.venv/green_bug/lib/python3.11/site-packages (from librosa) (0.3.7)
# Requirement already satisfied: typing-extensions>=4.1.1 in /home/gustavo/.venv/green_bug/lib/python3.11/site-packages (from librosa) (4.9.0)
# Requirement already satisfied: lazy-loader>=0.1 in /home/gustavo/.venv/green_bug/lib/python3.11/site-packages (from librosa) (0.3)
# Requirement already satisfied: msgpack>=1.0 in /home/gustavo/.venv/green_bug/lib/python3.11/site-packages (from librosa) (1.0.7)
# Requirement already satisfied: llvmlite<0.43,>=0.42.0dev0 in /home/gustavo/.venv/green_bug/lib/python3.11/site-packages (from numba>=0.51.0->librosa) (0.42.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /home/gustavo/.venv/green_bug/lib/python3.11/site-packages (from pooch>=1.0->librosa) (4.2.0)
# Requirement already satisfied: packaging>=20.0 in /home/gustavo/.venv/green_bug/lib/python3.11/site-packages (from pooch>=1.0->librosa) (23.2)
# Requirement already satisfied: requests>=2.19.0 in /home/gustavo/.venv/green_bug/lib/python3.11/site-packages (from pooch>=1.0->librosa) (2.31.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/gustavo/.venv/green_bug/lib/python3.11/site-packages (from scikit-learn>=0.20.0->librosa) (3.2.0)
# Requirement already satisfied: cffi>=1.0 in /home/gustavo/.venv/green_bug/lib/python3.11/site-packages (from soundfile>=0.12.1->librosa) (1.16.0)
# Requirement already satisfied: pycparser in /home/gustavo/.venv/green_bug/lib/python3.11/site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.21)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/gustavo/.venv/green_bug/lib/python3.11/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/gustavo/.venv/green_bug/lib/python3.11/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/gustavo/.venv/green_bug/lib/python3.11/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/gustavo/.venv/green_bug/lib/python3.11/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2023.11.17)
# Requirement already satisfied: tqdm in /home/gustavo/.venv/green_bug/lib/python3.11/site-packages (4.66.1)
# Requirement already satisfied: matplotlib in /home/gustavo/.venv/green_bug/lib/python3.11/site-packages (3.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/gustavo/.venv/green_bug/lib/python3.11/site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /home/gustavo/.venv/green_bug/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/gustavo/.venv/green_bug/lib/python3.11/site-packages (from matplotlib) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/gustavo/.venv/green_bug/lib/python3.11/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.21 in /home/gustavo/.venv/green_bug/lib/python3.11/site-packages (from matplotlib) (1.26.3)
# Requirement already satisfied: packaging>=20.0 in /home/gustavo/.venv/green_bug/lib/python3.11/site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in /home/gustavo/.venv/green_bug/lib/python3.11/site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/gustavo/.venv/green_bug/lib/python3.11/site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/gustavo/.venv/green_bug/lib/python3.11/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /home/gustavo/.venv/green_bug/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: tensorflow in /home/gustavo/.venv/green_bug/lib/python3.11/site-packages (2.15.0.post1)
# Requirement already satisfied: absl-py>=1.0.0 in /home/gustavo/.venv/green_bug/lib/python3.11/site-packages (from tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in /home/gustavo/.venv/green_bug/lib/python3.11/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /home/gustavo/.venv/green_bug/lib/python3.11/site-packages (from tensorflow) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /home/gustavo/.venv/green_bug/lib/python3.11/site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/gustavo/.venv/green_bug/lib/python3.11/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /home/gustavo/.venv/green_bug/lib/python3.11/site-packages (from tensorflow) (3.10.0)
# Requirement already satisfied: libclang>=13.0.0 in /home/gustavo/.venv/green_bug/lib/python3.11/site-packages (from tensorflow) (16.0.6)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /home/gustavo/.venv/green_bug/lib/python3.11/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /home/gustavo/.venv/green_bug/lib/python3.11/site-packages (from tensorflow) (1.26.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/gustavo/.venv/green_bug/lib/python3.11/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /home/gustavo/.venv/green_bug/lib/python3.11/site-packages (from tensorflow) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /home/gustavo/.venv/green_bug/lib/python3.11/site-packages (from tensorflow) (4.23.4)
# Requirement already satisfied: setuptools in /home/gustavo/.venv/green_bug/lib/python3.11/site-packages (from tensorflow) (69.0.3)
# Requirement already satisfied: six>=1.12.0 in /home/gustavo/.venv/green_bug/lib/python3.11/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/gustavo/.venv/green_bug/lib/python3.11/site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/gustavo/.venv/green_bug/lib/python3.11/site-packages (from tensorflow) (4.9.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /home/gustavo/.venv/green_bug/lib/python3.11/site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /home/gustavo/.venv/green_bug/lib/python3.11/site-packages (from tensorflow) (0.35.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/gustavo/.venv/green_bug/lib/python3.11/site-packages (from tensorflow) (1.60.1)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /home/gustavo/.venv/green_bug/lib/python3.11/site-packages (from tensorflow) (2.15.1)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /home/gustavo/.venv/green_bug/lib/python3.11/site-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in /home/gustavo/.venv/green_bug/lib/python3.11/site-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/gustavo/.venv/green_bug/lib/python3.11/site-packages (from astunparse>=1.6.0->tensorflow) (0.42.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/gustavo/.venv/green_bug/lib/python3.11/site-packages (from tensorboard<2.16,>=2.15->tensorflow) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /home/gustavo/.venv/green_bug/lib/python3.11/site-packages (from tensorboard<2.16,>=2.15->tensorflow) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /home/gustavo/.venv/green_bug/lib/python3.11/site-packages (from tensorboard<2.16,>=2.15->tensorflow) (3.5.2)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/gustavo/.venv/green_bug/lib/python3.11/site-packages (from tensorboard<2.16,>=2.15->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/gustavo/.venv/green_bug/lib/python3.11/site-packages (from tensorboard<2.16,>=2.15->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/gustavo/.venv/green_bug/lib/python3.11/site-packages (from tensorboard<2.16,>=2.15->tensorflow) (3.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/gustavo/.venv/green_bug/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/gustavo/.venv/green_bug/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/gustavo/.venv/green_bug/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/gustavo/.venv/green_bug/lib/python3.11/site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/gustavo/.venv/green_bug/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/gustavo/.venv/green_bug/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/gustavo/.venv/green_bug/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (2.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/gustavo/.venv/green_bug/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (2023.11.17)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/gustavo/.venv/green_bug/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow) (2.1.5)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /home/gustavo/.venv/green_bug/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/gustavo/.venv/green_bug/lib/python3.11/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow) (3.2.2)

# %%
#ref: https://www.kaggle.com/code/msripooja/steps-to-convert-audio-clip-to-spectrogram
import os
import matplotlib.pyplot as plt
import numpy as np
import skimage.io as io
import librosa
import librosa.display
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
from tqdm import tqdm
from keras.losses import CategoricalCrossentropy
from keras.models import Sequential, load_model
from keras.layers import GRU, LSTM, Conv2D, MaxPooling2D, Dense, Conv1D, MaxPooling1D, Flatten, Dropout, Activation, TimeDistributed
from PIL import Image
from keras.optimizers import Adam

#to play audio
import IPython.display as ipd

# %%
tipo_espectrograma = "mfcc"

# Nesse caso você precisa ter no seu diretório uma pasta com o mesmo nome da variável base_dir
base_dir = "clean_audioset"
# E dentro da pasta audioset, você precisa de 3 pastas: carros, motocicletas e motosserras contendo os áudios
audio_carro_path = base_dir + "/carros/"
audio_moto_path = base_dir + "/motocicletas/"  # caminho onde estão os arquivos de audio
audio_serra_path = base_dir + "/motosserras/"

spec_base_path = base_dir + f"/{tipo_espectrograma}"
spec_carro_path = os.path.join(spec_base_path, "carros")
spec_moto_path = os.path.join(spec_base_path, "motocicletas")
spec_serra_path = os.path.join(spec_base_path, "motosserras")
 
os.makedirs(spec_base_path, exist_ok=True)
os.makedirs(spec_carro_path, exist_ok=True)
os.makedirs(spec_moto_path, exist_ok=True)
os.makedirs(spec_serra_path, exist_ok=True)

FILE_FORMAT = "png"
TAM_IMAGEM = 40

# %%
audio_carro_clips = sorted(os.listdir(audio_carro_path))[:50]
print(f"Número de arquivos .wav na pasta {audio_carro_path}= ",len(audio_carro_clips))

audio_moto_clips = sorted(os.listdir(audio_moto_path))[:50]
print(f"Número de arquivos .wav na pasta {audio_moto_path}= ",len(audio_moto_clips))

audio_serra_clips = sorted(os.listdir(audio_serra_path))[:100]
print(f"Número de arquivos .wav na pasta {audio_serra_path}= ",len(audio_serra_clips))
# Out:
# Número de arquivos .wav na pasta clean_audioset/carros/=  50
# Número de arquivos .wav na pasta clean_audioset/motocicletas/=  50
# Número de arquivos .wav na pasta clean_audioset/motosserras/=  78

# %%
#aqui está selecionando o primeiro arquivo da lista, pode ser feito um for para pegar todos de uma vez
#verificar esse sample rate
x_carro, sr_carro = librosa.load(audio_carro_path+audio_carro_clips[0]) 
x_moto, sr_moto = librosa.load(audio_moto_path+audio_moto_clips[4]) 
x_serra, sr_serra = librosa.load(audio_serra_path+audio_serra_clips[6]) 

print(type(x_carro), type(sr_carro))
print(x_carro.shape, sr_carro)

print(type(x_moto), type(sr_moto))
print(x_moto.shape, sr_moto)

print(type(x_serra), type(sr_serra))
print(x_serra.shape, sr_serra)
# Out:
# <class 'numpy.ndarray'> <class 'int'>
# (220676,) 22050
# <class 'numpy.ndarray'> <class 'int'>
# (114308,) 22050
# <class 'numpy.ndarray'> <class 'int'>
# (1323000,) 22050

# %%
import librosa.display
import matplotlib.pyplot as plt

y, sr = librosa.load(os.path.join(audio_serra_path, audio_serra_clips[20]))
plt.plot(y);
plt.title('Signal');
plt.xlabel('Time (samples)');
plt.ylabel('Amplitude');

# %%
hop_length = 512 # in num. of samples
n_fft = 256 # window in num. of samples
n_mfcc=40

S = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=128,
                                   fmax=8000)
spectrum = librosa.feature.mfcc(S=librosa.power_to_db(S), n_mfcc=n_mfcc)
size_padding = TAM_IMAGEM - n_mfcc
padding = np.zeros((size_padding, spectrum.shape[1]))
    
spectrum = np.vstack((spectrum, padding))
# calculate abs values on complex numbers to get magnitude
# spectrum = np.abs(stft)
# spectrum = np.log(spectrum + 0.00000001)
librosa.display.specshow(spectrum, sr=sr, x_axis="time")

print(spectrum.shape)
# Out:
# []
# (40, 287)

# %% [markdown]
# # Salvar valores de espectrograma
#  - Pule esse passo se os arquivos já estiverem na pasta

# %%
##converter o audio para espectrograma:
## é nesse amplitude_to_dB que ele está convertendo para pressão sonora. Podemos explorar outras ponderações aqui. Se não tiver implementado, podemos implementar.
def gerar_espectrograma(y, sample_rate):

    n_mfcc = 40
    S = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=128,
                                   fmax=8000)
    spectrum = librosa.feature.mfcc(S=librosa.power_to_db(S), n_mfcc=n_mfcc)
    size_padding = TAM_IMAGEM - n_mfcc
    padding = np.zeros((size_padding, spectrum.shape[1]))
        
    spectrum = np.vstack((spectrum, padding))

    return spectrum 


def cortar_espectrograma(spectrogram, largura_janela=TAM_IMAGEM, altura_janela=TAM_IMAGEM):
    altura_spec = spectrogram.shape[0]+1
    largura_spec = spectrogram.shape[1]
    spectrogram_slices = []

    if altura_janela > altura_spec:
        altura_janela = altura_spec-1

    for h in range(altura_janela, altura_spec, altura_janela):
        for w in range(largura_janela, largura_spec, largura_janela):
            slice = spectrogram[h-altura_janela : h,   # largura
                                w-largura_janela : w,  # altura
                                np.newaxis]
            spectrogram_slices.append(slice)
            
    return spectrogram_slices    
    
# end def

# %%
# Salvar espectrogramas na pasta específica (carros, serras etc)
def salvar_espectrogtramas (audio_clips, audio_path, spectrogram_path, audios_por_arquivo=50):
    numero_audios = len(audio_clips)
    num_arquivo = 1

    spectrogram_values = []
    
    for i, audio_name in enumerate(audio_clips):
        y, sr = librosa.load( os.path.join(audio_path, audio_name) )
        audio_name = audio_name.replace(".mp3", "").replace(".wav", "").replace(".m4a", "")

        fullpath = os.path.join(spectrogram_path, audio_name)
        try:
            mfcc_spec = gerar_espectrograma(y, sr)
            mfcc_spec = 255 * (mfcc_spec - mfcc_spec.min()) / (mfcc_spec.max() - mfcc_spec.min())
            mfcc_spec = np.flip(mfcc_spec, axis=0) # put low frequencies at the bottom in image
            mfcc_spec_slices = cortar_espectrograma(mfcc_spec)
        
            # Salva o arquivo e começa o próximo
            for j in range(len(mfcc_spec_slices)):

                full_filename = fullpath + f"_{j+1}.{FILE_FORMAT}"
                spec_save = mfcc_spec_slices[j][:, :, 0]

                if FILE_FORMAT == "csv":
                    np.savetxt(full_filename, spec_save, delimiter=",")
                else:
                    im = Image.fromarray(spec_save).convert("L")
                    im.save(full_filename)

            print("Arquivo %s salvo com sucesso." % full_filename)
                
        except Exception as e:
            print( "Erro ao salvar %s: %s." % (fullpath, e) )


salvar_espectrogtramas(audio_carro_clips, audio_carro_path, spec_carro_path)

salvar_espectrogtramas(audio_moto_clips, audio_moto_path, spec_moto_path)

salvar_espectrogtramas(audio_serra_clips, audio_serra_path, spec_serra_path)
# Out:
# Arquivo clean_audioset/mfcc/carros/(HD) - Forza 4 - Top Gear - Car Test - 1990 Lotus Carlton-0GZbu00-aMY_10.png salvo com sucesso.
# Arquivo clean_audioset/mfcc/carros/1968 Chevy Camaro - V8 327 - MUSCLECAR SOUND - restauriert-1ddvRm8MURI_10.png salvo com sucesso.
# Arquivo clean_audioset/mfcc/carros/1995 Toyota Supra FOR SALE-2-1wY_Ndtgw_10.png salvo com sucesso.
# Arquivo clean_audioset/mfcc/carros/2013 Porsche 911 Carrera Start Up and Review 3.4 L Horizontally Opposed⧸6 Cylinder-9BzZvj5W09s_10.png salvo com sucesso.
# Arquivo clean_audioset/mfcc/carros/95 Mustang drag car start up-1sjKon7lrLY_9.png salvo com sucesso.
# Arquivo clean_audioset/mfcc/carros/99 Trans Am WS6 - Donuts, Take-Offs, 110MPH!-G4Rp68qV_aw_10.png salvo com sucesso.
# Arquivo clean_audioset/mfcc/carros/A guy trying to start car after flood-0TGPaUN2V5Q_9.png salvo com sucesso.
# Arquivo clean_audioset/mfcc/carros/AX kit car-1-Vhr9Ut4Tg_10.png salvo com sucesso.
# Arquivo clean_audioset/mfcc/carros/Atlanta GA： 1999 Jeep Grand Cherokee - Ignition Lock  Problem!-vsGv0Xf_hMI_9.png salvo com sucesso.
# Arquivo clean_audioset/mfcc/carros/Audely End House and Gardens Stately House. Essex. England. English Heritage-1pKxZkeXe9w_10.png salvo com sucesso.
# Arquivo clean_audioset/mfcc/carros/Audi 90 ISMA GTO und Audi 200 TransAm-B4l-0zH00nI_10.png salvo com sucesso.
# Arquivo clean_audioset/mfcc/carros/BMW E46 M3 Drift Day in car-2ujlG9xd9NA_9.png salvo com sucesso.
# Arquivo clean_audioset/mfcc/carros/Best car sounds in the world Part 14.--nlq9Dz4NIk_9.png salvo com sucesso.
# Arquivo clean_audioset/mfcc/carros/Bold and Beautiful 1969 Camaro Muscle Car For Sale!-0hefQELmzq8_10.png salvo com sucesso.
# Arquivo clean_audioset/mfcc/carros/Brisca F1 Stock Car Racing Swaffham 13⧸8⧸2000 Semi FWJ Wainman Speak Lund Harrison Pearce Willis--V2t-Yt1_-0_10.png salvo com sucesso.
# Arquivo clean_audioset/mfcc/carros/CAMERA CAR FABIO CON PIT BIKE 125 cc CROSS 002.AVI-5MVE73rP6R8_10.png salvo com sucesso.
# Arquivo clean_audioset/mfcc/carros/CAR ACCIDENT ON JERICHO TURNPIKE-2WoOCPOfgAo_10.png salvo com sucesso.
# Arquivo clean_audioset/mfcc/carros/CWC Car Winter Cup - Záskalí 2006-0Ree10eqPN4_10.png salvo com sucesso.
# Arquivo clean_audioset/mfcc/carros/Car 66 Adrian Barker Stages - Warts and All!--t3ETssuUYQ_10.png salvo com sucesso.
# Arquivo clean_audioset/mfcc/carros/Car Crash Sound Effects-22QDZUi_oS0_5.png salvo com sucesso.
# Arquivo clean_audioset/mfcc/carros/Car Recycling in Russia 15.9.2012 ｜FMV｜-2sF7d4EYxsI_10.png salvo com sucesso.
# Arquivo clean_audioset/mfcc/carros/Car sound imitations 3--vBVkcJCZ7M_9.png salvo com sucesso.
# Arquivo clean_audioset/mfcc/carros/Circuit Of Ireland 2014 - Car 18--nyKu0ezRN8_5.png salvo com sucesso.
# Arquivo clean_audioset/mfcc/carros/City Car Driving 1.2.2 BMW M3 E36-6HMi-OYf0rI_10.png salvo com sucesso.
# Arquivo clean_audioset/mfcc/carros/Conduite de prototype⧸Drive a race car--XH1WiOPLRs_10.png salvo com sucesso.
# Arquivo clean_audioset/mfcc/carros/Custom 3 Car racing trailer (Toy Hauler) with tractor with sleeping Quarters for sale-3Mif39PORh8_10.png salvo com sucesso.
# Arquivo clean_audioset/mfcc/carros/
10.png salvo com sucesso.
# Arquivo clean_audioset/mfcc/motosserras/Resident Evil 4 HD： Walkthrough Part 3 - Chainsaw Man!!!-HPmDHUD51EI_10.png salvo com sucesso.
# Arquivo clean_audioset/mfcc/motosserras/Récolte d'arbres Douglas pour la Pessière.-FJeQBOfG7p8_10.png salvo com sucesso.
# Arquivo clean_audioset/mfcc/motosserras/Secho E 2000 Elektrikli Testere-i7gsZHbY2YI_10.png salvo com sucesso.
# Arquivo clean_audioset/mfcc/motosserras/Skidder vtt.wmv-2Jtfxu0vob4_10.png salvo com sucesso.
# Arquivo clean_audioset/mfcc/motosserras/Solo 681 felling a big spurance-m9caDFvU-9Q_10.png salvo com sucesso.
# Arquivo clean_audioset/mfcc/motosserras/Sägen mit Stihl 024AV-M9mBJmt4EXs_10.png salvo com sucesso.
# Arquivo clean_audioset/mfcc/motosserras/aprire birra con motosega san pellegrino-6tXkKR9EU6w_10.png salvo com sucesso.
# Arquivo clean_audioset/mfcc/motosserras/chain sawing the big tree regular speed-d5AKgq5JDBA_10.png salvo com sucesso.
# Arquivo clean_audioset/mfcc/motosserras/chainsaw skil 933  type1 sold-0NOfrBTZC_M_10.png salvo com sucesso.
# Arquivo clean_audioset/mfcc/motosserras/cutting branches over power lines-59svx6RTX6E_10.png salvo com sucesso.
# Arquivo clean_audioset/mfcc/motosserras/echo gt225 curved shft weed trimmer-9vPMaY9f540_10.png salvo com sucesso.
# Arquivo clean_audioset/mfcc/motosserras/first mod on the 460-tZUBvalpY_k_10.png salvo com sucesso.
# Arquivo clean_audioset/mfcc/motosserras/home made chainsaw mill-DwE0cQ3Xz70_10.png salvo com sucesso.
# Arquivo clean_audioset/mfcc/motosserras/husqvarna 40-z13omhGxAeQ_10.png salvo com sucesso.
# Arquivo clean_audioset/mfcc/motosserras/hızar  motoru nasıl kullanılır hüsamettin-WDAxpni8Dkk_10.png salvo com sucesso.
# Arquivo clean_audioset/mfcc/motosserras/large defected water oak removal-d9QM-2K9jPA_10.png salvo com sucesso.
# Arquivo clean_audioset/mfcc/motosserras/mit der Stihl MS 241 C-M bei der Sturmschadenbeseitigung-DA2ECI9KQV8_10.png salvo com sucesso.
# Arquivo clean_audioset/mfcc/motosserras/motorkettingzaag cursus IVN Hardenberg-FeSvAVZXKAA_10.png salvo com sucesso.
# Arquivo clean_audioset/mfcc/motosserras/motoseghe stihl ms880 e 023 in taglio pioppo-Vwfzey2Fwq4_10.png salvo com sucesso.
# Arquivo clean_audioset/mfcc/motosserras/pocket bike first ride-o2z2ugX9VcA_10.png salvo com sucesso.
# Arquivo clean_audioset/mfcc/motosserras/poulan 2800 vs. husqvarna 346 oe-fZPf86wPZiQ_7.png salvo com sucesso.
# Arquivo clean_audioset/mfcc/motosserras/precision pumped concrete ⧸ precision poured concrete-kxP-x1bcpc4_10.png salvo com sucesso.

# %% [markdown]
# # Treinamento e teste de rede neural

# %%
# Carregar espectrogramas com uma CNN e classificar entre "motosserras e não motosserras"

espectrogramas_carro = sorted(os.listdir(spec_carro_path))
espectrogramas_moto = sorted(os.listdir(spec_moto_path))
espectrogramas_serra = sorted(os.listdir(spec_serra_path))

spectrogram_list = []
labels = []

def carregar_espectrograma(full_filename):
    if FILE_FORMAT == "png":
        return np.asarray(Image.open(full_filename))
    else:
        return np.loadtxt(full_filename, delimiter=",")


def adicionar_rotulos_spec(espectrogramas, spec_path, label):
    for filename in espectrogramas:
        full_filename = os.path.join(spec_path, filename)  

        spectrogram = carregar_espectrograma(full_filename)
        spectrogram_list.append(spectrogram)
        # 0 corresponde aos carros e motos
        labels.append(label)


adicionar_rotulos_spec(espectrogramas_carro, spec_carro_path, 0)
adicionar_rotulos_spec(espectrogramas_moto, spec_moto_path, 0)
adicionar_rotulos_spec(espectrogramas_serra, spec_serra_path, 1)

spectrogram_np = np.array(spectrogram_list) / 255

spectrogram_np = spectrogram_np.reshape(
    (spectrogram_np.shape[0], spectrogram_np.shape[1], spectrogram_np.shape[2], 1)
)

labels_np = np.array(labels)

X_train, X_test, y_train, y_test = train_test_split(
    spectrogram_np, labels_np, test_size=0.2  # , random_state=42
)

print("Amostras treinamento:", len(X_train))
print("Amostras teste:", len(X_test))
# Out:
# Amostras treinamento: 1713
# Amostras teste: 429

# %%
model = Sequential()

model.add(Conv2D(16, 3, activation='relu', use_bias=True, bias_initializer='zeros', input_shape=X_train[0].shape))
model.add(MaxPooling2D())
model.add(Conv2D(32, 3, activation='relu', use_bias=True, bias_initializer='zeros'))
model.add(MaxPooling2D())
model.add(Conv2D(64, 3, activation='relu', use_bias=True, bias_initializer='zeros'))
model.add(MaxPooling2D())
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.25))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid')) # Binary classification
model.compile(loss='binary_crossentropy',
              optimizer = 'RMSProp',
              metrics=['accuracy'])
# Print model summaryImage.open
model.summary()
model.fit(X_train, y_train, epochs=100, validation_split=0.2, batch_size=16)

model.save(f"checkpoints/{tipo_espectrograma}.keras")
# Out:
# /home/gustavo/.venv/green_bug/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_15 (Conv2D)              │ (None, 38, 38, 16)     │           160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_15 (MaxPooling2D) │ (None, 19, 19, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_16 (Conv2D)              │ (None, 17, 17, 32)     │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_16 (MaxPooling2D) │ (None, 8, 8, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_17 (Conv2D)              │ (None, 6, 6, 64)       │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_17 (MaxPooling2D) │ (None, 3, 3, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_5 (Flatten)             │ (None, 576)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_15 (Dense)                │ (None, 128)            │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_16 (Dense)                │ (None, 256)            │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_17 (Dense)                │ (None, 1)              │           257 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 130,433 (509.50 KB)
#  Trainable params: 130,433 (509.50 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - accuracy: 0.5489 - loss: 0.6885 - val_accuracy: 0.5423 - val_loss: 0.6731
# Epoch 2/100
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 0.5885 - loss: 0.6713 - val_accuracy: 0.6210 - val_loss: 0.6337
# Epoch 3/100
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - accuracy: 0.6915 - loss: 0.6067 - val_accuracy: 0.4694 - val_loss: 0.7839
# Epoch 4/100
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.6742 - loss: 0.6083 - val_accuracy: 0.7609 - val_loss: 0.5488
# Epoch 5/100
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.7126 - loss: 0.5758 - val_accuracy: 0.7143 - val_loss: 0.5661
# Epoch 6/100
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - accuracy: 0.7466 - loss: 0.5332 - val_accuracy: 0.7434 - val_loss: 0.5209
# Epoch 7/100
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.7568 - loss: 0.5125 - val_accuracy: 0.7668 - val_loss: 0.5118
# Epoch 8/100
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - accuracy: 0.7461 - loss: 0.5383 - val_accuracy: 0.6735 - val_loss: 0.8256
# Epoch 9/100
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 0.7672 - loss: 0.5126 - val_accuracy: 0.7289 - val_loss: 0.5732
# Epoch 10/100
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - accuracy: 0.7862 - loss: 0.4847 - val_accuracy: 0.7376 - val_loss: 0.5853
# Epoch 11/100
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - accuracy: 0.7989 - loss: 0.4519 - val_accuracy: 0.7551 - val_loss: 0.5012
# Epoch 12/100
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - accuracy: 0.8115 - loss: 0.4316 - val_accuracy: 0.7347 - val_loss: 0.5043
# Epoch 13/100
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 0.8153 - loss: 0.4438 - val_accuracy: 0.7755 - val_loss: 0.4828
# Epoch 14/100
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.8362 - loss: 0.4299 - val_accuracy: 0.7638 - val_loss: 0.4988
# Epoch 15/100
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.8275 - loss: 0.4137 - val_accuracy: 0.7813 - val_loss: 0.4613
# Epoch 16/100
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.8193 - loss: 0.4156 - val_accuracy: 0.7959 - val_loss: 0.4740
# Epoch 17/100
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.8366 - loss: 0.3777 - val_accuracy: 0.6589 - val_loss: 0.7461
# Epoch 18/100
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.8192 - loss: 0.3897 - val_accuracy: 0.7464 - val_loss: 0.6769
# Epoch 19/100
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.8167 - loss: 0.4389 - val_accuracy: 0.8338 - val_loss: 0.3969
# Epoch 20/100
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.8624 - loss: 0.3343 - val_accuracy: 0.7697 - val_loss: 0.4773
# Epoch 21/100
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.8246 - loss: 0.3958 - val_accuracy: 0.8047 - val_loss: 0.4382
# Epoch 22/100
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 0.8419 - loss: 0.3695 - val_accuracy: 0.7522 - val_loss: 0.6536
# Epoch 23/100
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.8656 - loss: 0.3277 - val_accuracy: 0.7668 - val_loss: 0.5265
# Epoch 24/100
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 0.8423 - loss: 0.3651 - val_accuracy: 0.8338 - val_loss: 0.3746
# Epoch 25/100
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.8540 - loss: 0.3257 - val_accuracy: 0.8251 - val_loss: 0.4268
# Epoch 26/100
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.
100
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 8s 34ms/step - accuracy: 0.9056 - loss: 0.2187 - val_accuracy: 0.8047 - val_loss: 0.4999
# Epoch 58/100
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.9174 - loss: 0.1995 - val_accuracy: 0.8426 - val_loss: 0.3402
# Epoch 59/100
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - accuracy: 0.9289 - loss: 0.1744 - val_accuracy: 0.8513 - val_loss: 0.3997
# Epoch 60/100
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.9295 - loss: 0.1772 - val_accuracy: 0.8426 - val_loss: 0.4445
# Epoch 61/100
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.9205 - loss: 0.2052 - val_accuracy: 0.8776 - val_loss: 0.4099
# Epoch 62/100
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9172 - loss: 0.2149 - val_accuracy: 0.8571 - val_loss: 0.4265
# Epoch 63/100
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.9313 - loss: 0.1867 - val_accuracy: 0.8746 - val_loss: 0.3643
# Epoch 64/100
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - accuracy: 0.9240 - loss: 0.1751 - val_accuracy: 0.8601 - val_loss: 0.4224
# Epoch 65/100
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 4s 52ms/step - accuracy: 0.9234 - loss: 0.1712 - val_accuracy: 0.8717 - val_loss: 0.3187
# Epoch 66/100
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 82ms/step - accuracy: 0.9343 - loss: 0.1679 - val_accuracy: 0.8484 - val_loss: 0.4370
# Epoch 67/100
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 80ms/step - accuracy: 0.9311 - loss: 0.1686 - val_accuracy: 0.8280 - val_loss: 0.4337
# Epoch 68/100
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 6s 73ms/step - accuracy: 0.9410 - loss: 0.1564 - val_accuracy: 0.8746 - val_loss: 0.3424
# Epoch 69/100
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - accuracy: 0.9509 - loss: 0.1356 - val_accuracy: 0.8746 - val_loss: 0.3328
# Epoch 70/100
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - accuracy: 0.9377 - loss: 0.1501 - val_accuracy: 0.8426 - val_loss: 0.5808
# Epoch 71/100
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9275 - loss: 0.1633 - val_accuracy: 0.8834 - val_loss: 0.3363
# Epoch 72/100
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - accuracy: 0.9340 - loss: 0.1535 - val_accuracy: 0.8513 - val_loss: 0.3898
# Epoch 73/100
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 5s 52ms/step - accuracy: 0.9325 - loss: 0.1534 - val_accuracy: 0.8659 - val_loss: 0.5140
# Epoch 74/100
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 4s 44ms/step - accuracy: 0.9336 - loss: 0.1585 - val_accuracy: 0.8484 - val_loss: 0.5132
# Epoch 75/100
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 4s 49ms/step - accuracy: 0.9286 - loss: 0.1550 - val_accuracy: 0.8892 - val_loss: 0.3336
# Epoch 76/100
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - accuracy: 0.9465 - loss: 0.1292 - val_accuracy: 0.8776 - val_loss: 0.4014
# Epoch 77/100
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 5s 61ms/step - accuracy: 0.9416 - loss: 0.1342 - val_accuracy: 0.8717 - val_loss: 0.4508
# Epoch 78/100
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - accuracy: 0.9337 - loss: 0.1671 - val_accuracy: 0.8484 - val_loss: 0.4858
# Epoch 79/100
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 14s 110ms/step - accuracy: 0.9340 - loss: 0.1735 - val_accuracy: 0.8397 - val_loss: 0.4905
# Epoch 80/100
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 10s 108ms/step - accuracy: 0.9379 - loss: 0.1488 - val_accuracy: 0.8601 - val_loss: 0.4032
# Epoch 81/100
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - accuracy: 0.9328 - loss: 0.1582 - val_accuracy: 0.8542 - val_loss: 0.6292
# Epoch 82/100
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - accuracy: 0.9302 - loss: 0.1556 - val_accuracy: 0.8950 - val_loss: 0.3631
# Epoch 83/100
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 5s 52ms/step - accuracy: 0.9475 - loss: 0.1247 - val_accuracy: 0.8805 - val_loss: 0.3917
# Epoch 84/100
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - accuracy: 0.9518 - loss: 0.1084 - val_accuracy: 0.8571 - val_loss: 0.4582
# Epoch 85/100

# %%
model = load_model(f"checkpoints/{tipo_espectrograma}.keras")
y_pred = model.predict(X_test)[:, 0]
y_pred = np.round(y_pred)
acc = len(np.where(y_pred == y_test)[0]) / len(y_test)
print("Acurácia:", acc)
# Out:
# 13/13 [==============================] - 1s 29ms/step
# Acurácia: 0.5968992248062015

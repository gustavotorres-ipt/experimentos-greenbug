# %%
#ref: https://www.kaggle.com/code/msripooja/steps-to-convert-audio-clip-to-spectrogram
import os
import matplotlib.pyplot as plt
import numpy as np
import skimage.io as io
import librosa
import librosa.display
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
from tqdm import tqdm
from keras.losses import CategoricalCrossentropy
from keras.models import Sequential
from keras.layers import GRU, LSTM, Conv2D, MaxPooling2D, Dense, Conv1D, MaxPooling1D, Flatten, Dropout, Activation, TimeDistributed
from PIL import Image
from keras.optimizers import Adam

#to play audio
import IPython.display as ipd

# %%
pasta_audios = "clean_audioset"

audio_carro_path = os.path.join(pasta_audios, "carros")
audio_moto_path = os.path.join(pasta_audios, "motocicletas") #caminho onde estão os arquivos de audio
audio_serra_path = os.path.join(pasta_audios, "motosserras")

tipo_espectrograma = "stft"

spec_base_path = os.path.join(pasta_audios, tipo_espectrograma)
spec_carro_path = os.path.join(spec_base_path, "carros")
spec_moto_path = os.path.join(spec_base_path, "motocicletas")
spec_serra_path = os.path.join(spec_base_path, "motosserras")
 
os.makedirs(spec_base_path, exist_ok=True)
os.makedirs(spec_carro_path, exist_ok=True)
os.makedirs(spec_moto_path, exist_ok=True)
os.makedirs(spec_serra_path, exist_ok=True)

# %%
audio_carro_clips = sorted(os.listdir(audio_carro_path))[:100]
print(f"Número de arquivos .wav na pasta {audio_carro_path} =",len(audio_carro_clips))

audio_moto_clips = sorted(os.listdir(audio_moto_path))[:100]
print(f"Número de arquivos .wav na pasta {audio_moto_path} =",len(audio_moto_clips))

audio_serra_clips = sorted(os.listdir(audio_serra_path))[:200]
print(f"Número de arquivos .wav na pasta {audio_serra_path} =",len(audio_serra_clips))
# Out:
# Número de arquivos .wav na pasta clean_audioset/carros = 100
# Número de arquivos .wav na pasta clean_audioset/motocicletas = 100
# Número de arquivos .wav na pasta clean_audioset/motosserras = 100

# %%
#aqui está selecionando o primeiro arquivo da lista, pode ser feito um for para pegar todos de uma vez
#verificar esse sample rate
x_carro, sr_carro = librosa.load(os.path.join(audio_carro_path, audio_carro_clips[0]))
x_moto, sr_moto = librosa.load(os.path.join(audio_moto_path, audio_moto_clips[4]))
x_serra, sr_serra = librosa.load(os.path.join(audio_serra_path, audio_serra_clips[6]))

print(type(x_carro), type(sr_carro))
print(x_carro.shape, sr_carro)

print(type(x_moto), type(sr_moto))
print(x_moto.shape, sr_moto)

print(type(x_serra), type(sr_serra))
print(x_serra.shape, sr_serra)
# Out:
# <class 'numpy.ndarray'> <class 'int'>
# (220676,) 22050
# <class 'numpy.ndarray'> <class 'int'>
# (114308,) 22050
# <class 'numpy.ndarray'> <class 'int'>
# (220500,) 22050

# %%
import librosa.display
import matplotlib.pyplot as plt

y, sr = librosa.load(os.path.join(audio_serra_path, audio_serra_clips[20]))
plt.plot(y);
plt.title('Signal');
plt.xlabel('Time (samples)');
plt.ylabel('Amplitude');

# %%
# fig, ax = plt.subplots(nrows=4, ncols=3, sharex=True)

# librosa.display.waveshow(y, sr, ax=ax[i, 0])  # put wave in row i, column 0

# calculate abs values on complex numbers to get magnitude
hop_length = 512 # in num. of samples
n_fft = 256 # window in num. of samples

# perform stft
stft = librosa.stft(y, n_fft=n_fft, hop_length=hop_length)
spectrum = librosa.amplitude_to_db(np.abs(stft))
# calculate abs values on complex numbers to get magnitude
# spectrum = np.abs(stft)
# spectrum = np.log(spectrum + 0.00000001)
librosa.display.specshow(spectrum, sr=sr, x_axis="time")

print(spectrum.shape)
# Out:
# (129, 432)

# %% [markdown]
# # Salvar valores de espectrograma
#  - Pule esse passo se os arquivos já estiverem na pasta

# %%
#converter o audio para espectrograma:
# é nesse amplitude_to_dB que ele está convertendo para pressão sonora. Podemos explorar outras ponderações aqui. Se não tiver implementado, podemos implementar.
def gerar_espectrograma(y, sample_rate, n_fft=256, hop_length=512):
    # STFT -> spectrogram

    # perform stft
    stft = librosa.stft(y, n_fft=n_fft, hop_length=hop_length)
    # calculate abs values on complex numbers to get magnitude
    spectrogram = librosa.amplitude_to_db(np.abs(stft))
    # spectrogram = librosa.pcen(spectrogram)

    return spectrogram  # _positive, frequencies_positive

# %%
# Salvar espectrogramas na pasta específica (carros, serras etc)
def salvar_espectrogtramas (audio_clips, audio_path, spectrogram_path):
    numero_audios = len(audio_clips)
    num_arquivo = 1

    spectrogram_values = []
    
    for i, audio_name in enumerate(audio_clips):
        y, sr = librosa.load( os.path.join(audio_path, audio_name) )
        audio_name = audio_name.replace(".mp3", ".png")

        fullpath = os.path.join(spectrogram_path, audio_name)
        try:
            fft_spec = gerar_espectrograma(y, sr)
            
            fft_spec = 255 * (fft_spec - fft_spec.min()) / (fft_spec.max() - fft_spec.min())
            fft_spec = np.flip(fft_spec, axis=0) # put low frequencies at the bottom in image
            #fft_spec = 255 - fft_spec
            
            # Salva o arquivo e começa o próximo
            # np.savetxt(fullpath, fft_spec, delimiter=",")
            im = Image.fromarray(fft_spec).convert("L")
            im.save(fullpath)
            print("Arquivo %s salvo com sucesso." % fullpath)
                
        except Exception as e:
            print( "Erro ao salvar %s: %s." % (fullpath, e) )


salvar_espectrogtramas(audio_carro_clips, audio_carro_path, spec_carro_path)

salvar_espectrogtramas(audio_moto_clips, audio_moto_path, spec_moto_path)

salvar_espectrogtramas(audio_serra_clips, audio_serra_path, spec_serra_path)
# Out:
# Arquivo clean_audioset/stft/carros/(HD) - Forza 4 - Top Gear - Car Test - 1990 Lotus Carlton-0GZbu00-aMY.png salvo com sucesso.
# Arquivo clean_audioset/stft/carros/1968 Chevy Camaro - V8 327 - MUSCLECAR SOUND - restauriert-1ddvRm8MURI.png salvo com sucesso.
# Arquivo clean_audioset/stft/carros/1995 Toyota Supra FOR SALE-2-1wY_Ndtgw.png salvo com sucesso.
# Arquivo clean_audioset/stft/carros/2013 Porsche 911 Carrera Start Up and Review 3.4 L Horizontally Opposed⧸6 Cylinder-9BzZvj5W09s.png salvo com sucesso.
# Arquivo clean_audioset/stft/carros/95 Mustang drag car start up-1sjKon7lrLY.png salvo com sucesso.
# Arquivo clean_audioset/stft/carros/99 Trans Am WS6 - Donuts, Take-Offs, 110MPH!-G4Rp68qV_aw.png salvo com sucesso.
# Arquivo clean_audioset/stft/carros/A guy trying to start car after flood-0TGPaUN2V5Q.png salvo com sucesso.
# Arquivo clean_audioset/stft/carros/AX kit car-1-Vhr9Ut4Tg.png salvo com sucesso.
# Arquivo clean_audioset/stft/carros/Atlanta GA： 1999 Jeep Grand Cherokee - Ignition Lock  Problem!-vsGv0Xf_hMI.png salvo com sucesso.
# Arquivo clean_audioset/stft/carros/Audely End House and Gardens Stately House. Essex. England. English Heritage-1pKxZkeXe9w.png salvo com sucesso.
# Arquivo clean_audioset/stft/carros/Audi 90 ISMA GTO und Audi 200 TransAm-B4l-0zH00nI.png salvo com sucesso.
# Arquivo clean_audioset/stft/carros/BMW E46 M3 Drift Day in car-2ujlG9xd9NA.png salvo com sucesso.
# Arquivo clean_audioset/stft/carros/Best car sounds in the world Part 14.--nlq9Dz4NIk.png salvo com sucesso.
# Arquivo clean_audioset/stft/carros/Bold and Beautiful 1969 Camaro Muscle Car For Sale!-0hefQELmzq8.png salvo com sucesso.
# Arquivo clean_audioset/stft/carros/Brisca F1 Stock Car Racing Swaffham 13⧸8⧸2000 Semi FWJ Wainman Speak Lund Harrison Pearce Willis--V2t-Yt1_-0.png salvo com sucesso.
# Arquivo clean_audioset/stft/carros/CAMERA CAR FABIO CON PIT BIKE 125 cc CROSS 002.AVI-5MVE73rP6R8.png salvo com sucesso.
# Arquivo clean_audioset/stft/carros/CAR ACCIDENT ON JERICHO TURNPIKE-2WoOCPOfgAo.png salvo com sucesso.
# Arquivo clean_audioset/stft/carros/CWC Car Winter Cup - Záskalí 2006-0Ree10eqPN4.png salvo com sucesso.
# Arquivo clean_audioset/stft/carros/Car 66 Adrian Barker Stages - Warts and All!--t3ETssuUYQ.png salvo com sucesso.
# Arquivo clean_audioset/stft/carros/Car Crash Sound Effects-22QDZUi_oS0.png salvo com sucesso.
# Arquivo clean_audioset/stft/carros/Car Recycling in Russia 15.9.2012 ｜FMV｜-2sF7d4EYxsI.png salvo com sucesso.
# Arquivo clean_audioset/stft/carros/Car sound imitations 3--vBVkcJCZ7M.png salvo com sucesso.
# Arquivo clean_audioset/stft/carros/Circuit Of Ireland 2014 - Car 18--nyKu0ezRN8.png salvo com sucesso.
# Arquivo clean_audioset/stft/carros/City Car Driving 1.2.2 BMW M3 E36-6HMi-OYf0rI.png salvo com sucesso.
# Arquivo clean_audioset/stft/carros/Conduite de prototype⧸Drive a race car--XH1WiOPLRs.png salvo com sucesso.
# Arquivo clean_audioset/stft/carros/Custom 3 Car racing trailer (Toy Hauler) with tractor with sleeping Quarters for sale-3Mif39PORh8.png salvo com sucesso.
# Arquivo clean_audioset/stft/carros/Dead Rising： white car in the maitinence tunnel-2IDAWvi5alA.png salvo com sucesso.
# Arquivo clean_audioset/stft/carros/Dodge Cummins Rollin Coal!!-AiQoXi32QIA.png salvo com sucesso.
# Arquivo clean_audioset/stft/carros/Elnef Racing in new car from US 2010-3NBAnKg3YKU.png salvo com sucesso.
# Arquivo clean_audioset/stft/carros/Exhaust System Noise, Sounds like a Jet, bad catalytic converter？--K4R9SXZZsk.png salvo com sucesso.
# Arquivo clean_audioset/stft/carros/Fast Motorsports Catback '09 WRX sound clip in car-6QLZfL4SnR8.png salvo com sucesso.
# Arquivo clean_audioset/stft/carros/First ever Uber  car in Paris!---zLzL0sq3M.png salvo com sucesso.
# Arquivo clean_audioset/stft/carros/Fun car 7 Août 2011 St Christophe sur Guiers part.2-1N6OZ71Lvs0.png salvo com sucesso.
# Arquivo clean_audioset/stft/carros/GT4- Spoon Race car @ Citta Di Aria 1'25.568--whHfyc3-ds.png salvo com sucesso.
# Arquivo clean_audioset/stft/carros/GT40 Kit Car Test Drive-13_qekhjE4U.png salvo com sucesso.
# Arquivo clean_audioset/stft/carros/GTA 5 CAR MEETUP MP#3-1pAuLvy2K7o.png salvo com sucesso.
# Arquivo clean_audioset/stft/carros/GTA Car Repo Gone Wrong-1wU63KRlATQ.png salvo com sucesso.
# Arquivo clean_audioset/stft/carros/GTA IV Hit by my own car-0zwkWRoTW7k.png salvo com sucesso.
# Arquivo clean_audioset/stft/carros/GTR2： Spa 2008 Track in BMW Sauber F1 Car-1M_NPbRFjq8.png salvo com sucesso.
# Arquivo clean_audioset/stft/carros/Galatea Automobiles LLC Hyundai Tiburon Kit Car Body-3K-5ZZXUOO4.png salvo com sucesso.
# Arquivo clean_audioset/stft/carros/HONDA EK9 CIVIC VS DC5 INTEGRA ROLLING .RACE ⧸ CAMERA CAR EP3 CIVIC ⧸ NORTH CYPRUS MPG-2fVi79vgrUo.png salvo com sucesso.
# Arquivo clean_audioset/stft/carros/Hitchcock 39 Steps Car scene-3HiB7lqcJro.png salvo com sucesso.
# Arquivo clean_audioset/stft/carros/How NOT to drive a race car - Masterly demonstrated by Mr. Tommy Jagerwall-2weLpzs8h1o.png salvo com sucesso.
# Arquivo clean_audioset/stft/carros/How to sell your car gangstar vegas-2GOGdPSUAzg.png salvo com sucesso.
# Arquivo clean_audioset/stft/carros/IMCA Stock Car feature Boone Speedway 4⧸25⧸15-1Xt-GC4q1XI.png salvo com sucesso.
# Arquivo clean_audioset/stft/carros/In Car Footage of My Ride Along with Rob Primo-0t99Q6XnOPg.png salvo com sucesso.
# Arquivo clean_audioset/stft/carros/Insane golf car stunt-338ZA2jtFC4.png salvo com sucesso.
# Arquivo clean_audioset/stft/carros/Japanese girl cranking Renault 5 in black mary janes flats-c31HkFqWLAk.png salvo com sucesso.
# Arquivo clean_audioset/stft/carros/Kabul - Islamic Republic of Afghanistan - October 2011-5P3aq2BJYa0.png salvo com sucesso.
# Arquivo clean_audioset/stft/carros/LCPDFR 0.95  IN POLICE CAR RADIO SOUNDS IN GTA IV--8ZU97ub6l8.png salvo com sucesso.
# Arquivo clean_audioset/stft/carros/Lamborghini vs. Toyota Supra 900whp & Audi S2 PPR-1xzJrNhWvHk.png salvo com sucesso.
# Arquivo clean_audioset/stft/carros/Legend Car Flip at NHMS - Johnson Racing Team Camera-4H1CPHxSj1Q.png salvo com sucesso.
# Arquivo clean_audioset/stft/carros/Legends race car on eBay for sale--MFIdiRELg8.png salvo com sucesso.
# Arquivo clean_audioset/stft/carros/Let's Drive #46 Volvo XC90 ｜ City Car Driving [Download]--6YsMnBIJ-g.png salvo com sucesso.
# Arquivo clean_audioset/stft/carros/LittleBigPlanet- awesome suspension- by CVTURBO [HD]-qj5EUKfbk3A.png salvo com sucesso.
# Arquivo clean_audioset/stft/carros/Man claims he’s from a royal family in the Milky Way, vows to destroy the Earth if his car is towed-1QT_qLeT1hk.png salvo com sucesso.
# Arquivo clean_audioset/stft/carros/Mini Sprint Austin Waldrop Wins $50.00 fast car dash in Jackson MI.-0i6yVfazw90.png salvo com sucesso.
# Arquivo clean_audioset/stft/carros/Mini Stock Feature in car video, South Bend Motor Speedway-0X-WrjfJlys.png salvo com sucesso.
# Arquivo clean_audioset/stft/carros/Mobil 1 0W40 Engine Noise-B9n4a5ciI48.png salvo com sucesso.
# Arquivo clean_audioset/stft/carros/Motor City Freestyle with GR's Finest and 3S customs drifting-VliP9ufAS_o.png salvo com sucesso.
# Arquivo clean_audioset/stft/carros/Muscle Car Masters 2009 Eastern Creek HR31-2vkRgCaEqa8.png salvo com sucesso.
# Arquivo clean_audioset/stft/carros/Must See Racing Xtreme Sprint Car Series--lu5Ub2R5dQ.png salvo com sucesso.
# Arquivo clean_audioset/stft/carros/Mustang Day @ Sheehy Ford Dealership 2010-3bnqZuo6VOo.png salvo com sucesso.
# Arquivo clean_audioset/stft/carros/NFS SHIFT 2 Unleashed PC - Dubai Autodrome GP, car Nissan GT-R GT1-3Id9FCJr0lI.png salvo com sucesso.
# Arquivo clean_audioset/stft/carros/Old - 20+ Police Cars Chase Busted Up Car Blossom-6GJY_1ThSNY.png salvo com sucesso.
# Arquivo clean_audioset/stft/carros/Pakistan, Robot ,Car in peshawar university-1IB44BXXsEg.png salvo com sucesso.
# Arquivo clean_audioset/stft/carros/Paul Ricard Vintage In Car 1970 Ferrari 512S-3X2HRUzK4AA.png salvo com sucesso.
# Arquivo clean_audioset/stft/carros/Police  Euro Truck Simulator-45MeR1d_qck.png salvo com sucesso.
# Arquivo clean_audioset/stft/carros/Pontiac Firebird Trans-Am Engine Explosion-EkmKuR0RkZM.png salvo com sucesso.
# Arquivo clean_audioset/stft/carros/Power Gun Car Petrol-0mrM5kn3nHs.png salvo com sucesso.
# Arquivo clean_audioset/stft/carros/Punjab police wrongly make challan with driver in the car .-2-BcDQ7XO3Y.png salvo com sucesso.
# Arquivo clean_audioset/stft/carros/RALLY PORTUGAL HISTÓRICO 1-5EtFeil92p0.png salvo com sucesso.
# Arquivo clean_audioset/stft/carros/REPORT FROM JAPAN WATER POWERED CAR - PART 1 of 2-3aZL8JxAXFs.png salvo com sucesso.
# Arquivo clean_audioset/stft/carros/Rc car Brushless 3.5T motor-369yYdVycR4.png salvo com sucesso.
# Arquivo clean_audioset/stft/carros/Ring and pinion noise-5Jyk1kWjddg.png salvo com sucesso.
# Arquivo clean_audioset/stft/carros/Ritz car ki ma bhn done by Navjyoti..-0G7TnY4mqfU.png salvo com sucesso.
# Arquivo clean_audioset/stft/carros/Rocket Jet Car-08xtY_Ri9_Q.png salvo com sucesso.
# Arquivo clean_audioset/stft/carros/Seat ibiza Cupra 1.8L 20VT tuned by Tuning On Road-IMmJ-d84KG0.png salvo com sucesso.
# Arquivo clean_audioset/stft/carros/Special FX： Hit by a car-2gvYZI-3EA8.png salvo com sucesso.
# Arquivo clean_audioset/stft/carros/Spokane Police Responding to 3 car MVA--10fWp7Pqs4.png salvo com sucesso.
# Arquivo clean_audioset/stft/carros/Spongebob gets hit by car-1pHQVwWGn5M.png salvo com sucesso.
# Arquivo clean_audioset/stft/carros/Super Car Racer Saves Fellow Driver - deadly accident in race-0rTJcu_B3HA.png salvo com sucesso.
# Arquivo clean_audioset/stft/carros/The Hello Kitty Car - Orange County： http：⧸⧸dixonteamoc.com-1u7TH0u5ZNY.png salvo com sucesso.
# Arquivo clean_audioset/stft/carros/The Walking Dead's Carol gets hit by a car (S05E06)-03nkVP0cLuo.png salvo com sucesso.
# Arquivo clean_audioset/stft/carros/Top 32 FWD Honda's Drag Racing Turbo-gowumAdMWss.png salvo com sucesso.
# Arquivo clean_audioset/stft/carros/Traffic flow from spore's woodland checkpoint-4xnLQcJUdDQ.png salvo com sucesso.
# Arquivo clean_audioset/stft/carros/Travis Pastrana Sets World Record for Rally Car Jump 12⧸31⧸09-5dl-wbBdUnI.png salvo com sucesso.
# Arquivo clean_audioset/stft/carros/Triumph Spitfire 2500 car cam-1BljQ6AdSbM.png salvo com sucesso.
# Arquivo clean_audioset/stft/carros/Turbo nissan patrols in Dubai-WOSCX6icco0.png salvo com sucesso.
# Arquivo clean_audioset/stft/carros/Two Dudes in a Car： Skoda Octavia 1.8 TSi review--aVWxd6fwWo.png salvo com sucesso.
# Arquivo clean_audioset/stft/carros/World of Outlaws 2002 Sprint Car Race Las Vegas-0j-hv9nYhLI.png salvo com sucesso.
# Arquivo clean_audioset/stft/carros/Worst car ever  - YUGO-0GE_Bb1-92c.png salvo com sucesso.
# Arquivo clean_audioset/stft/carros/X-Fest 2008 _ X-Runner Rollout-1QaAJA5AeAI.png salvo com sucesso.
# Arquivo clean_audioset/stft/carros/Xanavi Nismo GTR vs. Citroen GT race car (GT5 online gameplay)-2Pqudye4emA.png salvo com sucesso.
# Arquivo clean_audioset/stft/carros/camera car mugello 11⧸09⧸2011-63tiML2mzEU.png salvo com sucesso.
# Arquivo clean_audioset/stft/carros/car accident ...-1zDcIMiEM18.png salvo com sucesso.
# Arquivo clean_audioset/stft/carros/mazda 626 klze burn out and dog chases car-0FV4FoNZURg.png salvo com sucesso.
# Arquivo clean_audioset/stft/carros/skoda felicia kit car nizamis motorsport 4-1nB9kHptkrI.png salvo com sucesso.
# Arquivo clean_audioset/stft/carros/touring cars crash restart after safety car croft circuit 14⧸6⧸09--bgRXF8G8WY.png salvo com sucesso.
# Arquivo clean_audioset/stft/carros/പുലിമുരുകൻ ഷൂട്ടിംഗ് ലൊക്കേഷനിൽ ഉണ്ടായ കാറപകടം-0_zLL39nfoM.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/100% attention, 100% of the time - Danger around the bends-49H9cty2Nfk.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/1978 Suzuki DS 185 Demo, 7 May 15-5BgJKx7Kkwc.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/2001 Kawasaki Ninja ZX6R - For Sale - Newton Motorcars-2QqLKkqEg44.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/2003 Yamaha R6 Special Edition (ON SALE!!!) $4,999-7BUhuRCSRgc.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/2007 Yamaha V-Star 1100 Silverado Classic-8b0tC2eLNOk.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/2008 Yamaha V-star 1100 Custom Hard-Krome Big Straights-7-bG394pYps.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/2008 zx10r dyno run--7gC66Xp1iY.png.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/2010 Ducati Streetfighter s-1PV6TCRQTok.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/2011⧸2012 QIRRCH Round 7 Highlights 26-5wpmjCOnunA.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/2014 Arctic Cat ZR7000 LXR - Yamaha engine sound-7qZqAraRFco.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/2014 Beta 450 RR Motorcycle Walk Around, 3 Seas Recreation, American Beta Motorcycle-8At-88WYYe8.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/2014 Kawasaki Z1000 dyno run-05Z4emmS7IE.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/400ex 460 stroker.-4V8UeW_t_U8.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/ARDIE RBU 350 erster Probelauf ⧸ vintage motorcycle first run-6kofP5LGVoU.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/Alpha Sport Cobra 180RS Quad-7Ybm8eUMEww.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/Around the block on Mike's `49 HRD Vincent, Black Shadow-3edhLN5jwvU.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/Backyard Pitbike Session Part 1-43FtdwYnMjA.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/Bean're interviewing spectators when a fire broke out on the Cannonball Motorcycle Rally-2p9WJ6wdHR8.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/Big pit pro 125cc RR-3vPuVLFnSX4.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/Booster 70 Dr On Board  Test Drive  Sound Arrow extreme HD-0p68pGdkUnE.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/CBR 125 Bike RIde-0BGmq-cu28w.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/CRF 450X Flaming Two Brothers Exhaust-22SLpBN31R0.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/Can Am MX500 -1985--3-t7Sm6un0.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/Classic motorcycle and car meeting in Nessebar, Bulgaria--pdljKJHPgg.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/Cleveland Cyclewerks tha Heist Updated Widow Kick started to life-8W2jnBkwMF0.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/Comine 19⧸03⧸16 KTM électrique-5gDn97zTkKs.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/Como tirar o filtro de ar da pop-9h1qTbIOiDs.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/Crazy Dog on Motorcycle-6RZA3VBca6Q.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/Crazy Mad Man Cycling Too Fast - Rides it like he stole it!---p-rk_HBuU.png.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/Credit loans insured motorcycle traffic car part 3.1-2FjwjCaIvo4.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/Crocodile tries to eat lawnmower-5CQU7-RISwA.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/DRZ Wheelie Practice and Wheelie Vlog-66j22lKCjQc.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/Daves MTX 125 - Fix and Test.-25Q3ZhL4me8.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/Derbi Antorcha funcionando.-6-mlwMzZ2Ow.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/Ducati 848 akrapovic cold start-1ZzPc9NkJsg.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/ENA DUGMA APO THN BOLTA TON STREET THUGS..!!-1e2uAdWaMBk.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/Flash Flood High Desert California 7⧸19⧸2015 - Shadrach Max-2cx1ZH-uolA.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/GPZ turbo rattle-2eG8jc_R46E.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/Ghostrider vs baddog and walt and hitman vs jb--QDkHHg5U2s.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/Group Ride： 4 Ducati, 2 Yamaha. 1 Kawasaki, 1 Suzuki, 1 Cagiva, 1 Bmw-4tRlgk--1ro.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/Großer Preis von Deutschland für Motorräder 1966 - Hockenheim-3UPGjswFukU.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/Guy Martin Big brew @ J&S Leicester 2014 - FZ8 Dyno run-9kSBEpCCnZQ.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/Gymineer - Dirtbiking-5Kx-mPqbvMU.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/HONDA CBF 600S Dominator exhaust-4gmq40xxXYA.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/HONDA CBF500 & SUZUKI GS500 & KAWASAKI ZX6R-6iOyPTnANbw.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/Hayling Island Scooter Rally Rideout 2014-8IBW3vNa0Ao.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/Honda ATC 70 r55 Suspension Kit-7OrTMrrIO9s.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/Honda TRX400ex HMF exhaust sound test-0axKgORkskQ.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/Honda VT1300CS Sabre 2010   COBRA Speedster Swept exhaust 2)--wfzJ1-A5Lc.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/Honda Valkyrie first engine start for season 2016 - pure sound-6N2spJt3rJA.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/Honda cbr 1000 rr 2005 Arrow Exhaust-50vWlNDf7DU.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/Insane Kawasaki Z750 revving engine sound-3P4lqzK93hA.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/Jawa Mustang 50 Bydgoszcz-2yHraFzb4nk.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/KAWASAKI ZX12R THE PUNISHER-9vm-7s2IOOA.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/KTM RC 200 with Custom Exhaust Street Ride Malaysia-A82I0f3o6ls.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/Kawasaki EN450 For Sale-8_GuQcMAsVk.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/Kawasaki ER-6n city ride-5Dgh1Ig3LCc.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/Kawasaki Versys 1000 LT Tourer review, ride and walkaround-7EjRKWgdBB8.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/Kimco zing 2 Dark side--jnOQkG1gMs.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/Ktm 525 EXC, Yamaha yz250 spring-1BE_jg5lAoM.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/Lifan Mohicano LF125-14B-7OWbCcSxvtA.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/Little vid of my 1998 Honda VFR800-0GO42Oh_vmA.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/MHR Big Bore 77cm³ 25,5 PS Timbo [RTSA]-1-4xqkRfFFc.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/Moto Guzzi chasing a Ducati down California hwy 58-6EtPQjLv0Qk.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/Moto guzzi convert--KdcpwL9psc.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/Moto guzzi convert--KdcpwL9psc.png.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/Motocavalcata Biccari sunday motorrad 21-53Cg6CCOfLI.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/Motorbike in Snow-0-SKeZDZyBw.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/Motorcycle exhaust noise inspection-8_4ihqmQcEM.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/Panstock 2010 - Panhead abuse-904NEWYQHYo.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/Philly hang gang-9zzMIhJt88w.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/Piaggio New skipper st 125 4T (2002), carbon wrapped and Scorpion exhaust.-44mltXF7vus.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/Piaggio Typhoon dyno run.-6WuAyuoXdp4.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/R1200GS on autobahn-7ggqUV_ZXlA.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/RSA - LONAVALA  MEET-8FolS1uHIO0.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/Run spitro corsa-40Rk-qrom-g.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/SUZUKI SV1000 VTWIN DALE WALKER HOLESHOT HIGHMOUN-42dlHFmHm60.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/Samuraiscoot - Zuma 125 stage 1 power run  0-100 metres --- 3-4iIkq9alb2A.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/Sound of Daytona 955i-85iZTkKSuXM.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/The 2016 version of the 124＂ Sportster. New ISR⧸Öhlins front end fitted-3GM6nBXu810.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/Tomos Airsal Ride 2-6YkQxD39Ksc.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/Traffic flow from spore's woodland checkpoint-4xnLQcJUdDQ.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/Trilha de Moto em macacos, Nova Lima  MG,  Tequila16-9jPnDG8OROU.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/Vortex vs Stock ECU 2009 yfz450r-74INCGkScu8.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/Wheel light motorcycle led wheel lights custom-1o0omq48-Cs.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/XJ 600 N Delkevic--sRJV2Bp1Ko.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/Yamaha MT-03-9YsJzxOb2Xc.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/Yamaha V-Star XVS1300 with stock pipes 2...-9bg2qmxNL_0.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/Yamaha VMAX-72rtamiUx-0.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/Yamaha WR 500 First Ride.mov-9KP4VYG2h_4.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/Zard Exhuast on a Ducati Monster S2R800-7kEs6ZWjHDY.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/bashan 300 výfuk Yamaha-6CNQ4Cy_qB0.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/bike accidents ： kids on bikes-7zTeDP6rEW0.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/blata B1 origami-27gjol4VSOE.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/chillin with graham jarvis on ktm freeride 350-4On13H4Jpbo.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/honda 200s mud bogging-2o5UzAtVVzY.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/minha sete galo urrando.mp4-9GpJP8V1gEs.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/motorcycle fly by-9BFaxToEQo4.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/motorcycle run-3ybsl7FEF0U.png salvo com sucesso.
# Arquivo clean_audioset/stft/motocicletas/the sound of horse power is back at the wally world gokart track [part 2]-4HBpU0TRpYg.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/1996 mcculloch mac 3200 chainsaw-ir3ipI5k1kI.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/Abattage chandelle liquidambart vs ms 660 guide de 55-Nszf2gBWruU.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/Alaskan saw mill-Jci_knX9g1I.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/Beezone бензопила М.mpg-Y4JfR36zPi4.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/Brian cutting down our mostly dead birch tree.m4v-mnfToxaQAgc.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/Bucherons2015-aqhELp8-o_c.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/Burnett Model B6 Chainsaw 125cc Villiers engine-Apudgyyvhvs.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/Caribou Creek Handcrafted Log Home -- 1775 LH -- Anaya -- YD -- 072909 -- 5 Arch part 3-Qb0LUJzJf64.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/Chainsaw Husqvarna 560 XP-WHzUPzWkST0.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/Chainsaw faceting with Aaron Hammer： Making circles with a chainsaw-pWRMgo0BGhU.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/Cuesta la pared Coamo 2-nkOXb95N0LU.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/DSCN2587.MOV Jonsered 370 chainsaw-4j2KuWhT_Ss.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/Dolmar 7900 + ＂Wojo＂-muffler--XVu2GZypIY.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/Dolpima BK3A Polnische Oldtimer Motorsäge-Hj5EYl2b91Q.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/Echo Timberwolf CS590 review-HNhLJa-cU-Y.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/FSI Baumstumpffräse Avant 528+-MfiszhvwDzI.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/Felling a Tree Bigger than Your Chainsaw-axr1fuHMcmA.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/Ford F150 Ecoboost Torture Test： HaulingTimber shot on the 5D MK II with Zeiss CP.2 compact primes-xQh4jY4n5_g.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/Handmade Chainsaw Base-5a_LPLNtBQs.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/Hepsiparis.Com - Oleo-Mac 952 Motorlu Testere-6-DAiSEzRA4.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/Hoss's 990g-rhGSqHtz_C4.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/Husqvarna 346xpg - Gopro HD-FGJQ3KC-Geo.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/Husqvarna 536 li XP-LXkUfPG3jKo.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/Husqvarna Longest Bar-zhFcXNK076k.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/Husqvarna NE346XP-BpBBVyd28e8.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/I need a new chainsaw-DZeyWdZ7yxw.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/Jonsered 2153 Vs Tölgy-_if557QC-zE.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/Jonsered Cs 2153 chainsaw-2XVl8t1-XOM.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/Linnunpönttö kelopuusta-TeDqdC16Wn0.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/Little Hot Saw-24ywlO1l1mE.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/MALL 2 man comes to life-t2pD_W3k-Ak.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/MS150TC After Ignition Timing Advance-jSCzPxHOfRI.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/Mann fährt mit Motorsäge auf Eis-pFo39HyyuYQ.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/McCULLOCH RACING ENGINE CONVERTED FROM CHAINSAW MOTOR-SGdSYIOgeSg.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/McCulloch 35cc chain saw-1B6kKOARYBo.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/McCulloch Pro Mac 610 60cc (3.7CI)-ez3rWlm8AcM.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/McCulloch saw motor conversion for go kart-nhtNK6LhBkg.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/Modified Mini ATV 110cc SEMI Selfmade ATV Quad Custom-9D32xsXlQeQ.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/Motorka MKS 35⧸35 Royal--eEZX4WFrcI.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/My first attempt at chainsaw carving.-aJb09Ttp69Q.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/New Toys - Lawn Mower, Leaf Blower, Chainsaw #3-zICNzWYJQ2o.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/Open face cut-XJSRthb6Fsw.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/PARTNER K650 STONE SAW-nI1USLL8NoI.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/Piaggio Typhoon dyno run.-6WuAyuoXdp4.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/Power Products Motorized Tricycle-NEXGbwxyG1k.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/Priprema za zimu ( DOSE )-5CWAf-BtBCQ.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/Prototipo caseiro motosserra Victor Sapage-n728Z-oMHck.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/Quarter sawing using chainsaw mill part 2-SzVhTvU4FCE.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/Resident Evil 4 HD： Walkthrough Part 3 - Chainsaw Man!!!-HPmDHUD51EI.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/Récolte d'arbres Douglas pour la Pessière.-FJeQBOfG7p8.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/STIHL GS 461 Rock Boss® Concrete Cutter ｜ Features and Benefits-uFlqr0wsWDc.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/STIHL HS75⧸HS80⧸HS85 PETROL HEDGE CUTTERS, 28＂ 30＂ TRIMMERS PROFFESIONAL-C5hCSx7GDns.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/STIHL MS 250 chainsaw cold start - 20-9qFy1anZ--M.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/Secho E 2000 Elektrikli Testere-i7gsZHbY2YI.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/Skidder vtt.wmv-2Jtfxu0vob4.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/Solo 681 felling a big spurance-m9caDFvU-9Q.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/Stihl 009L Arborist Chainsaw-93C94T6TfhA.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/Stihl 038 AV chainsaw-08zhZZn29jc.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/Stihl 064 lives 04-2009-ZQykT3D3lU4.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/Stihl 461-hA-xWwrOHnw.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/Stihl MS 250-K3SfuXPpHoo.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/Stihl MS 291-y_vMcXBq8FA.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/Stihl MS-460 Magnum-snlHJ9SOY0I.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/Stihl MS260C-hiUE_Q2RclA.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/Stihl MS271 20＂ cutting pine-TkpRorcLW38.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/Stihl MS441  Chainsaw-uGfJYGv-zuo.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/Stihl MS661 Chainsaw-AQtZz6xvwPA.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/Stihl vs. Husqvarna 1. CUP 1.5.2012-rb4UrhNo8dY.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/Sägen mit Stihl 024AV-M9mBJmt4EXs.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/Thai Chainsaw-dk5RqoGEcTM.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/The Secret to Sawing a Destiny Series Curved Bench from Tree2Table.com-pg31m8cTJYw.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/The chainsaw guy log testing McCulloch 125 101B chainsaw 8 16-fYpJldeYjOw.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/The correct way to fell large trees-ZUo0XMQ68AA.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/Tree felling and skidding with mini grapple skidder Goldoni Euro 45 - DIFFICULT !-CkrgwaCkcio.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/Tree job with 460 pt1-duzpidPK6zI.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/Trees To Timbers Chainsaw Mill part 2⧸3--PiosLMNwDc.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/Uomo che si arrabbia con la motosega-drDP3svhpuE.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/Zenoah engine chainsaw ゼノア エンジン チェーンソー-ZqmCvcsPOH0.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/aprire birra con motosega san pellegrino-6tXkKR9EU6w.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/chain sawing the big tree regular speed-d5AKgq5JDBA.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/chainsaw skil 933  type1 sold-0NOfrBTZC_M.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/cutting branches over power lines-59svx6RTX6E.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/echo gt225 curved shft weed trimmer-9vPMaY9f540.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/first mod on the 460-tZUBvalpY_k.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/home made chainsaw mill-DwE0cQ3Xz70.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/husqvarna 40-z13omhGxAeQ.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/hızar  motoru nasıl kullanılır hüsamettin-WDAxpni8Dkk.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/large defected water oak removal-d9QM-2K9jPA.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/mit der Stihl MS 241 C-M bei der Sturmschadenbeseitigung-DA2ECI9KQV8.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/motorkettingzaag cursus IVN Hardenberg-FeSvAVZXKAA.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/motoseghe stihl ms880 e 023 in taglio pioppo-Vwfzey2Fwq4.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/pocket bike first ride-o2z2ugX9VcA.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/poulan 2800 vs. husqvarna 346 oe-fZPf86wPZiQ.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/precision pumped concrete ⧸ precision poured concrete-kxP-x1bcpc4.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/stihl 460 vs. ported 026 w⧸044 carb-F8J19Klc2Eg.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/stihl ms-660-ttsVYFpBAPA.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/wild beehive-Msh94MTYC6A.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/Пила пилит сама-IDvzopNK304.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/찻상 톱조각  (엔진톱 조각 )-kCYMnkqTkQ8.png salvo com sucesso.
# Arquivo clean_audioset/stft/motosserras/＂The Machine＂ Jesse Green in Guess The Chainsaw Sculpture？-b55EUpsB6oA.png salvo com sucesso.

# %% [markdown]
# # Treinamento e teste de rede neural

# %%
# Carregar espectrogramas com uma CNN e classificar entre "motosserras e não motosserras"

espectrogramas_carro = sorted(os.listdir(spec_carro_path))
espectrogramas_moto = sorted(os.listdir(spec_moto_path))
espectrogramas_serra = sorted(os.listdir(spec_serra_path))

spectrogram_list = []
labels = []

print(espectrogramas_carro)
# Out:
# []

# %%
def cortar_espectrograma(spectrogram, largura_janela=128, altura_janela=128):
    largura_spec = spectrogram.shape[0]
    altura_spec = spectrogram.shape[1]
    spectrogram_slices = []

    for h in range(altura_janela, altura_spec, altura_janela):
        for w in range(largura_janela, largura_spec, largura_janela):
            slice = spectrogram[w-largura_janela : w,   # largura
                                h-altura_janela : h,  # altura
                                np.newaxis]
            spectrogram_slices.append(slice)
            
    return spectrogram_slices


def adicionar_rotulos_spec(espectrogramas, spec_path, lbl, spectrogram_list, labels):
    for filename in tqdm(espectrogramas):
        full_filename = os.path.join(spec_path, filename)  
        spectrogram = np.array(Image.open(full_filename))
        print(spectrogram.shape)
        spectrogram_slices = cortar_espectrograma(spectrogram)
        spectrogram_list += spectrogram_slices

        labels += [lbl] * len(spectrogram_slices)
        
        # 0 corresponde aos carros e motos
        
print("Cortando imagens e adicionando os rótulos...")

adicionar_rotulos_spec(espectrogramas_carro, spec_carro_path, 0, spectrogram_list, labels)
adicionar_rotulos_spec(espectrogramas_moto, spec_moto_path, 0, spectrogram_list, labels)
adicionar_rotulos_spec(espectrogramas_serra, spec_serra_path, 1, spectrogram_list, labels)

spectrograms_array = np.array(spectrogram_list)
labels_array = np.array(labels)

X_train, X_test, y_train, y_test = train_test_split(
    spectrograms_array, labels_array, test_size=0.2  # , random_state=42
)

# %%
# Initialize the model
print(X_train.shape)
model = Sequential()

# Add convolutional layers
model.add(Conv2D(32, (3, 3), input_shape=(X_train.shape[0], X_train.shape[1], 1)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(128, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

# Flatten the output before fully connected layers
model.add(Flatten())

# Fully connected layer with dropout
model.add(Dense(256))
model.add(Activation('relu'))
model.add(Dropout(0.5))

# Output layer with softmax activation
model.add(Dense(1, activation='sigmoid')) # Binary classification

# Compile the model
model.compile(loss='binary_crossentropy',
              optimizer=Adam(learning_rate=0.0001),
              metrics=['accuracy'])

# Print model summary
model.summary()
model.fit(X_train, y_train, epochs=25, validation_split=0.2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/gustavo/OneDrive_gustavotorres@ipt.br/Ciclo 3/Greenbug/Codigos/stft_espectrograma.ipynb Cell 12 line 2
#       <a href='vscode-notebook-cell:/home/gustavo/OneDrive_gustavotorres%40ipt.br/Ciclo%203/Greenbug/Codigos/stft_espectrograma.ipynb#X14sZmlsZQ%3D%3D?line=0'>1</a> # Initialize the model
# ----> <a href='vscode-notebook-cell:/home/gustavo/OneDrive_gustavotorres%40ipt.br/Ciclo%203/Greenbug/Codigos/stft_espectrograma.ipynb#X14sZmlsZQ%3D%3D?line=1'>2</a> print(X_train.shape)
#       <a href='vscode-notebook-cell:/home/gustavo/OneDrive_gustavotorres%40ipt.br/Ciclo%203/Greenbug/Codigos/stft_espectrograma.ipynb#X14sZmlsZQ%3D%3D?line=2'>3</a> model = Sequential()
#       <a href='vscode-notebook-cell:/home/gustavo/OneDrive_gustavotorres%40ipt.br/Ciclo%203/Greenbug/Codigos/stft_espectrograma.ipynb#X14sZmlsZQ%3D%3D?line=4'>5</a> # Add convolutional layers
#
# NameError: name 'X_train' is not defined

# %%
model = Sequential()
model.add(Conv1D(16, 3, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(MaxPooling1D(2))
model.add(Conv1D(32, 3, activation='relu'))
model.add(MaxPooling1D(2))
model.add(Conv1D(64, 3, activation='relu'))
model.add(MaxPooling1D(2))
model.add(Conv1D(64, 3, activation='relu'))
model.add(MaxPooling1D(2))
model.add(Conv1D(64, 3, activation='relu'))
model.add(MaxPooling1D(2))
model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='adam', loss='binary_crossentropy', metrics='accuracy')
model.summary()
model.fit(X_train, y_train, epochs=100)#, batch_size=64)

# %%
# model.fit(X_train, y_train, epochs=30)
y_pred = model.predict(X_test)[:, 0]
y_pred = np.round(y_pred)
acc = len(np.where(y_pred == y_test)[0]) / len(y_test)
print("Acurácia:", acc)
# Out:
# 6/6 [==============================] - 2s 285ms/step
# Acurácia: 0.7586206896551724

# %%
#ref: https://www.kaggle.com/code/msripooja/steps-to-convert-audio-clip-to-spectrogram
import os
import matplotlib.pyplot as plt
import numpy as np
import skimage.io as io
import librosa
import librosa.display
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
from tqdm import tqdm
from keras.losses import CategoricalCrossentropy
from keras.models import Sequential
from keras.layers import GRU, LSTM, Dense, Conv1D, MaxPooling1D, Flatten, Dropout, Activation, TimeDistributed

#to play audio
import IPython.display as ipd

audio_carro_path = "./audioset/carros/"
audio_moto_path = "./audioset/motocicletas/" #caminho onde estão os arquivos de audio
audio_serra_path = "./audioset/motosserras/"

spec_base_path = "./audioset/mfcc_vetor"
spec_carro_path = os.path.join(spec_base_path, "carros")
spec_moto_path = os.path.join(spec_base_path, "motocicletas")
spec_serra_path = os.path.join(spec_base_path, "motosserras")
 
os.makedirs(spec_base_path, exist_ok=True)
os.makedirs(spec_carro_path, exist_ok=True)
os.makedirs(spec_moto_path, exist_ok=True)
os.makedirs(spec_serra_path, exist_ok=True)

# %%
audio_carro_clips = sorted(os.listdir(audio_carro_path))[:250]
print(f"Número de arquivos .wav na pasta {audio_carro_path}= ",len(audio_carro_clips))

audio_moto_clips = sorted(os.listdir(audio_moto_path))[:250]
print(f"Número de arquivos .wav na pasta {audio_moto_path}= ",len(audio_moto_clips))

audio_serra_clips = sorted(os.listdir(audio_serra_path))[:500]
print(f"Número de arquivos .wav na pasta {audio_serra_path}= ",len(audio_serra_clips))
# Out:
# Número de arquivos .wav na pasta ./audioset/carros/=  250
# Número de arquivos .wav na pasta ./audioset/motocicletas/=  250
# Número de arquivos .wav na pasta ./audioset/motosserras/=  500

# %%
#aqui está selecionando o primeiro arquivo da lista, pode ser feito um for para pegar todos de uma vez
#verificar esse sample rate
x_carro, sr_carro = librosa.load(audio_carro_path+audio_carro_clips[0]) 
x_moto, sr_moto = librosa.load(audio_moto_path+audio_moto_clips[4]) 
x_serra, sr_serra = librosa.load(audio_serra_path+audio_serra_clips[6]) 

print(type(x_carro), type(sr_carro))
print(x_carro.shape, sr_carro)

print(type(x_moto), type(sr_moto))
print(x_moto.shape, sr_moto)

print(type(x_serra), type(sr_serra))
print(x_serra.shape, sr_serra)
# Out:
# <class 'numpy.ndarray'> <class 'int'>
# (220500,) 22050
# <class 'numpy.ndarray'> <class 'int'>
# (220500,) 22050
# <class 'numpy.ndarray'> <class 'int'>
# (220500,) 22050

# %%
import librosa.display
import matplotlib.pyplot as plt
y, sr = librosa.load(audio_serra_path+audio_serra_clips[10])
plt.plot(y);
plt.title('Signal');
plt.xlabel('Time (samples)');
plt.ylabel('Amplitude');

# %%
# fig, ax = plt.subplots(nrows=4, ncols=3, sharex=True)

# librosa.display.waveshow(y, sr, ax=ax[i, 0])  # put wave in row i, column 0

mfccs20 = librosa.feature.mfcc(y=y, sr=sr)
librosa.display.specshow(mfccs20, sr=sr, x_axis= z'time')

mfccs128 = librosa.feature.mfcc(y=y, sr=sr, hop_length=512, n_mfcc=40)
librosa.display.specshow(mfccs128, sr=sr, x_axis='time')

mfccs = mfccs128
print(mfccs.shape)
# Out:
# (40, 431)

# %% [markdown]
# # Salvar valores de espectrograma
#  - Pule esse passo se os arquivos já estiverem na pasta

# %%
TAMANHO_IMAGEM = 128

#converter o audio para espectrograma:
# é nesse amplitude_to_dB que ele está convertendo para pressão sonora. Podemos explorar outras ponderações aqui. Se não tiver implementado, podemos implementar.
def gerar_espectrograma(y, sr):
    mfccs = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=TAMANHO_IMAGEM)
    # mel_spect = librosa.power_to_db(mfccs, ref=librosa.feature.mfcc(S=librosa.power_to_db(S))np.max)
    return mfccs


def cortar_espectrograma(spectrogram, tam_corte=TAMANHO_IMAGEM):
    tam_total = spectrogram.shape[1]

    # Cortamos o trecho desejado na região do meio do áudio
    inicio = tam_total // 2 - (tam_corte // 2)
    fim = tam_total // 2 + (tam_corte // 2)
    
    return spectrogram[:, inicio:fim]

# %%
# Salvar espectrogramas na pasta específica (carros, serras etc)
def salvar_espectrogtramas (audio_clips, audio_path, spectrogram_path, audios_por_arquivo=50):
    numero_audios = len(audio_clips)
    num_arquivo = 1

    spectrogram_values = []
    
    for i, audio_name in enumerate(audio_clips):
        y, sr = librosa.load( os.path.join(audio_path, audio_name) )
        audio_name = audio_name.replace(".mp3", ".csv")

        fullpath = os.path.join(spectrogram_path, audio_name)
        try:
            mfcc_spec = gerar_espectrograma(y, sr)
            mfcc_spec = cortar_espectrograma(mfcc_spec)
            
            # Salva o arquivo e começa o próximo
            np.savetxt(fullpath, mfcc_spec, delimiter=",")
            print("Arquivo %s salvo com sucesso." % fullpath)
                
        except Exception as e:
            print( "Erro ao salvar %s: %s." % (fullpath, e) )


salvar_espectrogtramas(audio_carro_clips, audio_carro_path, spec_carro_path)

salvar_espectrogtramas(audio_moto_clips, audio_moto_path, spec_moto_path)

salvar_espectrogtramas(audio_serra_clips, audio_serra_path, spec_serra_path)
# Out:
# Arquivo ./audioset/mfcc_vetor/carros/#5) Project ForkenSwift electric car： shifting gears-Liqv3KgXThk.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/$150 car jump-1aCyNnYNWvA.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/'87 Honda Mugen Motul Civic Si Race Car at Costa Di Almafi GT4-28SbkfcA6kE.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/'０７ STREET CAR SHOW  ＃６ 大黒２--NBRp5qsrYQ.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/(16) Car Cam： 2 mobile speed cameras, speed racer & scenic esplanade route-2JAjo7yVCgs.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/(HD) - Forza 4 - Top Gear - Car Test - 1967 Chevrolet Corvette Stingray 427--v2FkuCVLjo.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/(HD) - Forza 4 - Top Gear - Car Test - 1980 Lotus Esprit Turbo-1Z3ciuA3Y3o.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/(HD) - Forza 4 - Top Gear - Car Test - 1982 DeLorean DMC-12-1zjyiznZSPY.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/(HD) - Forza 4 - Top Gear - Car Test - 1983 Volvo 242 Turbo Evolution--IsCA5lBN74.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/(HD) - Forza 4 - Top Gear - Car Test - 1990 Lotus Carlton-0GZbu00-aMY.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/(HD) - Forza 4 - Top Gear - Car Test - 1993 Nissan Skyline R32 GT-R V-Spec-2NDS2MNq5dk.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/(HD) - Forza 4 - Top Gear - Car Test - 2000 Honda Integra Type-R--PuWinl2B1s.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/(HD) Celebration Exotic Car Rally 4-15-2012-1cFoiMAX0jk.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/(HD) GTA V Epic Highway 5 Star Car Chase (Adder)-4VJSDVXGuqM.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/(Heat 1) Ahmed Tarek - Red Bull Car Park Drift (CPD) 2013 أحمد طارق دريفت ريد بول-1nayT4f9V-k.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/(PART 2~leaving the lots) Paul Walker Memorial Cruise and ROWW Charity Car show Saint Louis--jiyGQfbwt0.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/(PUNISH) VR Commodore @ winton performance car mania-1A4uFF5oTyA.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/03⧸02⧸14：  Clear video of stalker car with license plate 194 VJ9--arHLKEP5LY.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/07 BMW 335i vs 450whp 240sx-0jrhe6OFw-E.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/1200 horsepower Smart car - Wheelie Every Gear -  Forza 4--HVg-i88xE0.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/1280P HD 2.5＂ LCD NIGHT VISION CCTV IN CAR DVR ACCIDENT CAMERA Video Recorder-4eEOO9tzA1U.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/12th Annual Popular Hot Rodding Championships- Funny Car-11cctCD0ATQ.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/1300 Saloon Stock Car - Lochgelly (World)-5CjYO0nqgW8.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/150 Race Car Hits Cameraman-1P6NL71uTiY.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/154 kp⧸h RC car crash into woods-18C6WBVH9zg.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/15ο ΡΑΛΛΥ ΚΟΡΙΝΘΟΥ 2011 HYUNDAI ACCENT A6 ΓΙΩΤΗΣ - ΒΟΤΣΗΣ IN CAR-3DVoDho5RKY.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/1600 rally car 2--qffkib86ZE.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/1600 rally car action-0MryoXgDsQo.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/16th STREET CAR NATIONALS SUZUKA　②-2IgRckLK_wk.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/17 12 53 เช้าข่าวข้น ตอมแมลงวัน ศักดิ์ นานา-T40AD-E3ci4.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/17 Josh Baughman Sprint Car Flip @ SNMS 5⧸26⧸12-3HIukeVux1o.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/18-08-2012 car hit a pedestrian ⧸ кола удря пешеходец-2wKP1A8On1E.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/1800 Hp Ford GT-02tl_ek8f9I.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/1954 Dodge Firearrow Concept Car-1QZ_F_qnbqY.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/1957 Chevy  burnout at Pocono Racetrack~Good Guys car show-1Ap7QLh9i1o.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/1959 Austin Healey Bug Eye Sprite, AZ Car, Full Restored, Part II of II： Driving Video, SOLD.wmv-1h4yo1bshVQ.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/1964 Vintage Stock Car Chevelle Malibu Barn Find-32Mor3kITQk.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/1965 Pontiac GTO Twisted Sister Hot Love video car-1gCLyNJvEms.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/1968 Chevy Camaro - V8 327 - MUSCLECAR SOUND - restauriert-1ddvRm8MURI.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/1968 camaro drag car-1AeSZdAUfQ0.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/1969 Plymouth Barracuda Fastback Classic Muscle Car V8 Take Off-0Nkp6zb82xY.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/1970 Plymouth 340 Barracuda 9.50 ET Drag⧸Street Car owned by Ken Maisano-0yGNtfAA39Y.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/1972 Volkswagen Standard Beetle 1600cc-uciYg8Oz87I.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/1976 Cadillac Eldorado Convertible Drop Top. 500 cu Motor Congressmans car-BeILNH0jSVg.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/1976 Ford Granada-O9_oZ_c5yFg.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/1977 Pontiac Trans Am X275 car huge wheelstand at No Mercy 5 Quarter finals-2bqqIXMWXVQ.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/1979 Mercedes-Benz 240D parts car - old start, cold start - first start in 13 years (long version)-OuPNy_2AZ48.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/1979 Porsche 935-Cwur_jvxMzY.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/1980 chevy truck burnout-UqeLmHmoBR0.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/1981 Corvette Show Car For Sale-0FOXgf3KhAM.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/1988 Fiero GT 5 spd lauch 0-60 from outside car.-3BpG7TdlpMo.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/1989 Ferrari Testarossa - Spicer Collector Car Profile-0I2sWpnBubk.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/1989 Lincoln Town Car Start Up & Rev - Quick Engine View-6fVt1_MVt4Q.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/1992 EB Ford Fairmont Ghia Power Window Fix-_KYFnY6nAfk.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/1992 GMC with Built vortec 355-0hipL0SkXMo.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/1992 lincoln town car-2MWajC6aWgk.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/1994  5.0 GT Mustang-1⧸4 In Car--F_91SDkNBk.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/1994 POWERSTROKE F350 4X4 CC⧸LB 5SPD ONE OWNER 46K ORIGINAL MILES PROTRUCKSPLUS.COM-QNcSk5e-FII.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/1995 Ford Mustang GT 5.0 Bill Jones Tribute Start Up, Exhaust, Test Drive and In Depth Tour-MkUDPLkMGxA.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/1995 Toyota Supra FOR SALE-2-1wY_Ndtgw.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/1996 Lincoln Town Car short acceleration run-2VqHpGDheXA.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/1996 Nissan 200sx with GTIR motor swap and 60-1 Garrett Turbo-_-lXVZ9QpO8.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/1997 Ford Thunderbird LX V8, Start up, Exhaust and In Depth Review,-gqPj-axDt8w.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/1998 Toyota Mark II Car Reverse Sound (Spur Gear Sound)-1inmTlU0qZY.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/1999 ERA Cobra Kit Car Dyno Pull-2QdnSWzMPCI.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/1999 Miata Passenger Window-ta2vGgYNBgg.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/1999 Troyer Tour Race Car-31GRio_HPRQ.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/1_18 RC Brushless Car-2HPvQZdVs6o.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/1st car off assembly line after general motors became ＂government motors＂-2yNJIsbzAHc.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/2 Car Draft Dega NASCAR 2011 The Game-1G0mwXgqOCU.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/2000 Jeep Grand Cherokee Limited Start Up, Engine & Full Tour-3esyOI3cuPI.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/2001 FORD CROWN VIC ON 22S NO RUB-PE-U8iMqwho.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/2001 Jeep Cherokee Sport Start Up, Engine & Full Tour-cMFacOIgiRU.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/2001 Mustang GT  Bassani exhaust O⧸R X-pipe, Bassani Catback In car 1-3SFu86BPE4M.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/2001 dodge ram Lifted on 36x 15.50 mickeys-Cis2EFd9m2U.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/2001 mustang GT FOR SALE-bqPkbvp8PK4.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/2002 Mustang GT auto vs 2000 Z28 Camaro M6 in car-06EfveS296M.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/2003 Bobby Labonte Crashes At Chicagoland, Car On Fire-26eZe2xThp8.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/2003 Nissan Altima. check engine light on-GUn5_aGpNKM.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/2004 Nissan Sentra SE-R Spec V Supercharged - open header-2nbbfIoayaE.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/2005 BMW E46 ⧸⧸⧸M3 vs 2007 BMW 335i (Race 2)-E3YwyNv5zwk.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/2005 Honda Odyssey Startup Engine & In Depth Tour-4y0KbKCyKus.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/2005 SCCA⧸Champ Car Trans-Am @ San Jose (Full Race)-0g8d4MveZyM.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/2006 Mini Cooper S Review-50i6K-z7TvA.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/2006 Pontiac GTO Autocross Peach State Muscle Car Challenge-3XDs77s9ODA.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/2006 Subway Fresh 500 - Huge Multi Car Crash-2wABMt9m4Pw.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/2006 v6 mustang, pypes exhaust, bbk headers, bbk cai, etc-gT504Sv_XD8.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/2007 Aaron's 312 - Multi Car Crash-2jPTZqSW3LA.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/2007 Audi RS4-KnC_qb1RH9k.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/2007 Chrysler Town Country radiator fan noise-eEY8OozRve0.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/2007 Civic Si Greddy Turbo Kit-pNNjbJRrGao.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/2007 North Pole Speedway Bandoleros Car racing-0pDGae3INT8.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/2008 - AutoX 5 - Run 1-1a9CmJdD5Ns.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/2008 BMW M3 ｜ Track Tested ｜ Edmunds.com-Cu7uy6m4rw0.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/2008 Camping World RV 400 Multi Car spin!--HHJHAF4WxE.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/2008 Honda Accord Coupe V6 LOADED (stk# 40079B ) for sale Trend Motors Used Car Center Rockaway, NJ--r4CV2831Bo.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/2008 PPIHC - Car #44 - Pontiac Sunfire-3Lc8YlSBa10.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/2008 Sprint Car 48th Annual Knoxville Nationals Finish!!--tSPCa-VLS4.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/2009 LINCOLN TOWN CAR SIGNATURE L!!!LOW MILES!!LOW PRICE!!!-20BGawT1jo8.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/200sx skidding.-WBYa_u20cVo.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/2010 Audi R8 5.2 FSI ｜ Road Test ｜ Edmunds.com-d8Wt3ioGQTQ.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/2010 Out in my Bronco-2_-DU_uEow0.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/2010 RC Car Crash Compilation Part 2-0maAWjDvNAU.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/2011 2ltr Saloon Stock Car World Final (part3)-1dEg7y255fQ.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/2011 Duel in the Desert Tony Rost IMCA Sport Modified heat in car on board camera Las Vegas LVMS-42fJMD7_FFU.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/2011 F-150 vs 2012 Ram vs 2012 Silverado-6Bf8TALCj_4.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/2011 F1 Safety Car - Top Gear Test Track - On-Board + Trackside Camera's (rFactor)-5pjuE0iyRwE.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/2011 Ford F-350 Super Duty 6.7L Quick Tour, Start Up, & Rev With Exhaust View - 9K-nMfJgnHZ0zc.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/2011 Harris Clash Knoxville Raceway Sport Modified A Feature Tony Rost in car on board GoPro HD IMCA-0Rpjl1AO-P0.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/2011 High Desert Trails Rally Crash  - In car video with thinman⧸FATMAN racing.--tW9QbQnQvE.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/2011 Lowmead 3 car 4wd comp  Russell Mason-0q9MmzNS2_o.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/2011 NHRA Supernationals Funny Car Session 1 & 2 Qualifying Highlights-2dMvEHPLiP4.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/2011 Nissan 370Z - Convertible ｜ New Car Review ｜ AutoTrader--zzit4txEcE.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/2011 OPTIMA® Ultimate Street Car Invitational Trailer-21qzyUU_ytI.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/2011 Pure Stock Muscle Car Drag Race - Dodge Dart GT Sport Burn Out-1xZDoVUV3P8.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/2011 Shanghai China super car club challenge fiesta-1v6wX8Q5BIc.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/2012 Chevy Avalanche - Features - Augusta GA Car-3I1V62ci_xk.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/2012 Honda Civic - Sedan ｜ New Car Review ｜ AutoTrader-2EgSkmnXc4A.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/2012 Honda Civic Car Horn Sound Effect 2-0TpU5mIeMJk.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/2012 Quicken Loans 400 - Dale Earnhardt Jr's car comes to life, he takes the lead-0V_W0GSWOwk.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/2013 Ford Mustang 3.7L V6 Charleston Car Videos Review ＊ $98 Over Invoice @ Ravenel Ford SC-24Dk83zCBZs.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/2013 Mercedes GLK 350 on Snow-BM0MSMJBCrA.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/2013 Porsche 911 Carrera Start Up and Review 3.4 L Horizontally Opposed⧸6 Cylinder-9BzZvj5W09s.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/2013 Scion FR-S ＂Driving Is Back＂ Commercial-bTcRWzAwL70.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/2014 Chevrolet Silverado Southern Comfort Black Widow-xqASMt0kZjI.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/2014 F1 Australian Grand Prix Safety Car and Restart--Ib1wZDF3_o.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/2014 Mustang GT vs 2010 Genesis 3.8-2odAQZHNDRU.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/2015 BMW 1 Series M Coupe New car reviews,Top Speed,Test Drive-2Mr4P4YPWVs.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/2015 Dodge Challenger 392 SRT Vs 2013 Genesis R-Spec 5.0-3MOdK7QISdY.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/2015 Dodge Charger Hellcat Cold Start-Q6PCrFDeR0E.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/2015 Reunion - Race 4A - Car #54 (1970 Datsun 240Z)-2hNwQIohyEM.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/2015 Touring Car Masters - Winton - Race 2--4vYvHuiHH8.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/2016⧸06⧸05 Street Car Nationals SUZUKA-1fQYCu-R-KA.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/24 Devestator In Car Final 16th November 2014 1-24G1AfEWw1Q.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/240ZR ＂ KATANA＂ TEAM ZPASSION with an amazing sound at MONTHLERY 2010 ASALM.wmv-3JHVa1YqCeE.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/240z nearly finished-9P286DXo8Nk.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/24HrsLeMons Thunderhill08 Spins&Bumps Group of Foolz, Car #9 - Highlights-079vcq6drhg.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/26.09.09 Hednesford raceway pre 68 bangers in car with dom davies #261 part 1-33MSbp6i0SU.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/27th Fun Car Show Illzach - 2007-2v_eCyae0co.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/2o rally sprint othris (οθρυς) 2009 in car fiflis-0alAeNXv8To.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/2wd Datsun 1200 Coupe Rally Car Ulladulla Rally 2006-3HNLe73khxI.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/2ª Etapa do Catarinense de Velocidade na Terra - Acidente João Rodrigo Chemin - Stock Car Opala-1gYCv6BtJ2Y.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/300ZX Twin Turbo： In car video from the 10-second drag run-2X-Q3BSgUuI.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/350z blown engine-BZTSmF9zt_Q.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/350z making weird clutch noise-8iy3RjnVats.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/351 Cleveland Twin Exhaust , Lumpy Cam-OwN672LeXWw.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/3KGT 0 to 120-4OlkJQbNzi0.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/3d model car animation DRAFT--4R2rold4Bk.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/3rd Annual Kansas City Muscle Car Reunion And Nostalgia Drags TV Commercial--EGV3UsNmZ0.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/4-Second Funny Car Run-2FyalYzSF6g.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/435i M Performance Exhaust (#340)-APit6hIABQA.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/45 and parker Houston sunday night car meet-0zTaByZaltY.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/4Runner & Tacoma fun with Noobs-TCc4dnhyHvQ.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/5-11-13 Bee Springs, KY (Big Car Heat 2)-5MlIBN6hixw.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/50° coppa paolino teodori - Opel Astra Kit Car gruppo E1 - Amato D.-0zxNzueJasI.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/55 chevy cummins-killer burnout-PEkR2BLU1so.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/57 Chevy Stock Car - Street Legal-1QVjsCeVYHM.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/592 rw hp 2010 Camaro SS by Hennessey Performance-J6rKfrIq9Ds.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/650 RWHP Police Car-QAWuHvVCI6g.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/67 camaro pro street car-2w0NGuwz5e0.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/69 Camaro street car 10.73 pass-3An7IYyP4jY.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/69 pace car camaro snow donuts-0UhqGLU3zac.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/6° Slalom di Custonaci Camera car di Angelo Fici su Fiat 600--3yVqL0DWQE.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/720 Sprint Car Industry Speedway-0jBiK305ZIY.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/771 CARS CLUB TUNING CAR SHOW  HUAUCHINANGO PUEBLA-1VDw8dzHDpM.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/9-29-12 Mahoning Valley Speedway 4 cylinder Feature In Car Camera-2B9pv5-1SBE.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/95 Mustang drag car start up-1sjKon7lrLY.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/99 Cadillac Northstar DEATH BY BOOOT!!-p86PtMUr9Pg.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/99 S10 differential shaft vibration-_JFFhzZhIvk.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/99 Trans Am WS6 - Donuts, Take-Offs, 110MPH!-G4Rp68qV_aw.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/9° RALLY CITTA' DEL PALLADIO 2009 CAMERA CAR MATTLEY-HANDEL GS PROMOTION-0wlb7seNia0.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/A Dream Car. For Real Life. -- 2012 Kia Optima Super Bowl Full Commercial-0jWKCZfmVrE.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/A GOOD DAY TO DIE HARD -elokuvan klippi： Car Chase--Gf7EbySYsY.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/A Month in China - Dash Cam Compilation-AGHHdzjFNGI.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/A Ride in Dubstep Derek's car...-4RQ3BTe5XYs.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/A drive in Premier 118 NE car--5_2niNiBpE.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/A guy trying to start car after flood-0TGPaUN2V5Q.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/AE86 Special Edit-xHJ0MUpfuiU.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/AE86, First Drive-2Ck7MX5LEck.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/AJ's Burnout TURBO SILVERADO-E-F3eGRXiBI.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/ALFA 156 2,5V6 sound engine without exhaust-kw5kCegHsyk.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/APB： Taking my new car for a spin-0_aOKV0py48.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/APR Motorsport VW GTI Crash @ Watkins Glen - In Car Camera-2XQy-A6z-e8.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/ARENA CAR NENE POKO LOKO E TIOZINHO-0H0izirR2nc.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/ARRANCONES TOLUCA 28 de junio： crossfire vs shadow GTS Super Car's. Gana shadow.-1sjv-zUxX8M.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/ASDA Car Park Coatbridge 29 06 2009-0KWRUdRExUQ.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/AW11 MR2 Turbo Mana Road Hillclimb Hopkins Taranaki Car Club 13th Dec 2009-0GwzCSLj7ac.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/AW2 AW5-zz0ddNfz0h0.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/AWDC-NORC,  Comp Safari,Sweetlamb,  Car 46   13⧸9⧸09-1Cx2j9gtRyI.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/AX kit car-1-Vhr9Ut4Tg.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/Abdo Feghali Red Bull Car Park Drift-2SuEJ1MLOcQ.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/Absher Arnold sign falls on cars in car dealership!-1CD3O0YJNZw.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/Abu Dhabi - Ferrari World： car museum--ZQXEQp3awU.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/Advanced car hit movie-0P3HVIqijwo.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/Albany motorspeedway enduro car flips-36fvPlFr5CE.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/Alfa Montreal In Car Hilton Bridges Classic Adelaide Rally 1998-0xSZx2P7PQs.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/Alfa Romeo 164 QV V6 on Deviation Rd - Best Driving Roads 03-C1O7V0jiiNw.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/All About tvxq season 3 -drive car chasing--JdcKcINFgE.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/All the new cars from GT5 car pack 3 + speed test track-1r8eXfImkYg.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/Almera DCi sights and sounds - car mount test shots-1dHl7HIaTxk.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/Alpine A110..Sound of sidedraughts-5ZOlnEPH5p8.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/Amazing 4 wheel drift in ford focus ST rally car at the NEC autosport show 2009-17oCmGwmdtY.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/Amazing Showreel 2010 3D Animation Car Dodge Charger 3DS MAX--4vQjkVB1Ic.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/Amazing Truck Jump-QktjNB2BxjA.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/Amazing super car rally-0X_3JOfPdvU.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/Andrew trying to outrun rally car (2009 Sligo mini stages)--wLAP7X5iIQ.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/Annoying Starting Problem --  Clio 1.2 Litre 16v extreme-nsssMnabc0s.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/Anti-Violent Car (Edit-Room Version)-0xnlLma7Of8.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/Antique Car Parade at Old Sturbridge Village-0TtczPtxGwM.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/Antique Vintage Old Little German Junghans Wall Clock With Paper Dial See Video-Uik5Grn_oYU.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/Ariel Atom V8 vs 600bhp rallycross Citroen DS3 vs BMW HP4 superbike drag race - autocar.co.uk-lTAUV1Yj4NE.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/Arrancada Corsa 1.8 102cv-ZhTE3sWCfBs.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/Aston Martin DBS Sound & Acceleration LOUD Sound!-v5qpjASGr-Y.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/Aston Martin Track Day ｜ GNARPM ep.2-ISewgjSQFkA.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/Astra J Power Window Remotely Controlled-9VwjH2kglAA.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/Atlanta GA： 1999 Jeep Grand Cherokee - Ignition Lock  Problem!-vsGv0Xf_hMI.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/Audely End House and Gardens Stately House. Essex. England. English Heritage-1pKxZkeXe9w.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/Audi 90 ISMA GTO und Audi 200 TransAm-B4l-0zH00nI.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/Audi A3 3.2 V6 Quattro DSG - o meu 'AA' !-2Fp5A-Q63g8.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/Audi A4 B8 makes creaking noise when turning steering wheel-V9JU5FmhtjM.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/Audi A5 3.2 FSI ESD (Medium) by Warncke Car Art-1jt0E0tQ25Y.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/Audi R15 TDI race car-0NFseb9vIv0.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/Audi RS4 (B7) non-resonated Milltek exhaust SOUND HQ-4NpC9pbPIvI.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/Audi RS4 Avant B5 Accelerating-DA7axOalokI.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/Audi S4 V8 stock exhaust sound! Powerfull sound!-TWDytzefXXc.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/Audi S8 with mufflers disconnected-vqVsEaMWYJQ.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/Auto da paura-SwqfzROaTJY.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/Auto restoration rotisserie lifts car body right off the frame to rotisserie in one step--J-WfHQifzc.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/Automatic frs facts with kris.H-vZSU_WAWw-Q.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/Autumn Drift Matsuri, Fukushima, Japan--uBbPbRML3U.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/Awesome Sprint Car Crash--yCTTjbTWSo.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/Ax kit car cbr 1000 rr bike engine-0LS6MbWKsSs.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/B+E Trailer Towing Novice Reversing Lesson.-nvPYCEyKgCU.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/B+E Trailer Towing Test Reversing Lesson-WYle9IF5rgs.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/BACKFIRING Ferrari 360 Spider Sound W⧸ TUBI EXHAUST-_bYe6wcQCXs.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/BBK DSI intake test car-289diVzjuZI.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/BEST Mazda rotary 20B sound compilation-0IUR0a8uR5c.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/BEST OF KIT CAR ET SUPER 1600 EN NORMANDIE ET EN BRETAGNE DE 2010 A 2013-23NX-3tFQgE.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/BMW 1M Daytona Pace Car-0WiubQp6vDQ.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/BMW 1M Launch (part 2： on the track)-28EiKroYXXI.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/BMW 320i e36 drift-IsNQ98J3GlY.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/BMW Car Club M Flight at Hartge in Beckingen, Germany-17idvhqWdgA.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/BMW E30 325iS MagnaFlow 14815 Exhaust-piDzQjuf9bY.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/BMW E30 Coupe w⧸ E46 M3 Engine Swap - One Take-hZzTg1GoOxo.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/BMW E34 M5 TOURING S38B38 Engine and Exhaust Sound-yq84OepE8uw.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/BMW E34 V8 Turbocharged 500+ HP Drift car burnout--K89LwrlmC4.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/BMW E46 M3 Drift Day in car-2ujlG9xd9NA.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/BMW M3 drifting on ice with a 420 HP car--p8Zjtalh_Y.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/BMW M3 history and the new car on-track-0VMWLQn_Avs.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/carros/BMW M6 Convertible + Mercedes-Benz CL65 AMG + Sound--Q1Fopg1Yic.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/#BikeLife Friday Pt.4-5Ce6-dludmg.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/#Project KZ ： The Dass Effect-1ZPKvKZtWiA.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/(Stunt Wheelie)  KEEWAY MATRIX 150-2h0aBiolPBI.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/01 Suzuki Savage with Harley Screaming Eagle exhaust-2mW-H8L609E.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/05 Sea Doo RXP RUNS AGAIN AFTER DROWNING-6LKTbjlktm8.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/06 gsxr 750 stretched--aSDXtf3RLc.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/07 ZX6R 2 Bros Full exhaust takeoff-8s6T29Jjuak.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/08 YZ450F with two bros pipe-2ecDVIkze1o.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/08 yz 85-0dNXQt5BtEw.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/080314 Looking at a ＊cough＊ Ninja ＊cough＊ 250r ＊cough＊cough＊-4zdcZtLdp_Y.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/08FLSTF ファットボーイ マフラー交換-79md4v7E2rA.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/100% attention, 100% of the time - Danger around the bends-49H9cty2Nfk.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/100% grubus 2009 Hagfors ＂dynghåla＂-6SbU6lpm_EM.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/1000 HP Motorcycle..Highest HP ever-9DanwFX0fIE.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/100216 - 2003 Suzuki Intruder 1500 - Used Motorcycle For Sale-36_wwqceG5I.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/100cc Track Testing-2UgLZ3TWT3E.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/1107170162 Z750FX 3 ｋ-2FLANWI3go8.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/110cc moped  full throttle-0kLVMPVuB24.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/110cc snorked--9gZLVDKpnE.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/110cc snorked--9gZLVDKpnE.csv.~1~ salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/19 - Du vroom, des fails et du GPS-0rK_s5zW2x4.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/1911 Indian Motorcycle - Running!-2avCpTQb5QU.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/1929 Scott Flying Squirrel TT rep-6vAsn-PGssE.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/1955 New Hudson Autocycle-4A34BCGT3_w.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/1966 Suzuki K11P Motorcycle-3OiEoPjYQic.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/1967 Vespa Super Sport 180 SS 180-8oSsQ47GoNQ.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/1967 Yamaha Yr1 350 grand prix 023-2fB-TENN-SU.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/1967 ca160 Honda Dream start up and ride-5_pFiB5HSjU.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/1969 BSA Rocket III A75R by Randy's Cycle Service @ rcycle.com--UcCryhiyxc.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/1970 Yamaha YCS1-C 180cc 2-stroke twin, running.-70PToZZHWSg.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/1974 Honda CB360-83jHteMf6p0.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/1974 Ironhead hardtail Chopper bobber-27uWxSRoIIg.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/1974 Yamaha YZ125 Walkaround and running-9I7rfXGtfnw.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/1975 Suzuki GT750--Vbg01OcjRE.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/1975 Yamaha RD350--lWJgyAa4Tc.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/1976 Penton KTM MC5 400-AATuMwz9l5M.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/1978 Suzuki DS 185 Demo, 7 May 15-5BgJKx7Kkwc.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/1978 kz650 cafe⧸brat-8wDf_ApRd2k.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/1979 BMW R45 Cafe racer engine sound-8OOVXMYze9A.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/1979 Honda CX 500 Custom Test Drive-3mGNn8JZG1s.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/1980 Honda CM400T-1IEUtokg_UQ.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/1980 Suzuki GS1000L Show Start up and Drive-1iLRWtFiItU.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/1980 Yamaha YZ465 First Start ｜ Vintage MX dirt bike-18-XenSGxAU.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/1982 RM250-0jOAvZuo1SE.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/1982 Yamaha XJ750 Maxim - 4-1 Kerker header-6qMbqxRLahQ.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/1982？ Honda urban express-A5JFiOQUOfM.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/1985 HONDA XL125RF XL125 125 MOTORBIKE GC TAX & MOT !-7ulveG2h_io.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/1985 Honda Nighthawk 450-1t7DHni5HCg.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/1986 SRX 600 Yamaha Race bike for sale-7BCw08ae6xA.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/1986 Yamaha YZ490 Very 1st Start After Restoration Tom Morgan Engine & Pro Form Pipe Aug. 2014-1-v2SFonosc.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/1988 Yamaha YSR50 50cc Road Legal Bike.-6XoRUa2k9LE.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/1991 NSR250 MC21 HRC TT-F3 [Formula 3] Donington Park-19HbEKW7Rps.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/1991 Prostar Motorcycle Drag Racing TV Highlites #1--yJF5hr0j2E.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/1995 Honda cr125-7tBFmjKv0HU.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/1996 CBR 900 rr (A) Running with a knock-2S7qU2Esr7U.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/1997 Kawasaki VN1500 Vulcan 88 stock #9-4151-99v5S2Rv2v4.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/1997 RRV fireblade Vs 2006 ZX10, Part one-7aSEY71MlD8.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/1998 YZF750 R1 CONVERSION FOR SALE $2600 WWW.RACERSEDGE411.COM-6xXjhWcns7c.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/1998 superhawk vtr1000-2r_3JrPmUVw.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/1999 Kawasaki Vulcan 1500 Engine Noise-6_xyZ3abT9A.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/1999 yamaha yzf r6 600cc  walk around⧸sound test-1PMUC_J2Su0.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/2 15 inch obsidians getting down lots of lex-A4l5R48JUhM.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/2 wheel drive motorcycle first test ride-4Nih34qn6pg.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/2000 BANSHEE 350 $2400 FOR SALE WWW.RACERSEDGE411.COM-3R1IOUZzhY0.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/2000 Kawasaki KE100 Rebuild-6cEcxWWXZiw.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/2001 Kawasaki Ninja ZX6R - For Sale - Newton Motorcars-2QqLKkqEg44.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/2001 Yamaha r6 micron exhaust walk-around-7PmfCZ4FIV0.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/2001 honda cbr 600 F4i Loud Engine Tick-30D02P6p1vw.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/2002 Honda Shadow VT1100 Spirit 9-1616 walk around review-3aVYRYZJMWE.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/2003 DS650 Baja-7YD3aKxiYuo.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/2003 KTM 450 EXC Dual Sport with a 540 Big Bore Kit-3wcWiiapyAY.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/2003 Ktm Exc-rfs rattle, clink...-5qf3dW97foU.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/2003 Ski-Doo Rev MXZ 600 H.O. - Stock--WwAxd-BBrs.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/2003 Yamaha Blaster how to： start with no key-2K-XHzAZWyk.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/2003 Yamaha R6 Special Edition (ON SALE!!!) $4,999-7BUhuRCSRgc.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/2003 kawasaki zrx1200 with full muzzy exhaust-1nf4QA__ybo.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/2004 Honda Shadow Aero with HardKrome 2.75in Exhaust-64507_lC-tE.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/2004 Yamaha Banshee For Sale 11414-6QR38xGg6WQ.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/2005 Rubber Mount Harley Sportster Hardtail Conversion - Part 3-5iIsaVOg9l8.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/2005 Yamaha R6 from MOTOPRO SHOP Lithuania-0QYOc3oO5bM.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/2006 Cr250 walk around--Q7dmNjHyyI.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/2006 Cr250 walk around--Q7dmNjHyyI.csv.~1~ salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/2006 FLSTF⧸FLSTFI Fat Boy®-1dyTmrkZju0.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/2006 Harley-Davidson Road King Police-14wPUIldY6M.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/2006 Honda CRF250R--eO7J5kuaUg.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/2006 SV650S (second gen) Review-4VRMgZD7Yh4.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/2007 Honda CBR125R Won't Start-6zdUydciScM.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/2007 KAWASAKI ZX600 P ZX600P TS5846 U3599-8WYoQPlWq-E.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/2007 Yamaha V-Star 1100 Silverado Classic-8b0tC2eLNOk.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/2007 kx 85 startup-9CrCBML-AXE.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/2007 skidoo blizzard 800 idling problems--9yvWZMmbPE.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/2007 skidoo blizzard 800 idling problems--9yvWZMmbPE.csv.~1~ salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/2007 yamaha R6 tick sound idle？-4j9nfdnsMuk.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/2008 ADLY Jet 50 2-stroke scooter-1cpWyQjkVAc.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/2008 Honda GL1800 1800 Goldwing Overview Review Walk Around--YkMiYqlnfI.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/2008 KTM 300 xcw-4LRrcsf7Wm0.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/2008 KTM xcf-w 250 FMF megabomb & 4.1-09NvcvNBR-w.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/2008 Vancouver Motorcycle Toy Run-5pUnHwGlWGw.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/2008 Yamaha V-star 1100 Custom Hard-Krome Big Straights-7-bG394pYps.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/2008 zx10r dyno run--7gC66Xp1iY.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/2008 zx10r dyno run--7gC66Xp1iY.csv.~1~ salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/2009 11 12 Kevin Carmichael wheelie motore spento impennata eicma-3Hi6jvElVF0.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/2009 CRF450⧸CR500R Conversion TL-3rEYjghDo3c.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/2009 Kawasaki Ninja 250R Candy Thunder Blue-9mBFnO9HyXE.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/2009 Suzuki GSXR-600 K9 with Termignoni Exhaust-61VibcmcuCk.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/2009 Watertown NY Chrome Diva's, Save the Tatas Benefit Motorcycle run-2KLI8OG8HVo.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/2010 Big Dog Motorcycle Wolf S&S 121＂ X-WEDGE MOTOR-4n5663oxxDU.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/2010 Ducati Streetfighter s-1PV6TCRQTok.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/2010 Harley Davidson xr1200 danmoto 2⧸1 exhaust cold start-1AZwzCA66Ao.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/2010 Zero MX Electric Motorcycle on a Track - Natural Sound-5UtoIKMDjUY.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/2010-6-14 011.avi-5NXt2pRENBU.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/2011 Kawasaki Z1000 - Akrapovic - Dynorun-7H6gOCkSFmc.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/2011 Triumph Thruxton BC Predator Exhaust-1BwO2S8XiOk.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/2011 Yamaha Stryker start up and Rev-1N96JptQ6Bs.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/2011⧸2012 QIRRCH Round 7 Highlights 26-5wpmjCOnunA.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/2012 Ducati Diavel Carbon Red First Ride at Euro Cycles of Tampa Bay--4-87UgJcUw.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/2012 Ducati Diavel Carbon Red First Ride at Euro Cycles of Tampa Bay--4-87UgJcUw.csv.~1~ salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/2012 Harley Davidson iron 883-5JcsNKJpRzg.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/2012 Polaris Switchback Assault 800 GGB Exhaust outside-9DmTEGEXTSw.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/2012 Z1000 $7900 FOR SALE WWW.RACERSEDGE411.COM-0Mm6hbnREH4.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/2012 street bob--gAYyzIl2-w.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/2013 CBR 1000RR M4 GP Exhaust Sound + Tutorial-3qstngWyzo8.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/2013 FLSTC-ANV Heritage Softail® Classic Anniversary Edition 024914-0X9wj5DvYnA.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/2013 Kawasaki Ninja 300 Special Edition With Two Brothers Carbon Fiber Exhaust Sound Motorcycle VLOG--ulkcJTOahQ.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/2013 Round 4 - J Day Off-Road Crow Hill GP-4LvasOrxahc.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/2014 Arctic Cat ZR7000 LXR - Yamaha engine sound-7qZqAraRFco.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/2014 Beta 450 RR Motorcycle Walk Around, 3 Seas Recreation, American Beta Motorcycle-8At-88WYYe8.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/2014 Harley Davidson Breakout modified-3ySofIYmKfA.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/2014 Honda Grom Walkaround-175LkoxXMto.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/2014 Kawasaki Z1000 dyno run-05Z4emmS7IE.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/2015 Ducati Multistrada 1200 S Iceberg White at Euro Cycles of Tampa Bay-39vR4yap6so.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/2015 ⧸ 2016 Qatar Superbike Round 1 ⧸⧸ Superbike Race 2-2eAxbG6lSlA.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/2016 KTM RC390 Spotted Testing ｜ Live vlog with oggy f plans-6eNDrf7A_tc.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/2016 Pulsar Mania Kolkata -2016-4PBokzPbyuA.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/2016 Yamaha kodiak 700 wheelie-4kLp4qP72yc.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/24h00 du mans Moto-52xlYB6DKsA.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/250 Pro Liquid Nitro Arenacross Tour Round 3 Claremore, OK ⧸ Jimmy Albertson-0LSVUDmml1M.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/3 1981 Honda c70 Passports On Dirt .-3P0yQm4xM_g.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/4-Wheelin' at Turkey Bay OHV-97gsSnTkgd0.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/400ex 460 stroker.-4V8UeW_t_U8.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/450r vs cr125 vs cr250 drag racing-1C0bH19uXh0.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/4th Championship Drag Race 2009, Polykastro - Sunday Moto Part 2-3kNCkzSBrfM.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/60 hp DRZ dyno video,Sisneros Speed Works built and tuned.-8xL1wRY5KY8.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/600rr as First Bike-6sg3yHUT0y8.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/79' honda XL125 K2  engine sound-9h73n4mxNys.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/817 - 2009 BMW R1200RT Touring Motorcycle 1170cc 2-Cyl 108BHP--wOKbTpyF94.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/85 atc 250r with esr 310 kit-8b1mOdXaaU0.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/99 Gsxr 750 SRAD motorcycle Burnout Video-05c_JwurbrU.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/A Sheriff Motorcycle Escort--XhqRIAN9Ko.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/A saga da Partida no Pedal (MOTO)-9g0-YMKm0Gg.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motocicletas/ARDIE RBU 350 erster Probelauf ⧸ vintage motorcycle first run-6kofP5LGVoU.csv salvo com sucesso.
# ...
# Arquivo ./audioset/mfcc_vetor/motosserras/Firewood log Holder DIY brandhout  Stihl Fast cheap easy best-4kd99qbm25I.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/First run McCullock cs 340-b42EJ0iPKIU.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Flock of Geese-Ulz1urzNY7s.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Florestabilidade - Ep05 - Extração madeireira-yuGbc_kVWBo.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Ford F150 Ecoboost Torture Test： HaulingTimber shot on the 5D MK II with Zeiss CP.2 compact primes-xQh4jY4n5_g.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Forest monitoring to help curb effects of climate change： Could new technology be the answer？-050iiMJKE20.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Fort Howard Haunted Dungeons 2013 - Toxic Waste. Chainsaw scares.-NWG1AQtapqg.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Free Poulan Pro Chainsaw from a Youtuber! Part 2⧸2-mqJeLALpWYk.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/From Log to Lumber Sawing Pine 2X4's on 1880's Gaar Scott Steam Powered Circular Sawmill-WtsLE9Wy6wk.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Fuxtec 6150 teszt-QCvdVm3gDCo.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Fuxtec 6150 vs. Husqvarna 235, Fuxiból kifogyott a benzin ：)-OdOIHGWEsqg.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Fällung einer Pappel-T9nk8uwdJyw.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/GS 461 Arbeiten an Sandstein-TpPomddqXuY.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Gadgetman Fingerlakes modifies a Chainsaw!-bWoqHajtbZc.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Gara d i motosega-ZPJANiTXuqk.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Garden lopper tronçonneuse + élagueuse + ébrancheur taille haies thermique TCK GARDEN-BIT-3hb7kIM.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Gehl AL340 montage-STyaGr0aAyU.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Getting firewood-m3FPQl_UUuE.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Getting the tree to fall in the right direction-tgxXbesmx9k.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Gopro view of concrete cutting! Ring sawing 101-CocB6ItybUE.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Granberg Alaskan Chainsaw Mill   31 Foot Oak Beam   Side 4-w6pUOBS00oo.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Granberg Alaskan Chainsaw Mills (en español) from baileysonline.com-6gLbCktiyAM.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Granberg Chainsaw Filing Guide from Baileysonline.com-8xbj56gxXbQ.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Granburg G777 Chainsaw Mill in Action-c9xa5zorYWo.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Grappin coupeur scie de tronconneuse-kfEnkZoEOtE.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Gravely 16G snow blowing part 1-1O1AFLKeys0.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Ground crew cutting logs-KngzG6qgxkA.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Große Obstschale schnitzen mit Arbortech Werkzeugen-1uHXocWOpA8.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/HALLOWSCREAM ｜ Hallowscream 2012 - Teaser Trailer-0tray-DsgLA.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/HECHT 924 Profi Benzin-Heckenschere-bzkle-2peYQ.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/HHN18： Chainsaw Drill Team-aDXai2j982Q.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/HOW TO SHARPEN CHAINSAW-6mWz9fxXO7s.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/HUSQVARNA 142-xMELs0HDBXg.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/HUSQVARNA 3120XP OREGON 105cm bar with .404.chain-YvnbgvXrn40.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/HUSQVARNA 455 RANCHER  (new)-6Z1eAbekeLg.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Halloween 2009 mit Kettensäge, ich stürme Fuchs seine Bude!!!-AdoBKPCXMeo.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Handmade Chainsaw Base-5a_LPLNtBQs.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Hang-up Tree Removal, Step-Cut Technique-zEBrnIZa6-s.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Hazard Tree Falling 3⧸6⧸2011-fXS4OGMzjbc.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Hepsiparis.Com - Oleo-Mac 952 Motorlu Testere-6-DAiSEzRA4.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Hi-Line Tool Demo of Stanley DS11 Hydraulic Diamond Chain Saw-oku0-HByjpo.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Hirsitalon rakentaminen： Pyöröhirren veisto-GS75mzIW5Gc.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Holz in Spannung-T-YF1Hq5skk.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Holzaktion April.wmv-HxAlcG_rEZA.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Holzbank Gartenbank selber bauen mit Arbortech Turboplane-0PxvBPOjDKI.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Holzeinschlag (Baumfällung)  mit Husqvarna 560 xp-B5ugRlKeYPk.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Holzernte im Steilhang-qtRSll0iLIE.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Holzkunst mit Bandsäge und Kettensäge - Holzfigur Eule - Motorsägearbeit-d8quFTEpFHA.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Holzpilz schnitzen mit Kettensäge unter 5 Min.-vRa8ncJ-Zrw.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Holzschlägerung： Lärche-HZ69dl6yTYM.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Homelite 25cc to 30cc Transplant Weed Wacker-TjgCtHX-gxc.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Homelite 550 Chainsaw-73mQmyZZsSw.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Homelite C-5-eFdK7oXF598.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Homelite Little red XL-LHCCOsCIGSc.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Homelite Straight Shaft trimmer Review-drIqxiioHYg.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Homelite Super EZ-cJxmZX4rcFM.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Homelite Super XL Chainsaw-t_R09kzuKSc.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Homelite Super XL ＂BIG RED＂-vBqPbz5Pg-M.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Homelite Super XL-925 28＂ Bar-bGDPImSNZVM.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Homelite Super Xl-12 Automatic + Cold Start-a5vQ2AO8RCQ.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Homelite XL12 moottorisahakokoelma ⧸ A collection of chain saws-5csBOR-cdgw.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Homelite XL12 running E85 Ethanol - Winter start-SJTqc4w2bt0.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Homelite XL2 Automatic-sCzno8FeYWA.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Homelite XP1100 gear drive running half inch chisel chain-2mBAi3PkE4U.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/HomeliteC7-cLddM8Al17A.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Homemade Chainsaw Mill. (alaskan style)-KBuqNcauF4c.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Homemade chainsaw mill-BYGADuRTxYw.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Honda CB 750 SevenFifty 0 -120-8-rNE12KQ80.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Honda CBR600RR Rod Knock-6PiYwUuaXhM.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Honda Moto3 first time start-U3COtQZORMU.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Honeylocust trim-dY-f4c9pECQ.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Hoss's 990g-rhGSqHtz_C4.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Houthakkersroadshow uit Raalte in actie voor Makita Belgie-AgDxQIamHek.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/How To Use A Chainsaw Safely Part 2-CvVJd_J9A2E.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/How To Wind Cables and Cords Tangle Free-2VjOWA8QME8.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/How to Fell a Tree ｜ Art of Manliness-suhTyB2fozQ.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/How to chain saw a window log opening by Patriot Log HOme Builders-YzoNc-DFxyQ.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/How to change primer bulb on Stihl Chainsaw or small 2 stroke engine-UOrCn0InJl8.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/How to cut down a dead tree-Zs1NK7I5zzk.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/How to fix and start flooded chainsaw, 2 stroke engine floods, solve the problem-9-FLVe2r2BQ.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/How to get wild honey with a chainsaw!-redSkbpiRMk.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/How to install new front struts and performance springs-rUFHz9TKTpQ.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/How to make boards with a chain saw-5jPxN86-2P0.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/How to start a Chainsaw in less than 1 minute-CoWWUQiGVwQ.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/How to start the Jonsered 2252 or Husqvarna 545-Ae6pZjdGfRY.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/How to use a chainsaw in Gears of War 3-oTd22kNn8O8.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Hradeckej masakr motorovou pilou-fcbknNzzlLU.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Huggning inför dikning-i10JPKjqZjw.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Husky 254 got the shakes-iVu1M8S1UEA.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Husky 575XP 20＂-7cWiVBljHMg.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Husqvarna  560xp felling spruce trees-5k9zvzKkrqo.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Husqvarna 137 vs. Husqvarna 236--MwY3HhnYVY.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Husqvarna 141-cBmw9WWJOms.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Husqvarna 2100 cd back together...-CQDY8CdIfMw.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Husqvarna 2101 xp-CwePqPu5Rqo.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Husqvarna 236, with cheap chain replacement.-zwIArHIZbxU.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Husqvarna 242xp testaus-I2TerLINT5I.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Husqvarna 272 xp coldstart-m2n1fNT5BwY.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Husqvarna 272xp-TbmhIZEX6XA.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Husqvarna 288 Chainsaw-Gi-Qt6cYeqA.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Husqvarna 288xp felling-AOJA4TU2M9c.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Husqvarna 3120 Modified Saw-Tjc6ogDdeTM.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Husqvarna 3120xp 42＂ .404-NbwgLBhsHnU.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Husqvarna 3120xp. New Coil-HJxW5SGaPMA.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Husqvarna 340-Q-j7h0fr7VU.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Husqvarna 346 XP ported-EC3Lxrq_dxQ.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Husqvarna 346 XP-xAzzCxBF28s.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Husqvarna 346xpg - Gopro HD-FGJQ3KC-Geo.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Husqvarna 35 Chainsaw Start Up & Test Cut-zkH4h1WjD6Q.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Husqvarna 350 Chainsaw-CyLmUFWDEvs.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Husqvarna 350 cutting fire wood-bk7sK4J7LpM.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Husqvarna 350 muffler mod-oFpD7Ik6Qe0.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Husqvarna 353-9W1zHb6TcmE.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Husqvarna 357xp vs 353 vs 345-cG7MewpScjk.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Husqvarna 359 Motorlu Testere- www.hirdavatplaza.com-GD-hZIUFPus.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Husqvarna 359-lieV4tZybdI.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Husqvarna 365 (Woods Ported)-ZE6_E8CQ24c.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Husqvarna 365 VS makita 6401BB-9a1F8iNHHHE.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Husqvarna 365 la munca-ZlTttYgo8GI.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Husqvarna 372 a 445-QjzBMyHQUiA.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Husqvarna 372XP-4YPYs-bHaR4.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Husqvarna 372xp ported-bvlPH6tfh38.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Husqvarna 372xp-pLrjkMpkmu8.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Husqvarna 380--rB-q8LKp-I.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Husqvarna 380S-OVNtuxOm5ZA.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Husqvarna 385xp chainsaw-O03Xg6CiGkI.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Husqvarna 385xp-g6HeHbT3l1w.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Husqvarna 390 XP vs. böser Baum Teil 2-Pc6d7q9UGpE.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Husqvarna 390 XP. SOLO 681-xmwLqK7WeHM.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Husqvarna 395XP - Ported - 212 PSI Compression-JCv61xfuRQA.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Husqvarna 40-AwnRr_4Sm1g.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Husqvarna 42 Junk repair an engine-Lc_F4xsnUWY.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Husqvarna 42 Special still wrong!-hsx5FsH9CO4.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Husqvarna 436 AGROSANCHEZ-LOTibagId-E.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Husqvarna 44-cJRviXZkA3E.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Husqvarna 445 test cuts-D4g4hDty-0Y.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Husqvarna 450 Chainsaw-jEHpshgvNO0.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Husqvarna 450 E series Chainsaw-R6485ssu6HI.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Husqvarna 50 with 55 big bore-gJ_TFW6PHs4.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Husqvarna 536 AGROSANCHEZ-QiRy_Gxyf78.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Husqvarna 536 li XP-LXkUfPG3jKo.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Husqvarna 55 2-Bk0XDemhbqE.csv salvo com sucesso.
# Arquivo ./audioset/mfcc_vetor/motosserras/Husqvarna 550 XPG beim Ablängen-imaWlPW-Oe8.csv salvo com sucesso.

# %% [markdown]
# # Treinamento e teste de rede neural

# %%
# Carregar espectrogramas com uma CNN e classificar entre "motosserras e não motosserras"

espectrogramas_carro = sorted(os.listdir(spec_carro_path))
espectrogramas_moto = sorted(os.listdir(spec_moto_path))
espectrogramas_serra = sorted(os.listdir(spec_serra_path))

spectrogram_list = []
labels = []

def adicionar_rotulos_spec(espectrogramas, spec_path, label):
    for filename in espectrogramas:
        full_filename = os.path.join(spec_path, filename)  
        spectrogram = np.loadtxt(full_filename, delimiter=",")
        spectrogram_list.append(spectrogram)
        # 0 corresponde aos carros e motos
        labels.append(label)
        

adicionar_rotulos_spec(espectrogramas_carro, spec_carro_path, 0)
adicionar_rotulos_spec(espectrogramas_moto, spec_moto_path, 0)
adicionar_rotulos_spec(espectrogramas_serra, spec_serra_path, 1)

X_train, X_test, y_train, y_test = train_test_split(
    np.array(spectrogram_list), np.array(labels), test_size=0.2  # , random_state=42
)

# %%
model = Sequential()
model.add(Conv1D(16, 3, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(MaxPooling1D(2))
model.add(Conv1D(32, 3, activation='relu'))
model.add(MaxPooling1D(2))
model.add(Conv1D(64, 3, activation='relu'))
model.add(MaxPooling1D(2))
model.add(Conv1D(64, 3, activation='relu'))
model.add(MaxPooling1D(2))
model.add(Conv1D(64, 3, activation='relu'))
model.add(MaxPooling1D(2))
model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='RMSProp', loss='binary_crossentropy', metrics='accuracy')
model.summary()
model.fit(X_train, y_train, epochs=30)

# model = Sequential()
# model.add(Conv1D(64, 3, activation='relu', padding='same' ,input_shape=(X_train.shape[1], X_train.shape[2])))
# model.add(MaxPooling1D(pool_size=1))
# model.add(Dropout(0.1))
# model.add(Conv1D(32 , 3, activation='relu', padding='same'))
# model.add(MaxPooling1D(pool_size=1))
# model.add(TimeDistributed(Flatten()))
# model.add(LSTM(100, return_sequences=True))
# model.add(Dropout(0.2))
# model.add(LSTM(50, return_sequences=False))
# model.add(Dropout(0.2))
# model.add(Dense(1, activation='sigmoid'))
# 
# model.compile(optimizer='adam', loss='binary_crossentropy', metrics='accuracy')
# model.summary()
# model.fit(X_train, y_train, epochs=10)#, batch_size=64)

y_pred = model.predict(X_test)[:, 0]
y_pred = np.round(y_pred)
acc = len(np.where(y_pred == y_test)[0]) / len(y_test)
print("Acurácia:", acc)
# Out:
# Model: "sequential_24"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_102 (Conv1D)         (None, 126, 16)           6160
#
#  max_pooling1d_100 (MaxPool  (None, 63, 16)            0
#  ing1D)
#
#  conv1d_103 (Conv1D)         (None, 61, 32)            1568
#
#  max_pooling1d_101 (MaxPool  (None, 30, 32)            0
#  ing1D)
#
#  conv1d_104 (Conv1D)         (None, 28, 64)            6208
#
#  max_pooling1d_102 (MaxPool  (None, 14, 64)            0
#  ing1D)
#
#  conv1d_105 (Conv1D)         (None, 12, 64)            12352
#
#  max_pooling1d_103 (MaxPool  (None, 6, 64)             0
#  ing1D)
#
#  conv1d_106 (Conv1D)         (None, 4, 64)             12352
#
#  max_pooling1d_104 (MaxPool  (None, 2, 64)             0
#  ing1D)
#
#  flatten_20 (Flatten)        (None, 128)               0
#
#  dense_38 (Dense)            (None, 512)               66048
#
#  dense_39 (Dense)            (None, 1)                 513
#
# =================================================================
# Total params: 105201 (410.94 KB)
# Trainable params: 105201 (410.94 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/30
# 25/25 [==============================] - 4s 39ms/step - loss: 0.8901 - accuracy: 0.6737
# Epoch 2/30
# 25/25 [==============================] - 1s 38ms/step - loss: 0.5592 - accuracy: 0.7412
# Epoch 3/30
# 25/25 [==============================] - 1s 34ms/step - loss: 0.4841 - accuracy: 0.7788
# Epoch 4/30
# 25/25 [==============================] - 1s 47ms/step - loss: 0.3880 - accuracy: 0.8413
# Epoch 5/30
# 25/25 [==============================] - 1s 31ms/step - loss: 0.3761 - accuracy: 0.8525
# Epoch 6/30
# 25/25 [==============================] - 1s 32ms/step - loss: 0.2764 - accuracy: 0.8875
# Epoch 7/30
# 25/25 [==============================] - 1s 31ms/step - loss: 0.1647 - accuracy: 0.9500
# Epoch 8/30
# 25/25 [==============================] - 1s 41ms/step - loss: 0.1601 - accuracy: 0.9337
# Epoch 9/30
# 25/25 [==============================] - 1s 34ms/step - loss: 0.0815 - accuracy: 0.9712
# Epoch 10/30
# 25/25 [==============================] - 1s 31ms/step - loss: 0.0718 - accuracy: 0.9837
# Epoch 11/30
# 25/25 [==============================] - 1s 31ms/step - loss: 0.0486 - accuracy: 0.9887
# Epoch 12/30
# 25/25 [==============================] - 1s 36ms/step - loss: 0.0312 - accuracy: 0.9937
# Epoch 13/30
# 25/25 [==============================] - 1s 44ms/step - loss: 0.0695 - accuracy: 0.9800
# Epoch 14/30
# 25/25 [==============================] - 1s 34ms/step - loss: 0.0338 - accuracy: 0.9937
# Epoch 15/30
# 25/25 [==============================] - 1s 32ms/step - loss: 0.0665 - accuracy: 0.9787
# Epoch 16/30
# 25/25 [==============================] - 1s 33ms/step - loss: 0.0084 - accuracy: 0.9987
# Epoch 17/30
# 25/25 [==============================] - 1s 40ms/step - loss: 0.0865 - accuracy: 0.9725
# Epoch 18/30
# 25/25 [==============================] - 1s 31ms/step - loss: 0.0094 - accuracy: 0.9975
# Epoch 19/30
# 25/25 [==============================] - 1s 32ms/step - loss: 0.0296 - accuracy: 0.9950
# Epoch 20/30
# 25/25 [==============================] - 1s 30ms/step - loss: 0.0666 - accuracy: 0.9850
# Epoch 21/30
# 25/25 [==============================] - 1s 45ms/step - loss: 0.0173 - accuracy: 0.9962
# Epoch 22/30
# 25/25 [==============================] - 1s 32ms/step - loss: 0.0138 - accuracy: 0.9975
# Epoch 23/30
# 25/25 [==============================] - 1s 36ms/step - loss: 0.0762 - accuracy: 0.9775
# Epoch 24/30
# 25/25 [==============================] - 1s 40ms/step - loss: 0.0120 - accuracy: 0.9962
# Epoch 25/30
# 25/25 [==============================] - 1s 48ms/step - loss: 0.0519 - accuracy: 0.9825
# Epoch 26/30
# 25/25 [==============================] - 1s 33ms/step - loss: 0.0177 - accuracy: 0.9900
# Epoch 27/30
# 25/25 [==============================] - 1s 31ms/step - loss: 0.0095 - accuracy: 0.9975
# Epoch 28/30
# 25/25 [==============================] - 1s 31ms/step - loss: 0.0626 - accuracy: 0.9850
# Epoch 29/30
# 25/25 [==============================] - 1s 40ms/step - loss: 0.0077 - accuracy: 0.9962
# Epoch 30/30
# 25/25 [==============================] - 1s 34ms/step - loss: 0.0061 - accuracy: 0.9987
# 7/7 [==============================] - 0s 12ms/step
# Acurácia: 0.82

# %%
# POde pular essa etapa se os pacotes já estão instalados
# !pip install numpy
# !pip install scikit-learn
# !pip install scikit-image
# !pip install librosa
# !pip install tqdm
# !pip install matplotlib
# !pip install tensorflow
# Out:
# Collecting numpy
#   Using cached numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Using cached numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
# Installing collected packages: numpy
# Successfully installed numpy-1.26.4
# Collecting scikit-learn
#   Using cached scikit_learn-1.4.1.post1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: numpy<2.0,>=1.19.5 in ./.venv/lib/python3.11/site-packages (from scikit-learn) (1.26.4)
# Collecting scipy>=1.6.0 (from scikit-learn)
#   Using cached scipy-1.12.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Using cached joblib-1.3.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=2.0.0 (from scikit-learn)
#   Using cached threadpoolctl-3.3.0-py3-none-any.whl.metadata (13 kB)
# Using cached scikit_learn-1.4.1.post1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.1 MB)
# Using cached joblib-1.3.2-py3-none-any.whl (302 kB)
# Using cached scipy-1.12.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (38.4 MB)
# Using cached threadpoolctl-3.3.0-py3-none-any.whl (17 kB)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
# ^C
# ERROR: Operation cancelled by user
# Collecting scikit-image
#   Using cached scikit_image-0.22.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: numpy>=1.22 in ./.venv/lib/python3.11/site-packages (from scikit-image) (1.26.4)
# Requirement already satisfied: scipy>=1.8 in ./.venv/lib/python3.11/site-packages (from scikit-image) (1.12.0)
# Collecting networkx>=2.8 (from scikit-image)
#   Using cached networkx-3.2.1-py3-none-any.whl.metadata (5.2 kB)
# Collecting pillow>=9.0.1 (from scikit-image)
#   Using cached pillow-10.2.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (9.7 kB)
# Collecting imageio>=2.27 (from scikit-image)
#   Downloading imageio-2.34.0-py3-none-any.whl.metadata (4.9 kB)
# Collecting tifffile>=2022.8.12 (from scikit-image)
#   Downloading tifffile-2024.2.12-py3-none-any.whl.metadata (31 kB)
# Requirement already satisfied: packaging>=21 in ./.venv/lib/python3.11/site-packages (from scikit-image) (23.2)
# Collecting lazy_loader>=0.3 (from scikit-image)
#   Using cached lazy_loader-0.3-py3-none-any.whl.metadata (4.3 kB)
# Using cached scikit_image-0.22.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.7 MB)
# Downloading imageio-2.34.0-py3-none-any.whl (313 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.4/313.4 kB 5.0 MB/s eta 0:00:00a 0:00:01
# Using cached lazy_loader-0.3-py3-none-any.whl (9.1 kB)
# Using cached networkx-3.2.1-py3-none-any.whl (1.6 MB)
# Using cached pillow-10.2.0-cp311-cp311-manylinux_2_28_x86_64.whl (4.5 MB)
# Downloading tifffile-2024.2.12-py3-none-any.whl (224 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 8.7 MB/s eta 0:00:00
# Installing collected packages: tifffile, pillow, networkx, lazy_loader, imageio, scikit-image
# Successfully installed imageio-2.34.0 lazy_loader-0.3 networkx-3.2.1 pillow-10.2.0 scikit-image-0.22.0 tifffile-2024.2.12

# %%
#ref: https://www.kaggle.com/code/msripooja/steps-to-convert-audio-clip-to-spectrogram
import os
import matplotlib.pyplot as plt
import numpy as np
import skimage.io as io
import librosa
import librosa.display
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
from tqdm import tqdm
from keras.losses import CategoricalCrossentropy
from keras.models import Sequential
from keras.layers import GRU, LSTM, Dense, Conv1D, MaxPooling1D, Flatten, Dropout, Activation, TimeDistributed

#to play audio
import IPython.display as ipd

# Nesse caso você precisa ter no seu diretório uma pasta com o mesmo nome da variável base_dir
base_dir = "audioset"
# E dentro da pasta audioset, você precisa de 3 pastas: carros, motocicletas e motosserras contendo os áudios
audio_carro_path = base_dir + "/carros/"
audio_moto_path = base_dir + "/motocicletas/"  # caminho onde estão os arquivos de audio
audio_serra_path = base_dir + "/motosserras/"

# Caminho onde vão ficar os espectrogramas
spec_base_path = "./audioset/MFCC"
spec_carro_path = os.path.join(spec_base_path, "carros")
spec_moto_path = os.path.join(spec_base_path, "motocicletas")
spec_serra_path = os.path.join(spec_base_path, "motosserras")
 
os.makedirs(spec_base_path, exist_ok=True)
os.makedirs(spec_carro_path, exist_ok=True)
os.makedirs(spec_moto_path, exist_ok=True)
os.makedirs(spec_serra_path, exist_ok=True)
# Out:
# 2024-04-12 13:31:51.818261: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-04-12 13:31:52.091976: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-12 13:31:52.092017: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-12 13:31:52.098120: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-12 13:31:52.132628: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-04-12 13:31:52.136870: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-04-12 13:31:56.522320: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
audio_carro_clips = sorted(os.listdir(audio_carro_path))[:250]
print(f"Número de arquivos .wav na pasta {audio_carro_path}= ",len(audio_carro_clips))

audio_moto_clips = sorted(os.listdir(audio_moto_path))[:250]
print(f"Número de arquivos .wav na pasta {audio_moto_path}= ",len(audio_moto_clips))

audio_serra_clips = sorted(os.listdir(audio_serra_path))[:500]
print(f"Número de arquivos .wav na pasta {audio_serra_path}= ",len(audio_serra_clips))
# Out:
# Número de arquivos .wav na pasta audioset/carros/=  250
# Número de arquivos .wav na pasta audioset/motocicletas/=  250
# Número de arquivos .wav na pasta audioset/motosserras/=  500

# %% [markdown]
# # TESTE MFCC

# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt
y, sr = librosa.load(audio_carro_path+audio_carro_clips[0])
plt.plot(y);
plt.title('Signal');
plt.xlabel('Time (samples)');
plt.ylabel('Amplitude');

# %%
mfccs = librosa.feature.mfcc(y=y, sr=sr)
librosa.display.specshow(mfccs, sr=sr, x_axis='time')

# %% [markdown]
# fim dessa parte

# %%
#aqui está selecionando o primeiro arquivo da lista, pode ser feito um for para pegar todos de uma vez
#verificar esse sample rate
x_carro, sr_carro = librosa.load(audio_carro_path+audio_carro_clips[0]) 
x_moto, sr_moto = librosa.load(audio_moto_path+audio_moto_clips[4]) 
x_serra, sr_serra = librosa.load(audio_serra_path+audio_serra_clips[6]) 

print(type(x_carro), type(sr_carro))
print(x_carro.shape, sr_carro)

print(type(x_moto), type(sr_moto))
print(x_moto.shape, sr_moto)

print(type(x_serra), type(sr_serra))
print(x_serra.shape, sr_serra)
# Out:
# <class 'numpy.ndarray'> <class 'int'>
# (220500,) 22050
# <class 'numpy.ndarray'> <class 'int'>
# (220500,) 22050
# <class 'numpy.ndarray'> <class 'int'>
# (220500,) 22050

# %%
#converter o audio para espectrograma:
# é nesse amplitude_to_dB que ele está convertendo para pressão sonora. Podemos explorar outras ponderações aqui. Se não tiver implementado, podemos implementar.
def salvar_espectrograma(y, sr, spec_path, log=False):

    spect = librosa.feature.melspectrogram(y=y, sr=sr, n_fft=4096)
    mel_spect = librosa.power_to_db(spect, ref=np.max)

    plt.figure(figsize=(1, 1))

    if log:
        librosa.display.specshow(mel_spect, x_axis='time', y_axis='log', fmax=8000)
    else: librosa.display.specshow(mel_spect, x_axis='time', y_axis='mel', fmax=8000)
    plt.margins(0,0)
    
    plt.axis("off")
    plt.savefig(spec_path, dpi=300, bbox_inches = 'tight',
                pad_inches = 0, transparent=False, facecolor='white')
    plt.close()

    print(f"{spec_path} salvo com sucesso.")

# %% [markdown]
# # Salvar imagens de espectrograma
#  - Pule esse passo se as imagens já estiverem na pasta

# %%
# Salvar espectrogramas de carros
for audio_name in audio_carro_clips:
    x_carro, sr_carro = librosa.load(audio_carro_path + audio_name) 
    audio_name = audio_name.replace(".mp3", ".png")
    spec_path = os.path.join(spec_carro_path, audio_name)
    try:
        salvar_espectrograma(x_carro, sr_carro, spec_path)
    except:
        print("Erro ao salvar arquivo %s" % spec_path)

# Salvar espectrogramas de motos
for audio_name in audio_moto_clips:
    x_moto, sr_moto = librosa.load(audio_moto_path + audio_name) 
    audio_name = audio_name.replace(".mp3", ".png")
    spec_path = os.path.join(spec_moto_path, audio_name)
    try:
        salvar_espectrograma(x_moto, sr_moto, spec_path)
    except:
        print("Erro ao salvar arquivo %s" % spec_path)

# Salvar espectrogramas de motosserras
for audio_name in audio_serra_clips:
    x_serra, sr_serra = librosa.load(audio_serra_path + audio_name) 
    audio_name = audio_name.replace(".mp3", ".png")
    spec_path = os.path.join(spec_serra_path, audio_name)
    try:
        salvar_espectrograma(x_serra, sr_serra, spec_path)
    except:
        print("Erro ao salvar arquivo %s" % spec_path)
# Out:
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/#5) Project ForkenSwift electric car： shifting gears-Liqv3KgXThk.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/$150 car jump-1aCyNnYNWvA.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/'87 Honda Mugen Motul Civic Si Race Car at Costa Di Almafi GT4-28SbkfcA6kE.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/'０７ STREET CAR SHOW  ＃６ 大黒２--NBRp5qsrYQ.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/(16) Car Cam： 2 mobile speed cameras, speed racer & scenic esplanade route-2JAjo7yVCgs.png salvo com sucesso.
# Erro ao salvar arquivo ./audioset/mel_espectrogramas_com_log_8000Hz/carros/(HD) - Forza 4 - Top Gear - Car Test - 1967 Chevrolet Corvette Stingray 427--v2FkuCVLjo.png
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/(HD) - Forza 4 - Top Gear - Car Test - 1980 Lotus Esprit Turbo-1Z3ciuA3Y3o.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/(HD) - Forza 4 - Top Gear - Car Test - 1982 DeLorean DMC-12-1zjyiznZSPY.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/(HD) - Forza 4 - Top Gear - Car Test - 1983 Volvo 242 Turbo Evolution--IsCA5lBN74.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/(HD) - Forza 4 - Top Gear - Car Test - 1990 Lotus Carlton-0GZbu00-aMY.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/(HD) - Forza 4 - Top Gear - Car Test - 1993 Nissan Skyline R32 GT-R V-Spec-2NDS2MNq5dk.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/(HD) - Forza 4 - Top Gear - Car Test - 2000 Honda Integra Type-R--PuWinl2B1s.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/(HD) Celebration Exotic Car Rally 4-15-2012-1cFoiMAX0jk.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/(HD) GTA V Epic Highway 5 Star Car Chase (Adder)-4VJSDVXGuqM.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/(Heat 1) Ahmed Tarek - Red Bull Car Park Drift (CPD) 2013 أحمد طارق دريفت ريد بول-1nayT4f9V-k.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/(PART 2~leaving the lots) Paul Walker Memorial Cruise and ROWW Charity Car show Saint Louis--jiyGQfbwt0.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/(PUNISH) VR Commodore @ winton performance car mania-1A4uFF5oTyA.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/03⧸02⧸14：  Clear video of stalker car with license plate 194 VJ9--arHLKEP5LY.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/07 BMW 335i vs 450whp 240sx-0jrhe6OFw-E.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/1200 horsepower Smart car - Wheelie Every Gear -  Forza 4--HVg-i88xE0.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/1280P HD 2.5＂ LCD NIGHT VISION CCTV IN CAR DVR ACCIDENT CAMERA Video Recorder-4eEOO9tzA1U.png salvo com sucesso.
# /tmp/ipykernel_62255/1657064409.py:8: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure(figsize=(1, 1))
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/12th Annual Popular Hot Rodding Championships- Funny Car-11cctCD0ATQ.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/1300 Saloon Stock Car - Lochgelly (World)-5CjYO0nqgW8.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/150 Race Car Hits Cameraman-1P6NL71uTiY.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/154 kp⧸h RC car crash into woods-18C6WBVH9zg.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/15ο ΡΑΛΛΥ ΚΟΡΙΝΘΟΥ 2011 HYUNDAI ACCENT A6 ΓΙΩΤΗΣ - ΒΟΤΣΗΣ IN CAR-3DVoDho5RKY.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/1600 rally car 2--qffkib86ZE.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/1600 rally car action-0MryoXgDsQo.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/16th STREET CAR NATIONALS SUZUKA　②-2IgRckLK_wk.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/17 12 53 เช้าข่าวข้น ตอมแมลงวัน ศักดิ์ นานา-T40AD-E3ci4.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/17 Josh Baughman Sprint Car Flip @ SNMS 5⧸26⧸12-3HIukeVux1o.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/18-08-2012 car hit a pedestrian ⧸ кола удря пешеходец-2wKP1A8On1E.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/1800 Hp Ford GT-02tl_ek8f9I.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/1954 Dodge Firearrow Concept Car-1QZ_F_qnbqY.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/1957 Chevy  burnout at Pocono Racetrack~Good Guys car show-1Ap7QLh9i1o.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/1959 Austin Healey Bug Eye Sprite, AZ Car, Full Restored, Part II of II： Driving Video, SOLD.wmv-1h4yo1bshVQ.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/1964 Vintage Stock Car Chevelle Malibu Barn Find-32Mor3kITQk.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/1965 Pontiac GTO Twisted Sister Hot Love video car-1gCLyNJvEms.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/1968 Chevy Camaro - V8 327 - MUSCLECAR SOUND - restauriert-1ddvRm8MURI.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/1968 camaro drag car-1AeSZdAUfQ0.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/1969 Plymouth Barracuda Fastback Classic Muscle Car V8 Take Off-0Nkp6zb82xY.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/1970 Plymouth 340 Barracuda 9.50 ET Drag⧸Street Car owned by Ken Maisano-0yGNtfAA39Y.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/1972 Volkswagen Standard Beetle 1600cc-uciYg8Oz87I.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/1976 Cadillac Eldorado Convertible Drop Top. 500 cu Motor Congressmans car-BeILNH0jSVg.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/1976 Ford Granada-O9_oZ_c5yFg.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/1977 Pontiac Trans Am X275 car huge wheelstand at No Mercy 5 Quarter finals-2bqqIXMWXVQ.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/1979 Mercedes-Benz 240D parts car - old start, cold start - first start in 13 years (long version)-OuPNy_2AZ48.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/1979 Porsche 935-Cwur_jvxMzY.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/1980 chevy truck burnout-UqeLmHmoBR0.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/1981 Corvette Show Car For Sale-0FOXgf3KhAM.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/1988 Fiero GT 5 spd lauch 0-60 from outside car.-3BpG7TdlpMo.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/1989 Ferrari Testarossa - Spicer Collector Car Profile-0I2sWpnBubk.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/1989 Lincoln Town Car Start Up & Rev - Quick Engine View-6fVt1_MVt4Q.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/1992 EB Ford Fairmont Ghia Power Window Fix-_KYFnY6nAfk.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/1992 GMC with Built vortec 355-0hipL0SkXMo.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/1992 lincoln town car-2MWajC6aWgk.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/1994  5.0 GT Mustang-1⧸4 In Car--F_91SDkNBk.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/1994 POWERSTROKE F350 4X4 CC⧸LB 5SPD ONE OWNER 46K ORIGINAL MILES PROTRUCKSPLUS.COM-QNcSk5e-FII.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/1995 Ford Mustang GT 5.0 Bill Jones Tribute Start Up, Exhaust, Test Drive and In Depth Tour-MkUDPLkMGxA.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/1995 Toyota Supra FOR SALE-2-1wY_Ndtgw.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/1996 Lincoln Town Car short acceleration run-2VqHpGDheXA.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/1996 Nissan 200sx with GTIR motor swap and 60-1 Garrett Turbo-_-lXVZ9QpO8.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/1997 Ford Thunderbird LX V8, Start up, Exhaust and In Depth Review,-gqPj-axDt8w.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/1998 Toyota Mark II Car Reverse Sound (Spur Gear Sound)-1inmTlU0qZY.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/1999 ERA Cobra Kit Car Dyno Pull-2QdnSWzMPCI.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/1999 Miata Passenger Window-ta2vGgYNBgg.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/1999 Troyer Tour Race Car-31GRio_HPRQ.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/1_18 RC Brushless Car-2HPvQZdVs6o.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/1st car off assembly line after general motors became ＂government motors＂-2yNJIsbzAHc.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/2 Car Draft Dega NASCAR 2011 The Game-1G0mwXgqOCU.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/2000 Jeep Grand Cherokee Limited Start Up, Engine & Full Tour-3esyOI3cuPI.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/2001 FORD CROWN VIC ON 22S NO RUB-PE-U8iMqwho.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/2001 Jeep Cherokee Sport Start Up, Engine & Full Tour-cMFacOIgiRU.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/2001 Mustang GT  Bassani exhaust O⧸R X-pipe, Bassani Catback In car 1-3SFu86BPE4M.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/2001 dodge ram Lifted on 36x 15.50 mickeys-Cis2EFd9m2U.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/2001 mustang GT FOR SALE-bqPkbvp8PK4.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/2002 Mustang GT auto vs 2000 Z28 Camaro M6 in car-06EfveS296M.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/2003 Bobby Labonte Crashes At Chicagoland, Car On Fire-26eZe2xThp8.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/2003 Nissan Altima. check engine light on-GUn5_aGpNKM.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/2004 Nissan Sentra SE-R Spec V Supercharged - open header-2nbbfIoayaE.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/2005 BMW E46 ⧸⧸⧸M3 vs 2007 BMW 335i (Race 2)-E3YwyNv5zwk.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/2005 Honda Odyssey Startup Engine & In Depth Tour-4y0KbKCyKus.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/2005 SCCA⧸Champ Car Trans-Am @ San Jose (Full Race)-0g8d4MveZyM.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/2006 Mini Cooper S Review-50i6K-z7TvA.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/2006 Pontiac GTO Autocross Peach State Muscle Car Challenge-3XDs77s9ODA.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/2006 Subway Fresh 500 - Huge Multi Car Crash-2wABMt9m4Pw.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/2006 v6 mustang, pypes exhaust, bbk headers, bbk cai, etc-gT504Sv_XD8.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/2007 Aaron's 312 - Multi Car Crash-2jPTZqSW3LA.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/2007 Audi RS4-KnC_qb1RH9k.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/2007 Chrysler Town Country radiator fan noise-eEY8OozRve0.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/2007 Civic Si Greddy Turbo Kit-pNNjbJRrGao.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/2007 North Pole Speedway Bandoleros Car racing-0pDGae3INT8.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/2008 - AutoX 5 - Run 1-1a9CmJdD5Ns.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/2008 BMW M3 ｜ Track Tested ｜ Edmunds.com-Cu7uy6m4rw0.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/2008 Camping World RV 400 Multi Car spin!--HHJHAF4WxE.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/2008 Honda Accord Coupe V6 LOADED (stk# 40079B ) for sale Trend Motors Used Car Center Rockaway, NJ--r4CV2831Bo.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/2008 PPIHC - Car #44 - Pontiac Sunfire-3Lc8YlSBa10.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/2008 Sprint Car 48th Annual Knoxville Nationals Finish!!--tSPCa-VLS4.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/2009 LINCOLN TOWN CAR SIGNATURE L!!!LOW MILES!!LOW PRICE!!!-20BGawT1jo8.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/200sx skidding.-WBYa_u20cVo.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/2010 Audi R8 5.2 FSI ｜ Road Test ｜ Edmunds.com-d8Wt3ioGQTQ.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/2010 Out in my Bronco-2_-DU_uEow0.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/2010 RC Car Crash Compilation Part 2-0maAWjDvNAU.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/2011 2ltr Saloon Stock Car World Final (part3)-1dEg7y255fQ.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/2011 Duel in the Desert Tony Rost IMCA Sport Modified heat in car on board camera Las Vegas LVMS-42fJMD7_FFU.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/2011 F-150 vs 2012 Ram vs 2012 Silverado-6Bf8TALCj_4.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/2011 F1 Safety Car - Top Gear Test Track - On-Board + Trackside Camera's (rFactor)-5pjuE0iyRwE.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/2011 Ford F-350 Super Duty 6.7L Quick Tour, Start Up, & Rev With Exhaust View - 9K-nMfJgnHZ0zc.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/2011 Harris Clash Knoxville Raceway Sport Modified A Feature Tony Rost in car on board GoPro HD IMCA-0Rpjl1AO-P0.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/2011 High Desert Trails Rally Crash  - In car video with thinman⧸FATMAN racing.--tW9QbQnQvE.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/2011 Lowmead 3 car 4wd comp  Russell Mason-0q9MmzNS2_o.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/2011 NHRA Supernationals Funny Car Session 1 & 2 Qualifying Highlights-2dMvEHPLiP4.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/2011 Nissan 370Z - Convertible ｜ New Car Review ｜ AutoTrader--zzit4txEcE.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/2011 OPTIMA® Ultimate Street Car Invitational Trailer-21qzyUU_ytI.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/2011 Pure Stock Muscle Car Drag Race - Dodge Dart GT Sport Burn Out-1xZDoVUV3P8.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/2011 Shanghai China super car club challenge fiesta-1v6wX8Q5BIc.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/2012 Chevy Avalanche - Features - Augusta GA Car-3I1V62ci_xk.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/2012 Honda Civic - Sedan ｜ New Car Review ｜ AutoTrader-2EgSkmnXc4A.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/2012 Honda Civic Car Horn Sound Effect 2-0TpU5mIeMJk.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/2012 Quicken Loans 400 - Dale Earnhardt Jr's car comes to life, he takes the lead-0V_W0GSWOwk.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/2013 Ford Mustang 3.7L V6 Charleston Car Videos Review ＊ $98 Over Invoice @ Ravenel Ford SC-24Dk83zCBZs.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/2013 Mercedes GLK 350 on Snow-BM0MSMJBCrA.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/2013 Porsche 911 Carrera Start Up and Review 3.4 L Horizontally Opposed⧸6 Cylinder-9BzZvj5W09s.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/2013 Scion FR-S ＂Driving Is Back＂ Commercial-bTcRWzAwL70.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/2014 Chevrolet Silverado Southern Comfort Black Widow-xqASMt0kZjI.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/2014 F1 Australian Grand Prix Safety Car and Restart--Ib1wZDF3_o.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/2014 Mustang GT vs 2010 Genesis 3.8-2odAQZHNDRU.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/2015 BMW 1 Series M Coupe New car reviews,Top Speed,Test Drive-2Mr4P4YPWVs.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/2015 Dodge Challenger 392 SRT Vs 2013 Genesis R-Spec 5.0-3MOdK7QISdY.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/2015 Dodge Charger Hellcat Cold Start-Q6PCrFDeR0E.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/2015 Reunion - Race 4A - Car #54 (1970 Datsun 240Z)-2hNwQIohyEM.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/2015 Touring Car Masters - Winton - Race 2--4vYvHuiHH8.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/2016⧸06⧸05 Street Car Nationals SUZUKA-1fQYCu-R-KA.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/24 Devestator In Car Final 16th November 2014 1-24G1AfEWw1Q.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/240ZR ＂ KATANA＂ TEAM ZPASSION with an amazing sound at MONTHLERY 2010 ASALM.wmv-3JHVa1YqCeE.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/240z nearly finished-9P286DXo8Nk.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/24HrsLeMons Thunderhill08 Spins&Bumps Group of Foolz, Car #9 - Highlights-079vcq6drhg.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/26.09.09 Hednesford raceway pre 68 bangers in car with dom davies #261 part 1-33MSbp6i0SU.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/27th Fun Car Show Illzach - 2007-2v_eCyae0co.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/2o rally sprint othris (οθρυς) 2009 in car fiflis-0alAeNXv8To.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/2wd Datsun 1200 Coupe Rally Car Ulladulla Rally 2006-3HNLe73khxI.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/2ª Etapa do Catarinense de Velocidade na Terra - Acidente João Rodrigo Chemin - Stock Car Opala-1gYCv6BtJ2Y.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/300ZX Twin Turbo： In car video from the 10-second drag run-2X-Q3BSgUuI.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/350z blown engine-BZTSmF9zt_Q.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/350z making weird clutch noise-8iy3RjnVats.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/351 Cleveland Twin Exhaust , Lumpy Cam-OwN672LeXWw.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/3KGT 0 to 120-4OlkJQbNzi0.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/3d model car animation DRAFT--4R2rold4Bk.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/3rd Annual Kansas City Muscle Car Reunion And Nostalgia Drags TV Commercial--EGV3UsNmZ0.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/4-Second Funny Car Run-2FyalYzSF6g.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/435i M Performance Exhaust (#340)-APit6hIABQA.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/45 and parker Houston sunday night car meet-0zTaByZaltY.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/4Runner & Tacoma fun with Noobs-TCc4dnhyHvQ.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/5-11-13 Bee Springs, KY (Big Car Heat 2)-5MlIBN6hixw.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/50° coppa paolino teodori - Opel Astra Kit Car gruppo E1 - Amato D.-0zxNzueJasI.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/55 chevy cummins-killer burnout-PEkR2BLU1so.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/57 Chevy Stock Car - Street Legal-1QVjsCeVYHM.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/592 rw hp 2010 Camaro SS by Hennessey Performance-J6rKfrIq9Ds.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/650 RWHP Police Car-QAWuHvVCI6g.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/67 camaro pro street car-2w0NGuwz5e0.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/69 Camaro street car 10.73 pass-3An7IYyP4jY.png salvo com sucesso.
# ./audioset/mel_espectrogramas_com_log_8000Hz/carros/69 pace car camaro snow donuts-0UhqGLU3zac.png salvo com sucesso.

# %% [markdown]
# # Treinamento e teste de rede neural

# %%
# Carregar espectrogramas com uma CNN e classificar entre "motosserras e não motosserras"

espectrogramas_carro = sorted(os.listdir(spec_carro_path))
espectrogramas_moto = sorted(os.listdir(spec_moto_path))
espectrogramas_serra = sorted(os.listdir(spec_serra_path))

lista_imagens = []
labels = []


def adicionar_rotulos_imagens(espectrogramas, espectro_path, label):
    for spec in espectrogramas:
        image_path = os.path.join(espectro_path, spec)     
        img = io.imread(image_path)
        lista_imagens.append(img[:, :, :-1])
        # 0 corresponde aos carros e motos
        labels.append(label)

adicionar_rotulos_imagens(espectrogramas_carro, spec_carro_path, 0)
adicionar_rotulos_imagens(espectrogramas_moto, spec_moto_path, 0)
adicionar_rotulos_imagens(espectrogramas_serra, spec_serra_path, 1)


X_train, X_test, y_train, y_test = train_test_split(
    np.array(lista_imagens), np.array(labels), test_size=0.2, random_state=100
)
# Out:
# (792, 226, 232, 3)

# %%
print(X_train.shape)
# Out:
# (792, 226, 232, 3)

# %%
model = Sequential()
model.add(Conv2D(16, (3,3), activation='relu', input_shape=X_train[0].shape))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(32, (3,3), activation='relu'))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(64, (3,3), activation='relu'))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(64, (3,3), activation='relu'))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(64, (3,3), activation='relu'))
model.add(MaxPooling2D(2,2))
model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='RMSProp', metrics='accuracy')
model.fit(X_train, y_train, batch_size=32 , epochs=15)

y_pred = model.predict(X_test)[:, 0]
y_pred = np.round(y_pred)
acc = len(np.where(y_pred == y_test)[0]) / len(y_test)
print("Acurácia:", acc)
# Out:
# Epoch 1/15
# 25/25 [==============================] - 41s 2s/step - loss: 15.5470 - accuracy: 0.5202
# Epoch 2/15
# 25/25 [==============================] - 39s 2s/step - loss: 0.6922 - accuracy: 0.5997
# Epoch 3/15
# 25/25 [==============================] - 38s 2s/step - loss: 1.4618 - accuracy: 0.5581
# Epoch 4/15
# 25/25 [==============================] - 39s 2s/step - loss: 0.8158 - accuracy: 0.5934
# Epoch 5/15
# 25/25 [==============================] - 39s 2s/step - loss: 0.7896 - accuracy: 0.6023
# Epoch 6/15
# 25/25 [==============================] - 38s 2s/step - loss: 0.7279 - accuracy: 0.6023
# Epoch 7/15
# 25/25 [==============================] - 39s 2s/step - loss: 0.7356 - accuracy: 0.6414
# Epoch 8/15
# 25/25 [==============================] - 38s 2s/step - loss: 0.7656 - accuracy: 0.6578
# Epoch 9/15
# 25/25 [==============================] - 40s 2s/step - loss: 0.5778 - accuracy: 0.7083
# Epoch 10/15
# 25/25 [==============================] - 39s 2s/step - loss: 0.7047 - accuracy: 0.7109
# Epoch 11/15
# 25/25 [==============================] - 39s 2s/step - loss: 0.5875 - accuracy: 0.7399
# Epoch 12/15
# 25/25 [==============================] - 38s 2s/step - loss: 0.4895 - accuracy: 0.7601
# Epoch 13/15
# 25/25 [==============================] - 39s 2s/step - loss: 0.4637 - accuracy: 0.7740
# Epoch 14/15
# 25/25 [==============================] - 38s 2s/step - loss: 0.4627 - accuracy: 0.8056
# Epoch 15/15
# 25/25 [==============================] - 39s 2s/step - loss: 0.4201 - accuracy: 0.7942
# 7/7 [==============================] - 2s 287ms/step
# Acurácia: 0.7939698492462312
